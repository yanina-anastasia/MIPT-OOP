# %% [markdown]
# # Задание для отдела аналитики

# %%
import pandas as pd
import numpy as np
import math
import sys
import copy
import scipy
from sklearn.cluster import KMeans
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances
from collections import Counter
from scipy.stats import pearsonr, spearmanr, kendalltau

from sklearn.preprocessing import Binarizer
from scipy.stats.mstats import mode

from skimage.io import imread, imshow

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Считываем данные и отрезаем первый столбец: id-шники сессий.

# %%
data = pd.read_table('task1/analytics_task', names=range(101))
data.shape
# Out:
# (45578, 101)

# %%
transactions = data.ix[:,1:].astype('float').as_matrix()
transactions.shape
# Out:
# (45578, 100)

# %% [markdown]
# На первый взгляд кажется, что в таблице есть несколько полностью нулевых столбцов. Проверим эту догадку:

# %%
goodfeatures = []
print "Columns with same values:"
for i, column in enumerate(transactions.T):
    if max(column) == min(column):
        print i, max(column)
    else:
        goodfeatures.append(i)
# Out:
# Columns with same values:
# 37 0.0
# 46 0.0
# 54 0.0
# 56 0.0
# 73 0.0
# 74 0.0
# 75 0.0
# 77 0.0
# 85 1.0
# 92 0.0
# 93 0.0
# 96 0.0
# 97 0.0
# 98 0.0
# 99 0.0

# %% [markdown]
# Интересно, здесь есть столбцы из одних нулей и один столбец, состоящий из одних единиц. Эти признаки никакой информации не добавляют, можно их смело удалять

# %%
transactions = transactions[:, goodfeatures]
print transactions.shape
# Out:
# (45578, 85)

# %% [markdown]
# Проанализируем оставшиеся признаки:

# %% [markdown]
# ##### Анализ признаков

# %% [markdown]
# Смотрим минимум, максимум и количество ненулевых значений для каждого признака

# %%
for i in range(85):
    print "{0}: min {1}, max {2}, {3:.3f}% nonzero". format(i, min(transactions.T[i]), max(transactions.T[i]), np.count_nonzero(transactions.T[i]) * 100.0 / len(transactions.T[i]))
# Out:
# 0: min 0.0, max 6300.0, 98.449% nonzero
# 1: min 0.0, max 795.0, 79.060% nonzero
# 2: min 0.0, max 761.0, 45.671% nonzero
# 3: min 0.0, max 500.0, 93.808% nonzero
# 4: min 0.0, max 1.84467440737e+19, 97.892% nonzero
# 5: min 0.0, max 86375.0, 99.974% nonzero
# 6: min 0.0, max 88.0, 1.924% nonzero
# 7: min 0.0, max 100.0, 22.798% nonzero
# 8: min 0.0, max 1.0, 48.978% nonzero
# 9: min 0.0, max 197.0, 99.987% nonzero
# 10: min 0.0, max 76.0, 7.337% nonzero
# 11: min 0.0, max 244.0, 80.743% nonzero
# 12: min 0.0, max 107.0, 30.767% nonzero
# 13: min 0.0, max 100.0, 30.767% nonzero
# 14: min 0.0, max 544.0, 99.443% nonzero
# 15: min 1.0, max 302.0, 100.000% nonzero
# 16: min 0.0, max 41.0, 0.044% nonzero
# 17: min 0.0, max 5.0, 0.009% nonzero
# 18: min 0.0, max 287.0, 98.449% nonzero
# 19: min 0.0, max 287.0, 63.722% nonzero
# 20: min 0.0, max 39.0, 17.612% nonzero
# 21: min 0.0, max 20.0, 3.188% nonzero
# 22: min 0.0, max 880.0, 63.976% nonzero
# 23: min 0.0, max 500.0, 6.064% nonzero
# 24: min 0.0, max 104.0, 9.145% nonzero
# 25: min 0.0, max 1686.0, 99.928% nonzero
# 26: min 0.0, max 37818.0, 99.987% nonzero
# 27: min 0.0, max 3082.0, 86.662% nonzero
# 28: min 0.0, max 1.0, 4.877% nonzero
# 29: min 0.0, max 1375991982.0, 99.987% nonzero
# 30: min 0.0, max 1375991997.0, 98.431% nonzero
# 31: min 0.0, max 23.0, 96.781% nonzero
# 32: min 0.0, max 23.0, 97.824% nonzero
# 33: min 0.0, max 15.0, 53.557% nonzero
# 34: min 0.0, max 176.0, 62.050% nonzero
# 35: min 0.0, max 128.0, 71.725% nonzero
# 36: min 0.0, max 23.0, 5.941% nonzero
# 37: min 0.0, max 12.0, 0.250% nonzero
# 38: min 0.0, max 15.0, 99.987% nonzero
# 39: min 0.0, max 252.0, 98.431% nonzero
# 40: min 0.0, max 36.0, 0.105% nonzero
# 41: min 0.0, max 287.0, 93.988% nonzero
# 42: min 0.0, max 305.0, 99.895% nonzero
# 43: min 0.0, max 63.0, 0.895% nonzero
# 44: min 0.0, max 3245.0, 86.204% nonzero
# 45: min 0.0, max 6.0, 0.042% nonzero
# 46: min 0.0, max 304.0, 96.931% nonzero
# 47: min 0.0, max 49.0, 1.924% nonzero
# 48: min 0.0, max 157.0, 63.349% nonzero
# 49: min 0.0, max 199.0, 93.808% nonzero
# 50: min 0.0, max 1300.0, 38.137% nonzero
# 51: min 0.0, max 118.0, 0.138% nonzero
# 52: min 0.0, max 27.0, 1.852% nonzero
# 53: min 0.0, max 25.0, 24.391% nonzero
# 54: min 0.0, max 1.0, 32.226% nonzero
# 55: min 0.0, max 301.0, 9.726% nonzero
# 56: min 0.0, max 11.0, 0.895% nonzero
# 57: min 0.0, max 23.0, 9.230% nonzero
# 58: min 0.0, max 11.0, 0.825% nonzero
# 59: min 0.0, max 492.0, 60.834% nonzero
# 60: min 0.0, max 112.0, 60.211% nonzero
# 61: min 0.0, max 42.0, 11.179% nonzero
# 62: min 0.0, max 242.0, 22.798% nonzero
# 63: min 0.0, max 31.0, 2.481% nonzero
# 64: min 0.0, max 530.0, 15.036% nonzero
# 65: min 0.0, max 1.0, 10.288% nonzero
# 66: min 0.0, max 48.0, 0.584% nonzero
# 67: min 0.0, max 22.0, 0.976% nonzero
# 68: min 0.0, max 302.0, 98.282% nonzero
# 69: min 0.0, max 22.0, 6.110% nonzero
# 70: min 6.0, max 452.0, 100.000% nonzero
# 71: min 0.0, max 5.0, 58.596% nonzero
# 72: min 0.0, max 903.0, 94.370% nonzero
# 73: min 0.0, max 10000.0, 61.299% nonzero
# 74: min 0.0, max 453.0, 93.089% nonzero
# 75: min 0.0, max 45.0, 3.124% nonzero
# 76: min 0.0, max 119.0, 60.180% nonzero
# 77: min 0.0, max 6.0, 14.410% nonzero
# 78: min 0.0, max 1665.0, 10.795% nonzero
# 79: min 0.0, max 7.0, 99.987% nonzero
# 80: min 0.0, max 2.0, 99.987% nonzero
# 81: min 0.0, max 7.0, 0.099% nonzero
# 82: min 0.0, max 19.0, 0.066% nonzero
# 83: min 0.0, max 1.0, 0.022% nonzero
# 84: min 0.0, max 37.0, 1.979% nonzero

# %% [markdown]
# Нулей нет всего в двух столбцах (15 и 70). Посмотрим на гистограммы для них:

# %%
plt.plot(np.histogram(transactions.T[15], bins=range(50))[0])
plt.show()

# %%
plt.plot(np.histogram(transactions.T[70], bins=range(50))[0])
plt.show()

# %% [markdown]
# Хочется понять, есть ли какая-то корреляция между этими признаками. Для того, чтобы исследовать статистическую зависимость между двумя переменными, будем использовать три критерия: Pearson correlation coefficient, Spearman rank-order correlation coefficient и Kendall Tau correlation coefficient.

# %% [markdown]
# Pearson correlation coefficient - мера линейной корреляции между двумя переменными. Тот факт, что коэффициент положительный, интерпретируется как "если переменная 1 возрастает, то и переменная 2 возрастает", отрицательность интерпретируется соответственно как "если переменная 1 возрастает, то переменная 2 убывает". Ноль означает отсутствие корреляции между признаками.

# %% [markdown]
# Spearman rank-order correlation coefficient описывает, насколько хорошо зависимость между двумя переменными может быть описана монотонной функцией. Определяется как корреляционный коэффициент Пирсона для отранжированных переменных.

# %% [markdown]
# Формула для Kendall Tau correlation coefficient - $$\dfrac{P - Q}{\sqrt{(P + Q + T) * (P + Q + U)}}$$
# Здесь P - количество согласованных пар, Q - несогласованных. Пара согласована, если выполнены оба условия $x_i < x_j$ и $y_i < y_j$ (или наоборот). $T$ - количество связей только в $x$, $U$ - только в $y$.

# %%
def find_correlations(transactions, x, y):
    print '{0} and {1} features:'.format(x, y)
    print 'PearsonrResult', pearsonr(transactions.T[x], transactions.T[y])
    print spearmanr(transactions.T[x], transactions.T[y])
    print kendalltau(transactions.T[x], transactions.T[y])
    print 
    
def filter_correlations(transactions, features, pearson_t):
    for i, j in itertools.combinations(features,2):
        if pearsonr(transactions.T[i], transactions.T[j])[0] > pearson_t:
            print '{0} and {1} features:'.format(i, j)
            print 'PearsonrResult', pearsonr(transactions.T[i], transactions.T[j])
            print spearmanr(transactions.T[i], transactions.T[j])
            print kendalltau(transactions.T[i], transactions.T[j])
            print

# %%
find_correlations(transactions, 15, 70)
# Out:
# 15 and 70 features:
# PearsonrResult (0.11300421956462459, 2.1107412229867121e-129)
# SpearmanrResult(correlation=0.065713781207572694, pvalue=8.3803051257315272e-45)
# KendalltauResult(correlation=0.047576837521190331, pvalue=2.0653689699067576e-52)

# %% [markdown]
# Интерпертировать такой результат довольно сложно. Перед тем, как искать в датасете ассоциативные правила, попробуем посмотреть на корреляции всевозможных пар признаков друг с другом (вдруг что-то хорошее получится?).

# %%
filter_correlations(transactions, range(85), 0.9)
# Out:
# 4 and 83 features:
# PearsonrResult (1.0, 0.0)
# SpearmanrResult(correlation=0.043415623786015392, pvalue=1.8111584930848187e-20)
# KendalltauResult(correlation=0.042022670434706248, pvalue=2.8151751014965684e-41)
#
# 9 and 49 features:
# PearsonrResult (0.95245740970210124, 0.0)
# SpearmanrResult(correlation=0.82800853875657465, pvalue=0.0)
# KendalltauResult(correlation=0.77894358909492045, pvalue=0.0)
#
# 11 and 35 features:
# PearsonrResult (0.97591310671290488, 0.0)
# SpearmanrResult(correlation=0.92421989641929325, pvalue=0.0)
# KendalltauResult(correlation=0.87594305162631603, pvalue=0.0)
#
# 11 and 39 features:
# PearsonrResult (0.90152060345170593, 0.0)
# SpearmanrResult(correlation=0.69725484319058872, pvalue=0.0)
# KendalltauResult(correlation=0.62123902538911491, pvalue=0.0)
#
# 15 and 42 features:
# PearsonrResult (0.97186624251300047, 0.0)
# SpearmanrResult(correlation=0.97554759785375045, pvalue=0.0)
# KendalltauResult(correlation=0.94279331846884096, pvalue=0.0)
#
# 15 and 46 features:
# PearsonrResult (0.92787106050843515, 0.0)
# SpearmanrResult(correlation=0.90740145106472414, pvalue=0.0)
# KendalltauResult(correlation=0.83346163703031106, pvalue=0.0)
#
# 15 and 68 features:
# PearsonrResult (0.96993639770158113, 0.0)
# SpearmanrResult(correlation=0.94809723054031192, pvalue=0.0)
# KendalltauResult(correlation=0.92521835647239326, pvalue=0.0)
#
# 18 and 39 features:
# PearsonrResult (0.96894320648994026, 0.0)
# SpearmanrResult(correlation=0.97538414200031398, pvalue=0.0)
# KendalltauResult(correlation=0.92729099305553297, pvalue=0.0)
#
# 18 and 41 features:
# PearsonrResult (0.92857056022792517, 0.0)
# SpearmanrResult(correlation=0.914395383492554, pvalue=0.0)
# KendalltauResult(correlation=0.85148240813189457, pvalue=0.0)
#
# 42 and 46 features:
# PearsonrResult (0.92996241687767456, 0.0)
# SpearmanrResult(correlation=0.90497373935606562, pvalue=0.0)
# KendalltauResult(correlation=0.83851210865845349, pvalue=0.0)
#
# 42 and 68 features:
# PearsonrResult (0.94383960198385031, 0.0)
# SpearmanrResult(correlation=0.92803642452227031, pvalue=0.0)
# KendalltauResult(correlation=0.88115871994177031, pvalue=0.0)
#
# 46 and 68 features:
# PearsonrResult (0.91138631134524772, 0.0)
# SpearmanrResult(correlation=0.87332679846301486, pvalue=0.0)
# KendalltauResult(correlation=0.79359716038342787, pvalue=0.0)

# %% [markdown]
# Нашли 12 пар признаков, между которыми есть достаточно большая корреляция. В то же время найденные взаимосвязи могут оказаться ложными зависимостями. Посмотрим на гистограммы этих признаков:

# %%
for i in sorted([46,68,42,18,41,39,15,11,9,4,83]):
    f, ax = plt.subplots()
    ax.plot(np.histogram(transactions.T[i], bins=range(50))[0])
    ax.set_title("Feature {0}".format(i))

# %% [markdown]
# По графикам убеждаемся, что 15, 42, 46, 68 и 25 имеют очень похожие гистограммы.

# %% [markdown]
# Эти признаки явно описывают какую-то одну группу характеристик сессий.

# %% [markdown]
# Смотрим на гистограммы всех признаков и пытаемся найти еще подобные группы признаков:

# %%
for i in range(85):
    f, ax = plt.subplots()
    ax.plot(np.histogram(transactions.T[i], bins=range(50))[0])
    ax.set_title(i)

# %% [markdown]
# Посмотрим на признаки и попытаемся их интерпретировать

# %% [markdown]
# Признаки 31, 32 и 74 имеют необычную форму (и их гистограммы похожи друг на друга)

# %%
for i in sorted([31,32,74]):
    f, ax = plt.subplots()
    ax.plot(np.histogram(transactions.T[i], bins=range(50))[0])
    ax.set_title("Feature {0}".format(i))

# %%
filter_correlations(transactions, [31,32,74], 0.5)
# Out:
# 31 and 32 features:
# PearsonrResult (0.50745574461045129, 0.0)
# SpearmanrResult(correlation=0.53755024238192817, pvalue=0.0)
# KendalltauResult(correlation=0.46488027470523363, pvalue=0.0)

# %% [markdown]
# Смотрим на другие признаки с интересными гистограммами. Например, на признак 26:

# %%
plt.plot(np.histogram(transactions.T[26], bins=range(10000))[0])
plt.show()

# %% [markdown]
# Посмотрим на самые часто встречающиеся значения в этом признаке:

# %%
print Counter(transactions.T[26]).most_common(10)
# Out:
# [(1000.0, 8017), (3000.0, 5677), (4000.0, 5325), (3500.0, 4188), (2500.0, 4090), (2667.0, 1512), (3333.0, 1317), (3667.0, 781), (3250.0, 682), (3143.0, 628)]

# %% [markdown]
# 26-й признак наводит на мысль. В нем самые часто встречающиеся значения - целые круглые числа. Дальше по убыванию меры встречаемости идут числа (3333, 3667) которые наводят на мысль, что это число - одна третья какого-то другого числа, число 3250 наводит на мысль об одной четвертой, 3143 - об одной седьмой (1.7 = 0.142857...). Похоже, что это признак - доли чего-то (ну или какие-то хитро нормированные признаки). Надо взять это на заметку

# %% [markdown]
# Рассмотрим нулевой признак:

# %%
f, ax = plt.subplots()
ax.plot(np.histogram(transactions.T[0], bins=range(500))[0])
ax.set_title(0)

# %% [markdown]
# Тут явно видна закономерность: на гистограмме присутствуют пики, они расположены через примерно равные промежутки. При этом значения пиков убывают (чем больше значение, тем меньшее количество раз, оно встречается).

# %%
f, ax = plt.subplots()
ax.plot(np.histogram(transactions.T[1], bins=range(500))[0])
ax.set_title(1)

# %% [markdown]
# Здесь тоже видна закономерность

# %% [markdown]
# Теперь посмотрим на 72-й признак:

# %%
f, ax = plt.subplots()
ax.plot([len(transactions.T[72][transactions.T[72] == x]) for x in range(100)])
ax.set_title(72)

# %% [markdown]
# Здесь видно, что какие значения встречаются чаще предыдущих (причем заметна некоторая периодичность, часто встречаются те значения, которые отстоят друг от друга на расстояние примерно равное 10 на промежутке от 40 до 80)

# %%
print Counter(transactions.T[72]).most_common(10)
# Out:
# [(0.0, 2566), (49.0, 1566), (59.0, 1428), (39.0, 1222), (69.0, 1106), (48.0, 1059), (1.0, 1022), (9.0, 954), (58.0, 934), (38.0, 872)]

# %% [markdown]
# Кроме нуля, часто встречаемые значения - 49, 59, 39, 69. Все они различаются друг относительно друга на 10.

# %% [markdown]
# Мне показались странными признаки 29 и 30. Они оба сильно отличаются от всех остальных признаков по диапазону принимаемых значений и явно взаимосвязаны друг с другом. Кроме того, у них большие значения. Эти признаки похожи на айдишники. Например, на айдишник сессии. Но тогда непонятно, почему их два?

# %%
print Counter(transactions.T[29]).most_common(10)
print Counter(transactions.T[30]).most_common(10)
# Out:
# [(1375905638.0, 12), (1375905603.0, 11), (1375905645.0, 11), (1375905710.0, 11), (1375905647.0, 10), (1375905685.0, 10), (1375905616.0, 9), (1375905630.0, 9), (1375905649.0, 9), (1375905687.0, 9)]
# [(0.0, 715), (1375905613.0, 16), (1375905657.0, 16), (1375905615.0, 15), (1375905618.0, 15), (1375905731.0, 15), (1375905606.0, 14), (1375905609.0, 14), (1375905616.0, 14), (1375905689.0, 14)]

# %% [markdown]
# Часто встречающиеся значения отличаются друг от друга несильно.

# %% [markdown]
# Смотрим на графики:

# %%
f, ax = plt.subplots()
ax.plot(np.histogram(transactions.T[29], range(1375905000, 1375908000))[0])
ax.set_title(29)

# %%
f, ax = plt.subplots()
ax.plot(np.histogram(transactions.T[30], range(1375905000, 1375908000))[0])
ax.set_title(30)

# %% [markdown]
# Посмотрим, насколько различаются значения в 29 и 30 столбиках

# %%
diffs = np.array([transactions[i][30] - value for i, value in enumerate(transactions.T[29])])
print diffs[diffs < 0].size
# Out:
# 3036

# %% [markdown]
# Интересно, значение в 30 стоблике почти всегда больше значения в 29. Есть гипотеза, что эти два признака означают начало и конец сессии. Возможно, это какие-то специальные айдишники, обозначающие начало и конец сессии, но это вряд ли, потому что в столбиках есть повторяющиеся признаки. Скорее всего, это время начала и конца сессии.

# %% [markdown]
# Плюс еще есть много признаков, гистограммы которых по форме похожи на ветвь графика функции 1/x. Такие признаки могут быть зависимы друг относительно друга.

# %%
a = [11,19,22,34,35,76]
filter_correlations(transactions, a, 0.5)
# Out:
# 11 and 35 features:
# PearsonrResult (0.97591310671290488, 0.0)
# SpearmanrResult(correlation=0.92421989641929325, pvalue=0.0)
# KendalltauResult(correlation=0.87594305162631603, pvalue=0.0)
#
# 19 and 22 features:
# PearsonrResult (0.52871912632634899, 0.0)
# SpearmanrResult(correlation=0.9694648722079493, pvalue=0.0)
# KendalltauResult(correlation=0.93602719983310068, pvalue=0.0)
#
# 19 and 34 features:
# PearsonrResult (0.68710744667449186, 0.0)
# SpearmanrResult(correlation=0.49494442967072566, pvalue=0.0)
# KendalltauResult(correlation=0.40678731684566755, pvalue=0.0)

# %% [markdown]
# По полученным результатам трудно утверждать, что эти признаки взаимосвязаны (среди всей группы только три пары с высокими коэффициентами корреляции).

# %% [markdown]
# Попробуем то же самое для другой группы признаков:

# %%
find_correlations(transactions, 46, 42)
find_correlations(transactions, 48, 49)
find_correlations(transactions, 49, 42)
# Out:
# 46 and 42 features:
# PearsonrResult (0.92996241687767456, 0.0)
# SpearmanrResult(correlation=0.90497373935606562, pvalue=0.0)
# KendalltauResult(correlation=0.83851210865845349, pvalue=0.0)
#
# 48 and 49 features:
# PearsonrResult (0.82614250164964909, 0.0)
# SpearmanrResult(correlation=0.51914642806047162, pvalue=0.0)
# KendalltauResult(correlation=0.46479458078296138, pvalue=0.0)
#
# 49 and 42 features:
# PearsonrResult (0.80868675845760818, 0.0)
# SpearmanrResult(correlation=0.57664404579465844, pvalue=0.0)
# KendalltauResult(correlation=0.46835114642998316, pvalue=0.0)

# %% [markdown]
# 49, 48, 46 и 42 - эти признаки точно взаимосвязаны друг с другом.

# %% [markdown]
# ### Поиск ассоциативных правил

# %% [markdown]
# ##### Бинаризация признаков

# %% [markdown]
# Бинаризация признаков - сложная задача. От того, какие threshold'ы мы подберем, будет напрямую зависеть, какие ассоциативные правила мы сможем найти. Будем использовать несколько подходов к бинаризации признаков и сравним полученные результаты.

# %% [markdown]
# Будем использовать несколько подходов к бинаризации. В статье http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.14.4447&rep=rep1&type=pdf приводятся 4 метода:
# 1) Использование среднего значения по каждому признаку (меньше mean - 0, больше mean - 1).
# 2) То же самое, но для медианы.
# 3) Можно попробовать тот же метод для моды, но в вышеупомянутой статье описаны эксперименты, где поиск правил по бинаризованным данным, где порогом является мода, дает качество хуже, чем при использовании среднего значения и медианы. Мода чувствительна к ошибкам (или выбросам) в данных, из-за этого бинаризация, основанная на ней может работать хуже. Впрочем, на нашем датасете это может сработать, попробуем и медиану тоже.
# 4) Принципиально другой подход - использовать методы для кластеризации для того, что поделить значения признаков на две группы. Попробуем делать кластеризацию опираясь на данные только об одном признаке, о паре признаков, о тройке, а также о группах признаков, найденных ранее (см. подробнее далее в отчете).

# %% [markdown]
# Откровенно говоря, первые три метода вызывают у меня огромные подозрения. 4-ый метод стоит попробовать, он неожиданно может дать адекватный результат. Но самым логичным мне кажется следующий метод:

# %% [markdown]
# ##### Бинаризация

# %% [markdown]
# Есть признаки, которых очень мало уникальных значений (то есть в которых почти всегда стоит одно и то же значение). Они не очень информативны, можно их удалить из выборки

# %%
good_features = []
binary_features = []
for i, feature in enumerate(transactions.T):
    most_common_perc = Counter(feature).most_common(1)[0][1] * 1.0 / transactions.shape[0]
    if most_common_perc < 0.9 and len(np.unique(feature)) != 2:
        good_features.append(i)
    if len(np.unique(feature)) == 2:
        binary_features.append(i)
        
binary_transactions = transactions[:, binary_features]
transactions = transactions[:, good_features]
print transactions.shape
# Out:
# (45578, 51)

# %% [markdown]
# Для оставшихся 51 признака будем их область значений делить на несколько частей и смотреть, к какой части относится каждое значение

# %%
bins = 10
feature_bounds = []
for feature in transactions.T:
    feature_bounds.append(np.linspace(min(feature), max(feature), bins + 1))

# %%
X = np.zeros((transactions.shape[0], bins * transactions.shape[1]))
for i, feature in enumerate(transactions.T):
    for j, f in enumerate(feature):
        X[j, np.argmin(np.abs(feature_bounds[i] - f)) - 1 + i * bins] = 1

# %%
X = np.column_stack((X, binary_transactions))
print X.shape
# Out:
# (45578, 520)

# %% [markdown]
# Сделаем бинаризацию и по тем 4 методам из статьи, а потом будет сравнивать результаты

# %% [markdown]
# ##### threshold = mean, median, mode

# %% [markdown]
# Попробуем методы из статьи http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.14.4447&rep=rep1&type=pdf (делим на 0 и 1 относительно среднего значения, медианы и моды):

# %%
trans_len = transactions.shape[0]
mean_transactions = np.empty((trans_len, 0))
for feature in transactions.T:
    mean_bin = Binarizer(threshold=np.mean(feature))
    bin_feature = mean_bin.transform(feature)
    mean_transactions = np.column_stack((mean_transactions, bin_feature.T))

# %%
median_transactions = np.empty((trans_len, 0))
for feature in transactions.T:
    median_bin = Binarizer(threshold=np.median(feature))
    bin_feature = median_bin.transform(feature)
    median_transactions = np.column_stack((median_transactions, bin_feature.T))

# %%
mode_transactions = np.empty((trans_len, 0))
for feature in transactions.T:
    mode_bin = Binarizer(threshold=mode(feature)[0][0])
    bin_feature = mode_bin.transform(feature)
    mode_transactions = np.column_stack((mode_transactions, bin_feature.T))

# %% [markdown]
# ##### Бинаризация с помощью кластеризации

# %% [markdown]
# Вообще подбирать threshold, основываясь только на внешнем виде гистограмм признаков, довольно проблематично. Попробуем с помощью какого-нибудь алгоритма кластеризации, например, с помощью kmeans, делить каждый признак на два класса.

# %%
kmeans_transactions = np.empty((trans_len,0))

for i in range(transactions.shape[1]):
    kmeans = KMeans(n_clusters = 2)
    y_pred = kmeans.fit_predict([[feature] for feature in transactions.T[i]])
    #if 45 < sum(y_pred) * 100.0 / len(y_pred) < 55:
        #print i, sum(y_pred) * 100.0 / len(y_pred)
    kmeans_transactions = np.column_stack((kmeans_transactions, np.array(y_pred)))

# %%
print kmeans_transactions.shape
# Out:
# (45578, 51)

# %% [markdown]
# Попробуем делать кластеризацию не по одному признаку, а по нескольку:

# %%
import copy

feature_num = transactions.shape[1]
for i, j in itertools.combinations(range(feature_num), 2):
    kmeans = KMeans(n_clusters = 2)
    y_pred = kmeans.fit_predict(transactions[:,[i,j]])
    if 20 < sum(y_pred) * 100.0 / len(y_pred) < 80:
        #print i, j, sum(y_pred) * 100.0 / len(y_pred)
        kmeans_transactions = np.append(kmeans_transactions, np.array(y_pred).reshape(len(y_pred), 1), axis=1)

# %%
print kmeans_transactions.shape
# Out:
# (45578, 442)

# %% [markdown]
# ##### Ассоциативные правила. Apriori.

# %% [markdown]
# Метрики для оценки качества найденных правил:

# %%
def support(transactions, itemset):
    ids = []
    for id, transaction in enumerate(transactions):
        if all(transaction[itemset] != 0):
            ids.append(id)
    return len(ids) * 1.0 / len(transactions)

def confidence(transactions, x, y):
    return support(transactions, list(set(x + y))) / support(transactions, x)

def lift(transactions, x, y):
    return support(transactions, list(set(x + y))) / (support(transactions, x) * support(transactions, y)) 

def conviction(transactions, x, y):
    if confidence(transactions, x, y) != 1:
        return (1 - support(transactions, y)) / (1 - confidence(transactions, x, y))
    else:
        return np.inf

# %% [markdown]
# Например, ищем метрики для произвольных наборов признаков:

# %%
print support(transactions, [15])
print confidence(transactions, range(6,8), [15])
print lift(transactions, range(6,8), [15])
print conviction(transactions, range(6,8), [15])
# Out:
# 0.176115669841
# 0.25964777211
# 1.47430249872
# 1.11282751523

# %% [markdown]
# Теперь надо научиться искать frequent itemsets. Будем делать это с помощью алгоритма Apriori.

# %% [markdown]
# Алгоритм работает довольно долго.

# %%
def apriori(transactions, delta):
    freq_itemsets = []
    #find set of frequent 1-element sets
    one_itemsets = []
    for feature in range(transactions.shape[1]):
        one_itemsets.append(support(transactions, [feature]))
    freq_features = [[i] for i, x in enumerate(one_itemsets) if x > delta]
    freq_itemsets.append(freq_features)
    print freq_features 
    
    for j in range(1, len(freq_features)):
        #print 'j=', j
        if len(freq_itemsets[j-1]) == 0:
            break
        temp = []
        for itemset in freq_itemsets[j-1]:
            #print 'j=',' itemset:', itemset
            for f in freq_features:
                if f[0] not in itemset and list(set(itemset+f)) not in temp:
                    cur_support = support(transactions, list(set(itemset+f)))
                    if cur_support > delta:
                        temp.append(list(set(itemset+f)))
        freq_itemsets.append(temp)
    return freq_itemsets

def find_rules(transactions, itemset, y, kappa, assoc_rules, labels=None):
    for f in itemset:
        cur_itemset = copy.deepcopy(itemset)
        cur_itemset.remove(f)
        cur_y = list(set(y+[f]))
        if labels == None:
            conf = confidence(transactions, cur_itemset, cur_y)
            if conf > kappa:
                rule = (cur_itemset, cur_y, conf)
                if rule not in assoc_rules:
                    if len(cur_itemset) > 1: #правила вида 1 -> 2 нам не очень интересны
                        assoc_rules.append(rule)
                        print 'Rule', cur_itemset, '+', cur_y, 'was added to rules with confidence:', conf
                        find_rules(transactions, cur_itemset, cur_y, kappa, assoc_rules)
        elif len(cur_y) == 1 and cur_y[0] in labels:
            conf = confidence(transactions, cur_itemset, cur_y)
            if conf > kappa:
                rule = (cur_itemset, cur_y, conf)
                if rule not in assoc_rules:
                    if len(cur_itemset) > 1:
                        assoc_rules.append(rule)
                        print 'Rule', cur_itemset, '+', cur_y, 'was added to rules with confidence:', conf
                        find_rules(transactions, cur_itemset, cur_y, kappa, assoc_rules, labels)
            
    
def dummy_find_rules(freq_itemsets, transactions, kappa):
    assoc_rules = []
    for itemset_row in freq_itemsets:
        for itemset in itemset_row:
            for itemset_row_2 in freq_itemsets:
                for itemset2 in itemset_row_2:
                    if itemset != itemset2 and not bool(set(itemset) & set(itemset2)):
                        conf = confidence(transactions, itemset, itemset2)
                        if conf > kappa:
                            rule = (itemset, itemset2, conf)
                            if rule not in assoc_rules:
                                assoc_rules.append(rule)
                                print 'Rule', itemset, '+', itemset2, 'was added to rules with confidence:', conf
    return assoc_rules

# %% [markdown]
# Дальше тестирую алгоритм на датасетах, бинаризованных по первым трем правилам. В силу того, что бинаризация примитивная, результаты получаются не очень хорошие(в принципе, можно эту часть не смотреть)

# %%
freq_itemsets_mean = apriori(mean_transactions, 0.3)
# Out:
# [[0], [1], [2], [3], [5], [8], [11], [12], [14], [15], [18], [26], [27], [29], [30], [31], [32], [39], [41], [42], [44], [46], [50], [54], [59], [60], [68], [70], [71], [72], [74]]

# %%
assoc_rules_mean = []
for i, itemset_row in enumerate(freq_itemsets_mean):
    if i == 0:
        continue
    for itemset in itemset_row:
        find_rules(mean_transactions, itemset, [], 0.9, assoc_rules_mean)
        
assoc_rules_mean.sort(key=lambda rule: rule[2], reverse=True)
# Out:
# Rule [1, 30] + [29] was added to rules with confidence: 1.0
# Rule [1, 29] + [30] was added to rules with confidence: 0.984146496545
# Rule [26, 3] + [29] was added to rules with confidence: 1.0
# Rule [26, 3] + [30] was added to rules with confidence: 0.999852521876
# Rule [3, 30] + [29] was added to rules with confidence: 1.0
# Rule [3, 29] + [30] was added to rules with confidence: 0.983593353817
# Rule [3, 71] + [29] was added to rules with confidence: 1.0
# Rule [72, 3] + [29] was added to rules with confidence: 1.0
# Rule [74, 3] + [29] was added to rules with confidence: 1.0
# Rule [3, 71] + [30] was added to rules with confidence: 0.986567164179
# Rule [72, 3] + [30] was added to rules with confidence: 1.0
# Rule [74, 3] + [30] was added to rules with confidence: 1.0
# Rule [8, 30] + [29] was added to rules with confidence: 1.0
# Rule [8, 29] + [30] was added to rules with confidence: 0.987053711419
# Rule [26, 30] + [29] was added to rules with confidence: 1.0
# Rule [26, 29] + [30] was added to rules with confidence: 0.999776752493
# Rule [72, 26] + [29] was added to rules with confidence: 1.0
# Rule [26, 74] + [29] was added to rules with confidence: 1.0
# Rule [72, 26] + [30] was added to rules with confidence: 1.0
# Rule [26, 74] + [30] was added to rules with confidence: 1.0
# Rule [30, 31] + [29] was added to rules with confidence: 1.0
# Rule [29, 31] + [30] was added to rules with confidence: 0.98448692595
# Rule [32, 30] + [29] was added to rules with confidence: 1.0
# Rule [32, 29] + [30] was added to rules with confidence: 0.983923079917
# Rule [60, 30] + [29] was added to rules with confidence: 1.0
# Rule [60, 29] + [30] was added to rules with confidence: 0.995388245388
# Rule [68, 30] + [29] was added to rules with confidence: 1.0
# Rule [68, 29] + [30] was added to rules with confidence: 0.997525151988
# Rule [70, 30] + [29] was added to rules with confidence: 1.0
# Rule [70, 29] + [30] was added to rules with confidence: 0.972160984363
# Rule [30, 71] + [29] was added to rules with confidence: 1.0
# Rule [29, 71] + [30] was added to rules with confidence: 0.986969708316
# Rule [72, 30] + [29] was added to rules with confidence: 1.0
# Rule [72, 29] + [30] was added to rules with confidence: 1.0
# Rule [74, 30] + [29] was added to rules with confidence: 1.0
# Rule [74, 29] + [30] was added to rules with confidence: 1.0
# Rule [29, 70] + [30] was added to rules with confidence: 0.972160984363
# Rule [30, 70] + [29] was added to rules with confidence: 1.0
# Rule [72, 74] + [29] was added to rules with confidence: 1.0
# Rule [74, 26] + [29] was added to rules with confidence: 1.0
# Rule [72, 74] + [30] was added to rules with confidence: 1.0
# Rule [74, 26] + [30] was added to rules with confidence: 1.0
# Rule [26, 3, 30] + [29] was added to rules with confidence: 1.0
# Rule [26, 3] + [29, 30] was added to rules with confidence: 0.999852521876
# Rule [26, 3, 29] + [30] was added to rules with confidence: 0.999852521876
# Rule [3, 30, 71] + [29] was added to rules with confidence: 1.0
# Rule [3, 71] + [29, 30] was added to rules with confidence: 0.986567164179
# Rule [3, 29, 71] + [30] was added to rules with confidence: 0.986567164179
# Rule [72, 3, 30] + [29] was added to rules with confidence: 1.0
# Rule [72, 3] + [29, 30] was added to rules with confidence: 1.0
# Rule [72, 3, 29] + [30] was added to rules with confidence: 1.0
# Rule [74, 3, 30] + [29] was added to rules with confidence: 1.0
# Rule [74, 3] + [29, 30] was added to rules with confidence: 1.0
# Rule [74, 3, 29] + [30] was added to rules with confidence: 1.0
# Rule [72, 26, 30] + [29] was added to rules with confidence: 1.0
# Rule [72, 26] + [29, 30] was added to rules with confidence: 1.0
# Rule [72, 26, 29] + [30] was added to rules with confidence: 1.0
# Rule [26, 74, 30] + [29] was added to rules with confidence: 1.0
# Rule [26, 74] + [29, 30] was added to rules with confidence: 1.0
# Rule [26, 74, 29] + [30] was added to rules with confidence: 1.0
# Rule [72, 74, 30] + [29] was added to rules with confidence: 1.0
# Rule [72, 74] + [29, 30] was added to rules with confidence: 1.0
# Rule [72, 74, 29] + [30] was added to rules with confidence: 1.0
# Rule [74, 26, 30] + [29] was added to rules with confidence: 1.0
# Rule [74, 26] + [29, 30] was added to rules with confidence: 1.0
# Rule [74, 26, 29] + [30] was added to rules with confidence: 1.0

# %%
find_correlations(mean_transactions, 26, 30)
find_correlations(transactions, 3, 29)
# Out:
# 74 and 30 features:
# PearsonrResult (0.14641137695648337, 8.9349794139680286e-217)
# SpearmanrResult(correlation=0.14641137695648349, pvalue=8.9349794139207586e-217)
# KendalltauResult(correlation=0.1464113769564839, pvalue=0.0)
#
# 74 and 30 features:
# PearsonrResult (0.20752929951166862, 0.0)
# SpearmanrResult(correlation=0.085199662737841519, pvalue=3.4580811141929028e-74)
# KendalltauResult(correlation=0.058169646783117417, pvalue=1.9321667614068488e-77)

# %% [markdown]
# Есть ассоциативные правила, которые были приняты со 100 процентной вероятностью, то есть для всех пользователей из выборки верно, что если признаки из itemset1 есть у пользователя, то и признаки из itemset2 у него есть. Посмотрим, у каких именно пользователей присутствуют признаки из таких уверенных ассоциативных правил и сравним эти группы между собой.
# Ищем долю сессий, в которых встречаются совместно признаки из x и y для правила вида x => y:

# %%
def find_users(transactions, itemset, y):
    users = []
    for user, transaction in enumerate(transactions):
        if all(transaction[itemset] != 0) and all(transaction[y] != 0):
            users.append(user)
            
    return users

def give_users(transactions, itemset, y):
    users = []
    users_y = []
    for user, transaction in enumerate(transactions):
        if all(transaction[itemset] != 0) and all(transaction[y] != 0):
            users.append(user)
        if all(transaction[itemset] != 0):
            users_y.append(user)

    return len(users)

def analyse(trans,a,b):
    users = find_users(trans, a, b)
    print len(users) * 1.0 / len(trans)
    print 'Support{0}: {1}'.format(a, support(trans, a))
    print 'Support{0}: {1}'.format(b, support(trans, b))
    print 'Confidence{0}->{1}: {2}'.format(a, b, confidence(trans, a, b))
    print 'Confidence{0}->{1}: {2}'.format(b, a, confidence(trans, b, a))
    print 'Lift{0}->{1}: {2}'.format(a, b, lift(trans, a, b))
    print 'Lift{0}->{1}: {2}'.format(b, a, lift(trans, b, a))
    return users

# %%
users1 = analyse(mean_transactions, [74, 26, 29], [30])
print
users2 = analyse(mean_transactions, [72,3],[29])
print 
a = np.zeros(trans_len)
b = np.zeros(trans_len)
a[users1] = 1.0
b[users2] = 1.0
print 'Euclidean distance: ', euclidean_distances(a,b)
print len([i for i, j in zip(a, b) if i == j]) * 1.0 / trans_len
# Out:
# 0.440344025626
# Support[74, 26, 29]: 0.440344025626
# Support[30]: 0.984312606959
# Confidence[74, 26, 29]->[30]: 1.0
# Confidence[30]->[74, 26, 29]: 0.44736196866
# Lift[74, 26, 29]->[30]: 1.01593740945
# Lift[30]->[74, 26, 29]: 1.01593740945
#
# 0.433388915705
# Support[72, 3]: 0.433388915705
# Support[29]: 0.999868357541
# Confidence[72, 3]->[29]: 1.0
# Confidence[29]->[72, 3]: 0.433445975599
# Lift[72, 3]->[29]: 1.00013165979
# Lift[29]->[72, 3]: 1.00013165979
#
# Euclidean distance:  [[ 114.15340556]]
# 0.714094519286

# %%
freq_itemsets_median = apriori(median_transactions, 0.3)
assoc_rules_median = []
for i, itemset_row in enumerate(freq_itemsets_median):
    if i == 0:
        continue
    for itemset in itemset_row:
        find_rules(median_transactions, itemset, [], 0.9, assoc_rules_median)
        
assoc_rules_median.sort(key=lambda rule: rule[2], reverse=True)
# Out:
# [[0], [1], [2], [5], [8], [9], [11], [12], [13], [14], [15], [18], [19], [22], [25], [26], [27], [29], [30], [31], [32], [34], [35], [39], [41], [42], [44], [46], [49], [50], [54], [59], [60], [68], [70], [72], [73], [74], [76]]
# Rule [0, 11] + [35] was added to rules with confidence: 0.911111111111
# Rule [0, 35] + [11] was added to rules with confidence: 1.0
# Rule [0, 14] + [18] was added to rules with confidence: 0.984774066798
# Rule [0, 14] + [39] was added to rules with confidence: 0.951620825147
# Rule [0, 14] + [41] was added to rules with confidence: 0.920984774067
# Rule [0, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 18] + [39] was added to rules with confidence: 0.937845753336
# Rule [0, 18] + [41] was added to rules with confidence: 0.913222692266
# Rule [0, 41] + [18] was added to rules with confidence: 0.939987718417
# Rule [35, 39] + [0] was added to rules with confidence: 0.901959512069
# Rule [0, 39] + [41] was added to rules with confidence: 0.922565348138
# Rule [1, 9] + [2] was added to rules with confidence: 1.0
# Rule [1, 2] + [9] was added to rules with confidence: 1.0
# Rule [1, 49] + [2] was added to rules with confidence: 0.969984407484
# Rule [1, 2] + [49] was added to rules with confidence: 0.961922556536
# Rule [1, 9] + [49] was added to rules with confidence: 0.961922556536
# Rule [1, 49] + [9] was added to rules with confidence: 0.969984407484
# Rule [1, 22] + [19] was added to rules with confidence: 0.982286096257
# Rule [1, 19] + [22] was added to rules with confidence: 1.0
# Rule [2, 5] + [9] was added to rules with confidence: 1.0
# Rule [9, 5] + [2] was added to rules with confidence: 1.0
# Rule [2, 5] + [49] was added to rules with confidence: 0.946446138711
# Rule [2, 1] + [9] was added to rules with confidence: 1.0
# Rule [9, 1] + [2] was added to rules with confidence: 1.0
# Rule [2, 19] + [9] was added to rules with confidence: 1.0
# Rule [9, 19] + [2] was added to rules with confidence: 1.0
# Rule [2, 22] + [9] was added to rules with confidence: 1.0
# Rule [9, 22] + [2] was added to rules with confidence: 1.0
# Rule [2, 34] + [9] was added to rules with confidence: 1.0
# Rule [9, 34] + [2] was added to rules with confidence: 1.0
# Rule [2, 49] + [9] was added to rules with confidence: 1.0
# Rule [9, 49] + [2] was added to rules with confidence: 1.0
# Rule [2, 70] + [9] was added to rules with confidence: 1.0
# Rule [9, 70] + [2] was added to rules with confidence: 1.0
# Rule [2, 22] + [19] was added to rules with confidence: 0.982227411299
# Rule [2, 19] + [22] was added to rules with confidence: 1.0
# Rule [2, 19] + [49] was added to rules with confidence: 0.949481608664
# Rule [49, 19] + [2] was added to rules with confidence: 0.920958237253
# Rule [2, 22] + [49] was added to rules with confidence: 0.945320101187
# Rule [49, 22] + [2] was added to rules with confidence: 0.921238938053
# Rule [2, 34] + [49] was added to rules with confidence: 0.947936804213
# Rule [49, 34] + [2] was added to rules with confidence: 0.919555095706
# Rule [2, 1] + [49] was added to rules with confidence: 0.961922556536
# Rule [49, 1] + [2] was added to rules with confidence: 0.969984407484
# Rule [49, 9] + [2] was added to rules with confidence: 1.0
# Rule [49, 2] + [9] was added to rules with confidence: 1.0
# Rule [9, 5] + [49] was added to rules with confidence: 0.946446138711
# Rule [5, 22] + [19] was added to rules with confidence: 0.973235195718
# Rule [19, 5] + [22] was added to rules with confidence: 1.0
# Rule [5, 9] + [49] was added to rules with confidence: 0.946446138711
# Rule [59, 60] + [8] was added to rules with confidence: 0.905661302983
# Rule [8, 60] + [59] was added to rules with confidence: 0.918366331708
# Rule [8, 59] + [60] was added to rules with confidence: 0.965937630808
# Rule [49, 1] + [9] was added to rules with confidence: 0.969984407484
# Rule [9, 1] + [49] was added to rules with confidence: 0.961922556536
# Rule [9, 22] + [19] was added to rules with confidence: 0.982227411299
# Rule [9, 19] + [22] was added to rules with confidence: 1.0
# Rule [19, 49] + [9] was added to rules with confidence: 0.920958237253
# Rule [9, 19] + [49] was added to rules with confidence: 0.949481608664
# Rule [22, 49] + [9] was added to rules with confidence: 0.921238938053
# Rule [9, 22] + [49] was added to rules with confidence: 0.945320101187
# Rule [34, 2] + [9] was added to rules with confidence: 1.0
# Rule [34, 49] + [9] was added to rules with confidence: 0.919555095706
# Rule [9, 34] + [49] was added to rules with confidence: 0.947936804213
# Rule [11, 14] + [18] was added to rules with confidence: 0.930553090802
# Rule [11, 14] + [35] was added to rules with confidence: 0.92380952381
# Rule [35, 14] + [11] was added to rules with confidence: 1.0
# Rule [11, 39] + [14] was added to rules with confidence: 0.914105263158
# Rule [18, 11] + [35] was added to rules with confidence: 0.918098282062
# Rule [35, 18] + [11] was added to rules with confidence: 1.0
# Rule [11, 39] + [18] was added to rules with confidence: 1.0
# Rule [18, 11] + [39] was added to rules with confidence: 0.94886136636
# Rule [18, 11] + [41] was added to rules with confidence: 0.906626334113
# Rule [41, 11] + [18] was added to rules with confidence: 0.925267940354
# Rule [11, 0] + [35] was added to rules with confidence: 0.911111111111
# Rule [18, 35] + [11] was added to rules with confidence: 1.0
# Rule [11, 18] + [35] was added to rules with confidence: 0.918098282062
# Rule [35, 39] + [11] was added to rules with confidence: 1.0
# Rule [11, 39] + [35] was added to rules with confidence: 0.927037593985
# Rule [41, 35] + [11] was added to rules with confidence: 1.0
# Rule [11, 41] + [35] was added to rules with confidence: 0.913734855545
# Rule [72, 35] + [11] was added to rules with confidence: 1.0
# Rule [11, 39] + [41] was added to rules with confidence: 0.914827067669
# Rule [41, 11] + [35] was added to rules with confidence: 0.913734855545
# Rule [18, 15] + [14] was added to rules with confidence: 0.961931856669
# Rule [25, 14] + [15] was added to rules with confidence: 0.915125995131
# Rule [14, 15] + [42] was added to rules with confidence: 0.997369080431
# Rule [42, 14] + [15] was added to rules with confidence: 0.973524915928
# Rule [14, 15] + [46] was added to rules with confidence: 0.945878226009
# Rule [14, 15] + [68] was added to rules with confidence: 0.964983713355
# Rule [68, 14] + [15] was added to rules with confidence: 0.986298738716
# Rule [34, 14] + [18] was added to rules with confidence: 0.950638792102
# Rule [35, 14] + [18] was added to rules with confidence: 0.940257411795
# Rule [18, 35] + [14] was added to rules with confidence: 0.912843466368
# Rule [14, 39] + [18] was added to rules with confidence: 1.0
# Rule [18, 39] + [14] was added to rules with confidence: 0.900117970901
# Rule [18, 14] + [39] was added to rules with confidence: 0.945086705202
# Rule [18, 14] + [41] was added to rules with confidence: 0.919488026424
# Rule [41, 14] + [18] was added to rules with confidence: 0.96810302668
# Rule [18, 42] + [14] was added to rules with confidence: 0.955861070912
# Rule [18, 46] + [14] was added to rules with confidence: 0.958565636087
# Rule [18, 68] + [14] was added to rules with confidence: 0.963705759889
# Rule [25, 14] + [42] was added to rules with confidence: 0.932758734127
# Rule [25, 14] + [46] was added to rules with confidence: 0.906375419435
# Rule [34, 39] + [14] was added to rules with confidence: 0.921911726299
# Rule [34, 14] + [39] was added to rules with confidence: 0.911085301329
# Rule [34, 14] + [41] was added to rules with confidence: 0.902761646664
# Rule [35, 39] + [14] was added to rules with confidence: 0.926031663639
# Rule [35, 14] + [39] was added to rules with confidence: 0.913875904463
# Rule [14, 39] + [41] was added to rules with confidence: 0.926496286588
# Rule [41, 39] + [14] was added to rules with confidence: 0.909022717531
# Rule [41, 14] + [39] was added to rules with confidence: 0.921914905179
# Rule [42, 39] + [14] was added to rules with confidence: 0.969718260381
# Rule [46, 39] + [14] was added to rules with confidence: 0.971281843368
# Rule [41, 42] + [14] was added to rules with confidence: 0.945675286371
# Rule [41, 46] + [14] was added to rules with confidence: 0.943775100402
# Rule [42, 18] + [14] was added to rules with confidence: 0.955861070912
# Rule [42, 14] + [46] was added to rules with confidence: 0.93683888719
# Rule [68, 14] + [42] was added to rules with confidence: 0.986874959985
# Rule [42, 14] + [68] was added to rules with confidence: 0.942464078264
# Rule [68, 14] + [46] was added to rules with confidence: 0.943914463154
# Rule [60, 14] + [59] was added to rules with confidence: 0.94545830177
# Rule [59, 14] + [60] was added to rules with confidence: 0.966830985915
# Rule [39, 15] + [18] was added to rules with confidence: 1.0
# Rule [18, 15] + [39] was added to rules with confidence: 0.937749779855
# Rule [18, 15] + [42] was added to rules with confidence: 0.997019575967
# Rule [18, 42] + [15] was added to rules with confidence: 0.968227864755
# Rule [18, 15] + [46] was added to rules with confidence: 0.938765833503
# Rule [18, 15] + [68] was added to rules with confidence: 0.964370385423
# Rule [18, 68] + [15] was added to rules with confidence: 0.9879944483
# Rule [25, 15] + [42] was added to rules with confidence: 0.999008059516
# Rule [25, 42] + [15] was added to rules with confidence: 0.960653392155
# Rule [25, 15] + [46] was added to rules with confidence: 0.938189708617
# Rule [25, 46] + [15] was added to rules with confidence: 0.941516829466
# Rule [25, 15] + [68] was added to rules with confidence: 0.963608183509
# Rule [25, 68] + [15] was added to rules with confidence: 0.995070422535
# Rule [15, 39] + [18] was added to rules with confidence: 1.0
# Rule [15, 39] + [42] was added to rules with confidence: 0.997182895117
# Rule [42, 39] + [15] was added to rules with confidence: 0.969929038151
# Rule [41, 15] + [42] was added to rules with confidence: 0.996776002243
# Rule [41, 42] + [15] was added to rules with confidence: 0.975512723781
# Rule [41, 15] + [68] was added to rules with confidence: 0.972876366695
# Rule [41, 68] + [15] was added to rules with confidence: 0.987339071058
# Rule [42, 18] + [15] was added to rules with confidence: 0.968227864755
# Rule [39, 15] + [42] was added to rules with confidence: 0.997182895117
# Rule [46, 15] + [42] was added to rules with confidence: 0.99831138129
# Rule [42, 15] + [46] was added to rules with confidence: 0.930144745123
# Rule [42, 46] + [15] was added to rules with confidence: 0.968439445233
# Rule [49, 15] + [42] was added to rules with confidence: 0.99567068331
# Rule [49, 42] + [15] was added to rules with confidence: 0.961669802774
# Rule [68, 15] + [42] was added to rules with confidence: 0.998630362132
# Rule [42, 15] + [68] was added to rules with confidence: 0.955947136564
# Rule [42, 68] + [15] was added to rules with confidence: 0.997591943958
# Rule [46, 15] + [68] was added to rules with confidence: 0.962006079027
# Rule [68, 15] + [46] was added to rules with confidence: 0.936339231907
# Rule [68, 46] + [15] was added to rules with confidence: 0.990667748667
# Rule [34, 39] + [18] was added to rules with confidence: 1.0
# Rule [18, 34] + [39] was added to rules with confidence: 0.933447098976
# Rule [18, 34] + [41] was added to rules with confidence: 0.922111165285
# Rule [41, 34] + [18] was added to rules with confidence: 0.946216385241
# Rule [35, 39] + [18] was added to rules with confidence: 1.0
# Rule [18, 35] + [39] was added to rules with confidence: 0.958100211364
# Rule [18, 35] + [41] was added to rules with confidence: 0.909548675867
# Rule [41, 35] + [18] was added to rules with confidence: 0.932683113406
# Rule [18, 39] + [41] was added to rules with confidence: 0.917420369642
# Rule [41, 39] + [18] was added to rules with confidence: 1.0
# Rule [41, 18] + [39] was added to rules with confidence: 0.928049326239
# Rule [42, 39] + [18] was added to rules with confidence: 1.0
# Rule [18, 42] + [39] was added to rules with confidence: 0.936258387054
# Rule [46, 39] + [18] was added to rules with confidence: 1.0
# Rule [18, 46] + [39] was added to rules with confidence: 0.937595032945
# Rule [18, 42] + [41] was added to rules with confidence: 0.91612945665
# Rule [41, 42] + [18] was added to rules with confidence: 0.95527813979
# Rule [18, 46] + [41] was added to rules with confidence: 0.915547389762
# Rule [41, 46] + [18] was added to rules with confidence: 0.951412206202
# Rule [18, 42] + [46] was added to rules with confidence: 0.927377976582
# Rule [18, 42] + [68] was added to rules with confidence: 0.937113537692
# Rule [18, 68] + [42] was added to rules with confidence: 0.988619014573
# Rule [34, 22] + [19] was added to rules with confidence: 0.97543049139
# Rule [34, 19] + [22] was added to rules with confidence: 1.0
# Rule [49, 22] + [19] was added to rules with confidence: 0.986852085967
# Rule [49, 19] + [22] was added to rules with confidence: 1.0
# Rule [59, 22] + [19] was added to rules with confidence: 0.968427284089
# Rule [59, 19] + [22] was added to rules with confidence: 1.0
# Rule [60, 22] + [19] was added to rules with confidence: 0.97179535825
# Rule [19, 60] + [22] was added to rules with confidence: 1.0
# Rule [70, 22] + [19] was added to rules with confidence: 0.979684908789
# Rule [19, 70] + [22] was added to rules with confidence: 1.0
# Rule [19, 9] + [49] was added to rules with confidence: 0.949481608664
# Rule [49, 19] + [9] was added to rules with confidence: 0.920958237253
# Rule [19, 59] + [22] was added to rules with confidence: 1.0
# Rule [19, 60] + [59] was added to rules with confidence: 0.924383419015
# Rule [19, 59] + [60] was added to rules with confidence: 0.964816953067
# Rule [59, 19] + [60] was added to rules with confidence: 0.964816953067
# Rule [22, 70] + [19] was added to rules with confidence: 0.979684908789
# Rule [22, 9] + [49] was added to rules with confidence: 0.945320101187
# Rule [49, 22] + [9] was added to rules with confidence: 0.921238938053
# Rule [60, 22] + [59] was added to rules with confidence: 0.925441092772
# Rule [59, 22] + [60] was added to rules with confidence: 0.962573176347
# Rule [25, 46] + [42] was added to rules with confidence: 0.966776581845
# Rule [25, 42] + [46] was added to rules with confidence: 0.926374150471
# Rule [25, 68] + [42] was added to rules with confidence: 0.996542893726
# Rule [25, 42] + [68] was added to rules with confidence: 0.927983784428
# Rule [25, 46] + [68] was added to rules with confidence: 0.916070428669
# Rule [25, 68] + [46] was added to rules with confidence: 0.942637644046
# Rule [30, 31] + [29] was added to rules with confidence: 0.9911747851
# Rule [29, 31] + [30] was added to rules with confidence: 0.977561747584
# Rule [34, 2] + [49] was added to rules with confidence: 0.947936804213
# Rule [34, 18] + [39] was added to rules with confidence: 0.933447098976
# Rule [34, 18] + [41] was added to rules with confidence: 0.922111165285
# Rule [34, 39] + [41] was added to rules with confidence: 0.930007834944
# Rule [34, 9] + [49] was added to rules with confidence: 0.947936804213
# Rule [49, 34] + [9] was added to rules with confidence: 0.919555095706
# Rule [35, 41] + [11] was added to rules with confidence: 1.0
# Rule [35, 39] + [41] was added to rules with confidence: 0.91662341033
# Rule [41, 35] + [39] was added to rules with confidence: 0.90055459935
# Rule [46, 39] + [41] was added to rules with confidence: 0.924184066491
# Rule [41, 46] + [39] was added to rules with confidence: 0.900454276121
# Rule [42, 18] + [39] was added to rules with confidence: 0.936258387054
# Rule [42, 18] + [41] was added to rules with confidence: 0.91612945665
# Rule [41, 68] + [42] was added to rules with confidence: 0.987694715129
# Rule [41, 42] + [68] was added to rules with confidence: 0.952465875574
# Rule [42, 18] + [46] was added to rules with confidence: 0.927377976582
# Rule [68, 18] + [42] was added to rules with confidence: 0.988619014573
# Rule [42, 18] + [68] was added to rules with confidence: 0.937113537692
# Rule [68, 46] + [42] was added to rules with confidence: 0.991479248783
# Rule [42, 46] + [68] was added to rules with confidence: 0.933984929562
# Rule [42, 68] + [46] was added to rules with confidence: 0.93613178634
# Rule [60, 46] + [59] was added to rules with confidence: 0.957924950994
# Rule [59, 46] + [60] was added to rules with confidence: 0.974989311672
# Rule [0, 11, 14] + [18] was added to rules with confidence: 0.990931810068
# Rule [0, 18, 11] + [35] was added to rules with confidence: 0.923468401726
# Rule [0, 35, 18] + [11] was added to rules with confidence: 1.0
# Rule [0, 11, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 18, 11] + [39] was added to rules with confidence: 0.962893770534
# Rule [0, 18, 11] + [41] was added to rules with confidence: 0.914449526509
# Rule [0, 41, 11] + [18] was added to rules with confidence: 0.953388407549
# Rule [0, 18, 35] + [11] was added to rules with confidence: 1.0
# Rule [0, 11, 18] + [35] was added to rules with confidence: 0.923468401726
# Rule [11, 35, 39] + [0] was added to rules with confidence: 0.901959512069
# Rule [35, 39] + [0, 11] was added to rules with confidence: 0.901959512069
# Rule [0, 35, 39] + [11] was added to rules with confidence: 1.0
# Rule [0, 11, 39] + [35] was added to rules with confidence: 0.930019401887
# Rule [0, 35, 41] + [11] was added to rules with confidence: 1.0
# Rule [0, 11, 41] + [35] was added to rules with confidence: 0.920814023776
# Rule [35, 11, 39] + [0] was added to rules with confidence: 0.901959512069
# Rule [41, 11, 39] + [0] was added to rules with confidence: 0.905121967256
# Rule [0, 11, 39] + [41] was added to rules with confidence: 0.920987489128
# Rule [0, 41, 11] + [39] was added to rules with confidence: 0.924575189737
# Rule [0, 41, 35] + [11] was added to rules with confidence: 1.0
# Rule [0, 41, 11] + [35] was added to rules with confidence: 0.920814023776
# Rule [0, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 14] + [18, 39] was added to rules with confidence: 0.951620825147
# Rule [0, 18, 14] + [39] was added to rules with confidence: 0.966334164589
# Rule [0, 18, 14] + [41] was added to rules with confidence: 0.927680798005
# Rule [0, 14] + [41, 18] was added to rules with confidence: 0.913555992141
# Rule [0, 41, 14] + [18] was added to rules with confidence: 0.991933871075
# Rule [0, 14, 39] + [41] was added to rules with confidence: 0.932064516129
# Rule [0, 41, 39] + [14] was added to rules with confidence: 0.905597693224
# Rule [0, 41, 14] + [39] was added to rules with confidence: 0.963069128725
# Rule [18, 35, 39] + [0] was added to rules with confidence: 0.901959512069
# Rule [35, 39] + [0, 18] was added to rules with confidence: 0.901959512069
# Rule [0, 35, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 18, 35] + [39] was added to rules with confidence: 0.969724450645
# Rule [0, 18, 39] + [41] was added to rules with confidence: 0.922565348138
# Rule [0, 39] + [41, 18] was added to rules with confidence: 0.922565348138
# Rule [0, 41, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 41, 18] + [39] was added to rules with confidence: 0.947440313576
# Rule [1, 49, 9] + [2] was added to rules with confidence: 1.0
# Rule [1, 9] + [49, 2] was added to rules with confidence: 0.961922556536
# Rule [1, 49] + [9, 2] was added to rules with confidence: 0.969984407484
# Rule [1, 2, 9] + [49] was added to rules with confidence: 0.961922556536
# Rule [1, 2] + [49, 9] was added to rules with confidence: 0.961922556536
# Rule [1, 2, 49] + [9] was added to rules with confidence: 1.0
# Rule [1, 2] + [9, 49] was added to rules with confidence: 0.961922556536
# Rule [1, 9, 49] + [2] was added to rules with confidence: 1.0
# Rule [2, 5, 49] + [9] was added to rules with confidence: 1.0
# Rule [2, 5] + [9, 49] was added to rules with confidence: 0.946446138711
# Rule [9, 5, 49] + [2] was added to rules with confidence: 1.0
# Rule [9, 5] + [49, 2] was added to rules with confidence: 0.946446138711
# Rule [9, 2, 5] + [49] was added to rules with confidence: 0.946446138711
# Rule [2, 5] + [49, 9] was added to rules with confidence: 0.946446138711
# Rule [2, 5, 9] + [49] was added to rules with confidence: 0.946446138711
# Rule [5, 9] + [49, 2] was added to rules with confidence: 0.946446138711
# Rule [49, 5, 9] + [2] was added to rules with confidence: 1.0
# Rule [49, 2, 5] + [9] was added to rules with confidence: 1.0
# Rule [2, 49, 1] + [9] was added to rules with confidence: 1.0
# Rule [49, 1] + [9, 2] was added to rules with confidence: 0.969984407484
# Rule [2, 1] + [9, 49] was added to rules with confidence: 0.961922556536
# Rule [9, 49, 1] + [2] was added to rules with confidence: 1.0
# Rule [9, 1] + [49, 2] was added to rules with confidence: 0.961922556536
# Rule [9, 2, 1] + [49] was added to rules with confidence: 0.961922556536
# Rule [2, 1] + [49, 9] was added to rules with confidence: 0.961922556536
# Rule [2, 19, 22] + [9] was added to rules with confidence: 1.0
# Rule [2, 22] + [9, 19] was added to rules with confidence: 0.982227411299
# Rule [2, 19] + [9, 22] was added to rules with confidence: 1.0
# Rule [9, 19, 22] + [2] was added to rules with confidence: 1.0
# Rule [9, 22] + [2, 19] was added to rules with confidence: 0.982227411299
# Rule [9, 19] + [2, 22] was added to rules with confidence: 1.0
# Rule [9, 2, 22] + [19] was added to rules with confidence: 0.982227411299
# Rule [9, 2, 19] + [22] was added to rules with confidence: 1.0
# Rule [2, 19, 49] + [9] was added to rules with confidence: 1.0
# Rule [19, 49] + [9, 2] was added to rules with confidence: 0.920958237253
# Rule [2, 19] + [9, 49] was added to rules with confidence: 0.949481608664
# Rule [9, 19, 49] + [2] was added to rules with confidence: 1.0
# Rule [9, 19] + [49, 2] was added to rules with confidence: 0.949481608664
# Rule [9, 2, 19] + [49] was added to rules with confidence: 0.949481608664
# Rule [2, 19] + [49, 9] was added to rules with confidence: 0.949481608664
# Rule [2, 22, 49] + [9] was added to rules with confidence: 1.0
# Rule [22, 49] + [9, 2] was added to rules with confidence: 0.921238938053
# Rule [2, 22] + [9, 49] was added to rules with confidence: 0.945320101187
# Rule [9, 22, 49] + [2] was added to rules with confidence: 1.0
# Rule [9, 22] + [49, 2] was added to rules with confidence: 0.945320101187
# Rule [9, 2, 22] + [49] was added to rules with confidence: 0.945320101187
# Rule [2, 22] + [49, 9] was added to rules with confidence: 0.945320101187
# Rule [2, 34, 49] + [9] was added to rules with confidence: 1.0
# Rule [34, 49] + [9, 2] was added to rules with confidence: 0.919555095706
# Rule [2, 34] + [9, 49] was added to rules with confidence: 0.947936804213
# Rule [9, 34, 49] + [2] was added to rules with confidence: 1.0
# Rule [9, 34] + [49, 2] was added to rules with confidence: 0.947936804213
# Rule [9, 2, 34] + [49] was added to rules with confidence: 0.947936804213
# Rule [2, 34] + [49, 9] was added to rules with confidence: 0.947936804213
# Rule [2, 1, 49] + [9] was added to rules with confidence: 1.0
# Rule [9, 1, 49] + [2] was added to rules with confidence: 1.0
# Rule [2, 19, 22] + [49] was added to rules with confidence: 0.949481608664
# Rule [2, 22] + [49, 19] was added to rules with confidence: 0.932606862554
# Rule [2, 19] + [49, 22] was added to rules with confidence: 0.949481608664
# Rule [49, 19, 22] + [2] was added to rules with confidence: 0.920958237253
# Rule [49, 22] + [2, 19] was added to rules with confidence: 0.908849557522
# Rule [49, 19] + [2, 22] was added to rules with confidence: 0.920958237253
# Rule [49, 2, 22] + [19] was added to rules with confidence: 0.986551392891
# Rule [49, 2, 19] + [22] was added to rules with confidence: 1.0
# Rule [2, 19, 9] + [49] was added to rules with confidence: 0.949481608664
# Rule [19, 9] + [49, 2] was added to rules with confidence: 0.949481608664
# Rule [49, 19, 9] + [2] was added to rules with confidence: 1.0
# Rule [49, 19] + [9, 2] was added to rules with confidence: 0.920958237253
# Rule [49, 2, 19] + [9] was added to rules with confidence: 1.0
# Rule [2, 22, 9] + [49] was added to rules with confidence: 0.945320101187
# Rule [22, 9] + [49, 2] was added to rules with confidence: 0.945320101187
# Rule [49, 22, 9] + [2] was added to rules with confidence: 1.0
# Rule [49, 22] + [9, 2] was added to rules with confidence: 0.921238938053
# Rule [49, 2, 22] + [9] was added to rules with confidence: 1.0
# Rule [2, 34, 9] + [49] was added to rules with confidence: 0.947936804213
# Rule [34, 9] + [49, 2] was added to rules with confidence: 0.947936804213
# Rule [49, 34, 9] + [2] was added to rules with confidence: 1.0
# Rule [49, 34] + [9, 2] was added to rules with confidence: 0.919555095706
# Rule [49, 2, 34] + [9] was added to rules with confidence: 1.0
# Rule [2, 9, 1] + [49] was added to rules with confidence: 0.961922556536
# Rule [49, 9, 1] + [2] was added to rules with confidence: 1.0
# Rule [49, 2, 1] + [9] was added to rules with confidence: 1.0
# Rule [2, 1, 9] + [49] was added to rules with confidence: 0.961922556536
# Rule [49, 1, 9] + [2] was added to rules with confidence: 1.0
# Rule [19, 22, 49] + [9] was added to rules with confidence: 0.920958237253
# Rule [22, 49] + [9, 19] was added to rules with confidence: 0.908849557522
# Rule [19, 49] + [9, 22] was added to rules with confidence: 0.920958237253
# Rule [9, 22, 49] + [19] was added to rules with confidence: 0.986551392891
# Rule [9, 22] + [49, 19] was added to rules with confidence: 0.932606862554
# Rule [9, 19, 49] + [22] was added to rules with confidence: 1.0
# Rule [9, 19] + [49, 22] was added to rules with confidence: 0.949481608664
# Rule [9, 19, 22] + [49] was added to rules with confidence: 0.949481608664
# Rule [34, 2, 49] + [9] was added to rules with confidence: 1.0
# Rule [34, 2] + [9, 49] was added to rules with confidence: 0.947936804213
# Rule [9, 34, 2] + [49] was added to rules with confidence: 0.947936804213
# Rule [34, 2] + [49, 9] was added to rules with confidence: 0.947936804213
# Rule [18, 11, 14] + [35] was added to rules with confidence: 0.933443519166
# Rule [35, 11, 14] + [18] was added to rules with confidence: 0.940257411795
# Rule [35, 14] + [18, 11] was added to rules with confidence: 0.940257411795
# Rule [35, 18, 14] + [11] was added to rules with confidence: 1.0
# Rule [35, 18] + [11, 14] was added to rules with confidence: 0.912843466368
# Rule [35, 18, 11] + [14] was added to rules with confidence: 0.912843466368
# Rule [11, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [11, 39] + [18, 14] was added to rules with confidence: 0.914105263158
# Rule [18, 11, 39] + [14] was added to rules with confidence: 0.914105263158
# Rule [18, 11, 14] + [39] was added to rules with confidence: 0.966054287712
# Rule [18, 11, 14] + [41] was added to rules with confidence: 0.916089250524
# Rule [41, 11, 14] + [18] was added to rules with confidence: 0.972139773341
# Rule [41, 18, 11] + [14] was added to rules with confidence: 0.907208057916
# Rule [18, 35, 14] + [11] was added to rules with confidence: 1.0
# Rule [18, 35] + [11, 14] was added to rules with confidence: 0.912843466368
# Rule [11, 35, 14] + [18] was added to rules with confidence: 0.940257411795
# Rule [11, 18, 14] + [35] was added to rules with confidence: 0.933443519166
# Rule [11, 18, 35] + [14] was added to rules with confidence: 0.912843466368
# Rule [35, 14, 39] + [11] was added to rules with confidence: 1.0
# Rule [35, 39] + [11, 14] was added to rules with confidence: 0.926031663639
# Rule [35, 14] + [11, 39] was added to rules with confidence: 0.913875904463
# Rule [11, 14, 39] + [35] was added to rules with confidence: 0.939132723564
# Rule [11, 35, 39] + [14] was added to rules with confidence: 0.926031663639
# Rule [11, 35, 14] + [39] was added to rules with confidence: 0.913875904463
# Rule [41, 35, 14] + [11] was added to rules with confidence: 1.0
# Rule [11, 41, 14] + [35] was added to rules with confidence: 0.932137075013
# Rule [35, 11, 39] + [14] was added to rules with confidence: 0.926031663639
# Rule [35, 11, 14] + [39] was added to rules with confidence: 0.913875904463
# Rule [11, 14, 39] + [41] was added to rules with confidence: 0.921760873857
# Rule [41, 11, 39] + [14] was added to rules with confidence: 0.921033598527
# Rule [41, 11, 14] + [39] was added to rules with confidence: 0.94495412844
# Rule [41, 14, 35] + [11] was added to rules with confidence: 1.0
# Rule [41, 11, 14] + [35] was added to rules with confidence: 0.932137075013
# Rule [11, 0, 18] + [35] was added to rules with confidence: 0.923468401726
# Rule [18, 35, 39] + [11] was added to rules with confidence: 1.0
# Rule [35, 39] + [18, 11] was added to rules with confidence: 1.0
# Rule [18, 35] + [11, 39] was added to rules with confidence: 0.958100211364
# Rule [11, 35, 39] + [18] was added to rules with confidence: 1.0
# Rule [11, 39] + [18, 35] was added to rules with confidence: 0.927037593985
# Rule [11, 18, 39] + [35] was added to rules with confidence: 0.927037593985
# Rule [11, 18, 35] + [39] was added to rules with confidence: 0.958100211364
# Rule [41, 18, 35] + [11] was added to rules with confidence: 1.0
# Rule [18, 35] + [41, 11] was added to rules with confidence: 0.909548675867
# Rule [41, 35] + [18, 11] was added to rules with confidence: 0.932683113406
# Rule [11, 18, 35] + [41] was added to rules with confidence: 0.909548675867
# Rule [11, 41, 35] + [18] was added to rules with confidence: 0.932683113406
# Rule [11, 41, 18] + [35] was added to rules with confidence: 0.921057601511
# Rule [18, 11, 39] + [35] was added to rules with confidence: 0.927037593985
# Rule [35, 11, 39] + [18] was added to rules with confidence: 1.0
# Rule [35, 18, 39] + [11] was added to rules with confidence: 1.0
# Rule [35, 18] + [11, 39] was added to rules with confidence: 0.958100211364
# Rule [35, 18, 11] + [39] was added to rules with confidence: 0.958100211364
# Rule [18, 11, 39] + [41] was added to rules with confidence: 0.914827067669
# Rule [11, 39] + [41, 18] was added to rules with confidence: 0.914827067669
# Rule [41, 11, 39] + [18] was added to rules with confidence: 1.0
# Rule [41, 18, 11] + [39] was added to rules with confidence: 0.957444129682
# Rule [18, 11, 35] + [41] was added to rules with confidence: 0.909548675867
# Rule [41, 11, 35] + [18] was added to rules with confidence: 0.932683113406
# Rule [41, 18, 11] + [35] was added to rules with confidence: 0.921057601511
# Rule [11, 14, 41] + [35] was added to rules with confidence: 0.932137075013
# Rule [35, 14, 41] + [11] was added to rules with confidence: 1.0
# Rule [18, 11, 41] + [35] was added to rules with confidence: 0.921057601511
# Rule [35, 11, 41] + [18] was added to rules with confidence: 0.932683113406
# Rule [35, 41] + [18, 11] was added to rules with confidence: 0.932683113406
# Rule [35, 18, 41] + [11] was added to rules with confidence: 1.0
# Rule [35, 18] + [41, 11] was added to rules with confidence: 0.909548675867
# Rule [35, 18, 11] + [41] was added to rules with confidence: 0.909548675867
# Rule [11, 41, 39] + [35] was added to rules with confidence: 0.928857913078
# Rule [35, 41, 39] + [11] was added to rules with confidence: 1.0
# Rule [35, 39] + [41, 11] was added to rules with confidence: 0.91662341033
# Rule [35, 41] + [11, 39] was added to rules with confidence: 0.90055459935
# Rule [35, 11, 39] + [41] was added to rules with confidence: 0.91662341033
# Rule [35, 11, 41] + [39] was added to rules with confidence: 0.90055459935
# Rule [11, 35, 39] + [41] was added to rules with confidence: 0.91662341033
# Rule [41, 35, 39] + [11] was added to rules with confidence: 1.0
# Rule [41, 35] + [11, 39] was added to rules with confidence: 0.90055459935
# Rule [41, 11, 39] + [35] was added to rules with confidence: 0.928857913078
# Rule [41, 11, 35] + [39] was added to rules with confidence: 0.90055459935
# Rule [11, 0, 39] + [35] was added to rules with confidence: 0.930019401887
# Rule [11, 41, 35] + [39] was added to rules with confidence: 0.90055459935
# Rule [18, 14, 15] + [42] was added to rules with confidence: 0.99739454968
# Rule [18, 15] + [42, 14] was added to rules with confidence: 0.959425591005
# Rule [18, 42, 15] + [14] was added to rules with confidence: 0.962293634078
# Rule [18, 42] + [14, 15] was added to rules with confidence: 0.931719510591
# Rule [18, 42, 14] + [15] was added to rules with confidence: 0.974743651504
# Rule [18, 14, 15] + [68] was added to rules with confidence: 0.96697415675
# Rule [18, 15] + [68, 14] was added to rules with confidence: 0.930163245953
# Rule [18, 68, 15] + [14] was added to rules with confidence: 0.96452904404
# Rule [18, 68] + [14, 15] was added to rules with confidence: 0.952949340736
# Rule [18, 68, 14] + [15] was added to rules with confidence: 0.988838482034
# Rule [25, 14, 15] + [42] was added to rules with confidence: 0.999352936947
# Rule [25, 14] + [42, 15] was added to rules with confidence: 0.914533850911
# Rule [25, 42, 14] + [15] was added to rules with confidence: 0.980461310573
# Rule [42, 18, 15] + [14] was added to rules with confidence: 0.962293634078
# Rule [42, 18] + [14, 15] was added to rules with confidence: 0.931719510591
# Rule [42, 18, 14] + [15] was added to rules with confidence: 0.974743651504
# Rule [46, 14, 15] + [42] was added to rules with confidence: 0.998741721854
# Rule [14, 15] + [42, 46] was added to rules with confidence: 0.944688048108
# Rule [42, 14, 15] + [46] was added to rules with confidence: 0.947180002512
# Rule [42, 14] + [46, 15] was added to rules with confidence: 0.922103332314
# Rule [42, 46, 14] + [15] was added to rules with confidence: 0.9842709829
# Rule [68, 14, 15] + [42] was added to rules with confidence: 0.998831548199
# Rule [14, 15] + [42, 68] was added to rules with confidence: 0.963856176397
# Rule [68, 14] + [42, 15] was added to rules with confidence: 0.985146296178
# Rule [42, 14, 15] + [68] was added to rules with confidence: 0.966398693631
# Rule [42, 14] + [68, 15] was added to rules with confidence: 0.94081320697
# Rule [42, 68, 14] + [15] was added to rules with confidence: 0.99824834566
# Rule [14, 46, 15] + [42] was added to rules with confidence: 0.998741721854
# Rule [42, 14, 46] + [15] was added to rules with confidence: 0.9842709829
# Rule [14, 46, 15] + [68] was added to rules with confidence: 0.968741721854
# Rule [14, 15] + [68, 46] was added to rules with confidence: 0.916311701328
# Rule [68, 14, 15] + [46] was added to rules with confidence: 0.949561830574
# Rule [68, 14] + [46, 15] was added to rules with confidence: 0.936551635828
# Rule [68, 14, 46] + [15] was added to rules with confidence: 0.992199687988
# Rule [46, 14, 15] + [68] was added to rules with confidence: 0.968741721854
# Rule [68, 46, 14] + [15] was added to rules with confidence: 0.992199687988
# Rule [34, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [34, 39] + [18, 14] was added to rules with confidence: 0.921911726299
# Rule [34, 14] + [18, 39] was added to rules with confidence: 0.911085301329
# Rule [18, 34, 39] + [14] was added to rules with confidence: 0.921911726299
# Rule [18, 34, 14] + [39] was added to rules with confidence: 0.958392723817
# Rule [18, 34, 14] + [41] was added to rules with confidence: 0.934025656689
# Rule [41, 34, 14] + [18] was added to rules with confidence: 0.983560860553
# Rule [41, 18, 34] + [14] was added to rules with confidence: 0.909517514871
# Rule [35, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [35, 39] + [18, 14] was added to rules with confidence: 0.926031663639
# Rule [35, 14] + [18, 39] was added to rules with confidence: 0.913875904463
# Rule [18, 35, 39] + [14] was added to rules with confidence: 0.926031663639
# Rule [18, 35, 14] + [39] was added to rules with confidence: 0.971942250068
# Rule [18, 14, 39] + [41] was added to rules with confidence: 0.926496286588
# Rule [14, 39] + [41, 18] was added to rules with confidence: 0.926496286588
# Rule [41, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [41, 39] + [18, 14] was added to rules with confidence: 0.909022717531
# Rule [41, 14] + [18, 39] was added to rules with confidence: 0.921914905179
# Rule [41, 18, 39] + [14] was added to rules with confidence: 0.909022717531
# Rule [41, 18, 14] + [39] was added to rules with confidence: 0.952290076336
# Rule [42, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [42, 39] + [18, 14] was added to rules with confidence: 0.969718260381
# Rule [18, 42, 39] + [14] was added to rules with confidence: 0.969718260381
# Rule [18, 42] + [14, 39] was added to rules with confidence: 0.907906854361
# Rule [18, 42, 14] + [39] was added to rules with confidence: 0.949831394949
# Rule [46, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [46, 39] + [18, 14] was added to rules with confidence: 0.971281843368
# Rule [18, 46, 39] + [14] was added to rules with confidence: 0.971281843368
# Rule [18, 46] + [14, 39] was added to rules with confidence: 0.910669031931
# Rule [18, 46, 14] + [39] was added to rules with confidence: 0.950033046927
# Rule [18, 46, 14] + [41] was added to rules with confidence: 0.920621282221
# Rule [41, 46, 14] + [18] was added to rules with confidence: 0.971677711894
# Rule [41, 46] + [18, 14] was added to rules with confidence: 0.917045230101
# Rule [41, 18, 46] + [14] was added to rules with confidence: 0.963877932323
# Rule [18, 42, 14] + [68] was added to rules with confidence: 0.945564654876
# Rule [18, 42] + [68, 14] was added to rules with confidence: 0.903828443626
# Rule [18, 68, 14] + [42] was added to rules with confidence: 0.98941456038
# Rule [18, 68] + [42, 14] was added to rules with confidence: 0.953504510756
# Rule [18, 68, 42] + [14] was added to rules with confidence: 0.964481257897
# Rule [14, 46, 39] + [18] was added to rules with confidence: 1.0
# Rule [18, 14, 46] + [39] was added to rules with confidence: 0.950033046927
# Rule [18, 14, 46] + [41] was added to rules with confidence: 0.920621282221
# Rule [41, 14, 46] + [18] was added to rules with confidence: 0.971677711894
# Rule [34, 18, 39] + [14] was added to rules with confidence: 0.921911726299
# Rule [34, 18, 14] + [39] was added to rules with confidence: 0.958392723817
# Rule [34, 18, 14] + [41] was added to rules with confidence: 0.934025656689
# Rule [41, 34, 18] + [14] was added to rules with confidence: 0.909517514871
# Rule [42, 18, 39] + [14] was added to rules with confidence: 0.969718260381
# Rule [42, 18] + [14, 39] was added to rules with confidence: 0.907906854361
# Rule [42, 18, 14] + [39] was added to rules with confidence: 0.949831394949
# Rule [68, 18, 14] + [42] was added to rules with confidence: 0.98941456038
# Rule [68, 18] + [42, 14] was added to rules with confidence: 0.953504510756
# Rule [42, 18, 14] + [68] was added to rules with confidence: 0.945564654876
# Rule [42, 18] + [68, 14] was added to rules with confidence: 0.903828443626
# Rule [42, 68, 18] + [14] was added to rules with confidence: 0.964481257897
# Rule [68, 14, 46] + [42] was added to rules with confidence: 0.992877975989
# Rule [68, 14] + [42, 46] was added to rules with confidence: 0.937191881683
# Rule [42, 14, 46] + [68] was added to rules with confidence: 0.955358308315
# Rule [42, 68, 14] + [46] was added to rules with confidence: 0.949656156741
# Rule [68, 46, 14] + [42] was added to rules with confidence: 0.992877975989
# Rule [42, 46, 14] + [68] was added to rules with confidence: 0.955358308315
# Rule [15, 42, 39] + [18] was added to rules with confidence: 1.0
# Rule [42, 39] + [18, 15] was added to rules with confidence: 0.969929038151
# Rule [15, 39] + [18, 42] was added to rules with confidence: 0.997182895117
# Rule [18, 42, 39] + [15] was added to rules with confidence: 0.969929038151
# Rule [18, 42] + [39, 15] was added to rules with confidence: 0.908104196816
# Rule [18, 15, 39] + [42] was added to rules with confidence: 0.997182895117
# Rule [15, 39] + [42, 18] was added to rules with confidence: 0.997182895117
# Rule [18, 15] + [42, 39] was added to rules with confidence: 0.935108040371
# Rule [18, 15, 42] + [39] was added to rules with confidence: 0.937903390176
# Rule [18, 42] + [15, 39] was added to rules with confidence: 0.908104196816
# Rule [39, 42, 15] + [18] was added to rules with confidence: 1.0
# Rule [39, 15] + [18, 42] was added to rules with confidence: 0.997182895117
# Rule [39, 42] + [18, 15] was added to rules with confidence: 0.969929038151
# Rule [18, 42, 15] + [39] was added to rules with confidence: 0.937903390176
# Rule [18, 39, 15] + [42] was added to rules with confidence: 0.997182895117
# Rule [39, 15] + [42, 18] was added to rules with confidence: 0.997182895117
# Rule [18, 39, 42] + [15] was added to rules with confidence: 0.969929038151
# Rule [18, 46, 15] + [42] was added to rules with confidence: 0.998773360271
# Rule [18, 15] + [42, 46] was added to rules with confidence: 0.937614306035
# Rule [18, 42, 15] + [46] was added to rules with confidence: 0.940417147904
# Rule [18, 42] + [46, 15] was added to rules with confidence: 0.910538087094
# Rule [18, 42, 46] + [15] was added to rules with confidence: 0.981841395943
# Rule [18, 42, 15] + [68] was added to rules with confidence: 0.96609824037
# Rule [18, 15] + [42, 68] was added to rules with confidence: 0.963218857956
# Rule [18, 42] + [68, 15] was added to rules with confidence: 0.935403236416
# Rule [18, 68, 15] + [42] was added to rules with confidence: 0.998805928215
# Rule [18, 68] + [42, 15] was added to rules with confidence: 0.986814712006
# Rule [18, 68, 42] + [15] was added to rules with confidence: 0.998174926295
# Rule [25, 46, 15] + [42] was added to rules with confidence: 0.999735676997
# Rule [25, 15] + [42, 46] was added to rules with confidence: 0.937941723497
# Rule [25, 46] + [42, 15] was added to rules with confidence: 0.94126796491
# Rule [25, 42, 15] + [46] was added to rules with confidence: 0.938873029664
# Rule [25, 42] + [46, 15] was added to rules with confidence: 0.901931560749
# Rule [25, 42, 46] + [15] was added to rules with confidence: 0.973614775726
# Rule [25, 68, 15] + [42] was added to rules with confidence: 0.999613974136
# Rule [25, 15] + [42, 68] was added to rules with confidence: 0.963236205828
# Rule [25, 68] + [42, 15] was added to rules with confidence: 0.994686299616
# Rule [25, 42, 15] + [68] was added to rules with confidence: 0.964192627529
# Rule [25, 42] + [68, 15] was added to rules with confidence: 0.926254918326
# Rule [25, 42, 68] + [15] was added to rules with confidence: 0.998136965181
# Rule [25, 46, 15] + [68] was added to rules with confidence: 0.969867177691
# Rule [25, 15] + [68, 46] was added to rules with confidence: 0.909919404836
# Rule [25, 46] + [68, 15] was added to rules with confidence: 0.913146270142
# Rule [25, 68, 15] + [46] was added to rules with confidence: 0.944283600335
# Rule [25, 68] + [46, 15] was added to rules with confidence: 0.939628681178
# Rule [25, 68, 46] + [15] was added to rules with confidence: 0.996807932627
# Rule [39, 18, 15] + [42] was added to rules with confidence: 0.997182895117
# Rule [42, 18, 15] + [39] was added to rules with confidence: 0.937903390176
# Rule [42, 18] + [15, 39] was added to rules with confidence: 0.908104196816
# Rule [42, 39, 15] + [18] was added to rules with confidence: 1.0
# Rule [42, 39, 18] + [15] was added to rules with confidence: 0.969929038151
# Rule [42, 18] + [39, 15] was added to rules with confidence: 0.908104196816
# Rule [41, 68, 15] + [42] was added to rules with confidence: 0.998847345292
# Rule [41, 15] + [42, 68] was added to rules with confidence: 0.97175497617
# Rule [41, 68] + [42, 15] was added to rules with confidence: 0.986201010029
# Rule [41, 42, 15] + [68] was added to rules with confidence: 0.974898045282
# Rule [41, 42] + [68, 15] was added to rules with confidence: 0.951025447562
# Rule [41, 42, 68] + [15] was added to rules with confidence: 0.998487685439
# Rule [42, 18, 15] + [46] was added to rules with confidence: 0.940417147904
# Rule [42, 18] + [46, 15] was added to rules with confidence: 0.910538087094
# Rule [42, 18, 46] + [15] was added to rules with confidence: 0.981841395943
# Rule [68, 18, 15] + [42] was added to rules with confidence: 0.998805928215
# Rule [68, 18] + [42, 15] was added to rules with confidence: 0.986814712006
# Rule [42, 18, 15] + [68] was added to rules with confidence: 0.96609824037
# Rule [42, 18] + [68, 15] was added to rules with confidence: 0.935403236416
# Rule [42, 68, 18] + [15] was added to rules with confidence: 0.998174926295
# Rule [15, 18, 39] + [42] was added to rules with confidence: 0.997182895117
# Rule [15, 18] + [42, 39] was added to rules with confidence: 0.935108040371
# Rule [42, 18, 39] + [15] was added to rules with confidence: 0.969929038151
# Rule [42, 15, 39] + [18] was added to rules with confidence: 1.0
# Rule [42, 15, 18] + [39] was added to rules with confidence: 0.937903390176
# Rule [68, 46, 15] + [42] was added to rules with confidence: 0.999531917383
# Rule [46, 15] + [42, 68] was added to rules with confidence: 0.961555780705
# Rule [68, 15] + [42, 46] was added to rules with confidence: 0.935900947789
# Rule [68, 46] + [42, 15] was added to rules with confidence: 0.990204034315
# Rule [42, 46, 15] + [68] was added to rules with confidence: 0.963182228236
# Rule [42, 46] + [68, 15] was added to rules with confidence: 0.932783662772
# Rule [42, 68, 15] + [46] was added to rules with confidence: 0.93718455124
# Rule [42, 68] + [46, 15] was added to rules with confidence: 0.934927758319
# Rule [42, 68, 46] + [15] was added to rules with confidence: 0.998713826367
# Rule [18, 34, 39] + [41] was added to rules with confidence: 0.930007834944
# Rule [34, 39] + [41, 18] was added to rules with confidence: 0.930007834944
# Rule [41, 34, 39] + [18] was added to rules with confidence: 1.0
# Rule [41, 18, 34] + [39] was added to rules with confidence: 0.941440846001
# Rule [18, 35, 39] + [41] was added to rules with confidence: 0.91662341033
# Rule [35, 39] + [41, 18] was added to rules with confidence: 0.91662341033
# Rule [41, 35, 39] + [18] was added to rules with confidence: 1.0
# Rule [41, 35] + [18, 39] was added to rules with confidence: 0.90055459935
# Rule [41, 18, 35] + [39] was added to rules with confidence: 0.965552593808
# Rule [18, 46, 39] + [41] was added to rules with confidence: 0.924184066491
# Rule [46, 39] + [41, 18] was added to rules with confidence: 0.924184066491
# Rule [41, 46, 39] + [18] was added to rules with confidence: 1.0
# Rule [41, 46] + [18, 39] was added to rules with confidence: 0.900454276121
# Rule [41, 18, 46] + [39] was added to rules with confidence: 0.946439692755
# Rule [19, 22, 9] + [49] was added to rules with confidence: 0.949481608664
# Rule [22, 9] + [49, 19] was added to rules with confidence: 0.932606862554
# Rule [19, 9] + [49, 22] was added to rules with confidence: 0.949481608664
# Rule [49, 22, 9] + [19] was added to rules with confidence: 0.986551392891
# Rule [49, 22] + [9, 19] was added to rules with confidence: 0.908849557522
# Rule [49, 19, 9] + [22] was added to rules with confidence: 1.0
# Rule [49, 19] + [9, 22] was added to rules with confidence: 0.920958237253
# Rule [49, 19, 22] + [9] was added to rules with confidence: 0.920958237253
# Rule [59, 60, 22] + [19] was added to rules with confidence: 0.970684706847
# Rule [59, 22] + [19, 60] was added to rules with confidence: 0.934355061501
# Rule [19, 60, 22] + [59] was added to rules with confidence: 0.924383419015
# Rule [19, 60] + [59, 22] was added to rules with confidence: 0.924383419015
# Rule [19, 59, 22] + [60] was added to rules with confidence: 0.964816953067
# Rule [19, 59] + [60, 22] was added to rules with confidence: 0.964816953067
# Rule [19, 59, 60] + [22] was added to rules with confidence: 1.0
# Rule [59, 19, 22] + [60] was added to rules with confidence: 0.964816953067
# Rule [59, 19] + [60, 22] was added to rules with confidence: 0.964816953067
# Rule [59, 19, 60] + [22] was added to rules with confidence: 1.0
# Rule [25, 68, 46] + [42] was added to rules with confidence: 0.99789459386
# Rule [25, 46] + [42, 68] was added to rules with confidence: 0.914141728364
# Rule [25, 68] + [42, 46] was added to rules with confidence: 0.940653008963
# Rule [25, 42, 46] + [68] was added to rules with confidence: 0.945556342107
# Rule [25, 42, 68] + [46] was added to rules with confidence: 0.943916227676
# Rule [34, 2, 9] + [49] was added to rules with confidence: 0.947936804213
# Rule [49, 34, 2] + [9] was added to rules with confidence: 1.0
# Rule [34, 18, 39] + [41] was added to rules with confidence: 0.930007834944
# Rule [41, 34, 18] + [39] was added to rules with confidence: 0.941440846001
# Rule [41, 35, 0] + [11] was added to rules with confidence: 1.0
# Rule [11, 41, 0] + [35] was added to rules with confidence: 0.920814023776
# Rule [11, 18, 35, 39] + [0] was added to rules with confidence: 0.901959512069
# Rule [18, 35, 39] + [0, 11] was added to rules with confidence: 0.901959512069
# Rule [35, 39] + [0, 18, 11] was added to rules with confidence: 0.901959512069
# Rule [11, 35, 39] + [0, 18] was added to rules with confidence: 0.901959512069
# Rule [0, 18, 35, 39] + [11] was added to rules with confidence: 1.0
# Rule [0, 35, 39] + [18, 11] was added to rules with confidence: 1.0
# Rule [0, 18, 35] + [11, 39] was added to rules with confidence: 0.969724450645
# Rule [0, 11, 35, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 11, 39] + [18, 35] was added to rules with confidence: 0.930019401887
# Rule [0, 11, 18, 39] + [35] was added to rules with confidence: 0.930019401887
# Rule [0, 11, 18, 35] + [39] was added to rules with confidence: 0.969724450645
# Rule [35, 18, 11, 39] + [0] was added to rules with confidence: 0.901959512069
# Rule [35, 11, 39] + [0, 18] was added to rules with confidence: 0.901959512069
# Rule [35, 18, 39] + [0, 11] was added to rules with confidence: 0.901959512069
# Rule [0, 18, 11, 39] + [35] was added to rules with confidence: 0.930019401887
# Rule [0, 35, 11, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 35, 18, 39] + [11] was added to rules with confidence: 1.0
# Rule [0, 35, 18] + [11, 39] was added to rules with confidence: 0.969724450645
# Rule [0, 35, 18, 11] + [39] was added to rules with confidence: 0.969724450645
# Rule [41, 18, 11, 39] + [0] was added to rules with confidence: 0.905121967256
# Rule [41, 11, 39] + [0, 18] was added to rules with confidence: 0.905121967256
# Rule [0, 18, 11, 39] + [41] was added to rules with confidence: 0.920987489128
# Rule [0, 11, 39] + [41, 18] was added to rules with confidence: 0.920987489128
# Rule [0, 41, 11, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 41, 11] + [18, 39] was added to rules with confidence: 0.924575189737
# Rule [0, 41, 18, 11] + [39] was added to rules with confidence: 0.969778090877
# Rule [0, 18, 14, 39] + [41] was added to rules with confidence: 0.932064516129
# Rule [0, 14, 39] + [41, 18] was added to rules with confidence: 0.932064516129
# Rule [0, 18, 14] + [41, 39] was added to rules with confidence: 0.900685785536
# Rule [0, 41, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [0, 41, 39] + [18, 14] was added to rules with confidence: 0.905597693224
# Rule [0, 41, 14] + [18, 39] was added to rules with confidence: 0.963069128725
# Rule [0, 41, 18, 39] + [14] was added to rules with confidence: 0.905597693224
# Rule [0, 41, 18, 14] + [39] was added to rules with confidence: 0.970900537634
# Rule [2, 19, 22, 49] + [9] was added to rules with confidence: 1.0
# Rule [19, 22, 49] + [9, 2] was added to rules with confidence: 0.920958237253
# Rule [22, 49] + [9, 2, 19] was added to rules with confidence: 0.908849557522
# Rule [19, 49] + [9, 2, 22] was added to rules with confidence: 0.920958237253
# Rule [2, 22, 49] + [9, 19] was added to rules with confidence: 0.986551392891
# Rule [2, 22] + [9, 19, 49] was added to rules with confidence: 0.932606862554
# Rule [2, 19, 49] + [9, 22] was added to rules with confidence: 1.0
# Rule [2, 19] + [9, 22, 49] was added to rules with confidence: 0.949481608664
# Rule [2, 19, 22] + [9, 49] was added to rules with confidence: 0.949481608664
# Rule [9, 19, 22, 49] + [2] was added to rules with confidence: 1.0
# Rule [9, 22, 49] + [2, 19] was added to rules with confidence: 0.986551392891
# Rule [9, 22] + [49, 2, 19] was added to rules with confidence: 0.932606862554
# Rule [9, 19, 49] + [2, 22] was added to rules with confidence: 1.0
# Rule [9, 19] + [49, 2, 22] was added to rules with confidence: 0.949481608664
# Rule [9, 19, 22] + [49, 2] was added to rules with confidence: 0.949481608664
# Rule [9, 2, 22, 49] + [19] was added to rules with confidence: 0.986551392891
# Rule [9, 2, 22] + [49, 19] was added to rules with confidence: 0.932606862554
# Rule [2, 22] + [49, 19, 9] was added to rules with confidence: 0.932606862554
# Rule [9, 2, 19, 49] + [22] was added to rules with confidence: 1.0
# Rule [9, 2, 19] + [49, 22] was added to rules with confidence: 0.949481608664
# Rule [2, 19] + [49, 22, 9] was added to rules with confidence: 0.949481608664
# Rule [9, 2, 19, 22] + [49] was added to rules with confidence: 0.949481608664
# Rule [2, 19, 22] + [49, 9] was added to rules with confidence: 0.949481608664
# Rule [2, 19, 22, 9] + [49] was added to rules with confidence: 0.949481608664
# Rule [19, 22, 9] + [49, 2] was added to rules with confidence: 0.949481608664
# Rule [22, 9] + [49, 2, 19] was added to rules with confidence: 0.932606862554
# Rule [19, 9] + [49, 2, 22] was added to rules with confidence: 0.949481608664
# Rule [2, 22, 9] + [49, 19] was added to rules with confidence: 0.932606862554
# Rule [2, 19, 9] + [49, 22] was added to rules with confidence: 0.949481608664
# Rule [49, 19, 22, 9] + [2] was added to rules with confidence: 1.0
# Rule [49, 22, 9] + [2, 19] was added to rules with confidence: 0.986551392891
# Rule [49, 22] + [9, 2, 19] was added to rules with confidence: 0.908849557522
# Rule [49, 19, 9] + [2, 22] was added to rules with confidence: 1.0
# Rule [49, 19] + [9, 2, 22] was added to rules with confidence: 0.920958237253
# Rule [49, 19, 22] + [9, 2] was added to rules with confidence: 0.920958237253
# Rule [49, 2, 22, 9] + [19] was added to rules with confidence: 0.986551392891
# Rule [49, 2, 22] + [9, 19] was added to rules with confidence: 0.986551392891
# Rule [49, 2, 19, 9] + [22] was added to rules with confidence: 1.0
# Rule [49, 2, 19] + [9, 22] was added to rules with confidence: 1.0
# Rule [49, 2, 19, 22] + [9] was added to rules with confidence: 1.0
# Rule [18, 35, 14, 39] + [11] was added to rules with confidence: 1.0
# Rule [35, 14, 39] + [18, 11] was added to rules with confidence: 1.0
# Rule [35, 39] + [18, 11, 14] was added to rules with confidence: 0.926031663639
# Rule [35, 14] + [18, 11, 39] was added to rules with confidence: 0.913875904463
# Rule [18, 35, 39] + [11, 14] was added to rules with confidence: 0.926031663639
# Rule [18, 35, 14] + [11, 39] was added to rules with confidence: 0.971942250068
# Rule [11, 35, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [11, 14, 39] + [18, 35] was added to rules with confidence: 0.939132723564
# Rule [11, 35, 39] + [18, 14] was added to rules with confidence: 0.926031663639
# Rule [11, 35, 14] + [18, 39] was added to rules with confidence: 0.913875904463
# Rule [11, 18, 14, 39] + [35] was added to rules with confidence: 0.939132723564
# Rule [11, 18, 14] + [35, 39] was added to rules with confidence: 0.90725319433
# Rule [11, 18, 35, 39] + [14] was added to rules with confidence: 0.926031663639
# Rule [11, 18, 35, 14] + [39] was added to rules with confidence: 0.971942250068
# Rule [18, 11, 14, 39] + [35] was added to rules with confidence: 0.939132723564
# Rule [18, 11, 14] + [35, 39] was added to rules with confidence: 0.90725319433
# Rule [35, 11, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [35, 11, 39] + [18, 14] was added to rules with confidence: 0.926031663639
# Rule [35, 11, 14] + [18, 39] was added to rules with confidence: 0.913875904463
# Rule [35, 18, 14, 39] + [11] was added to rules with confidence: 1.0
# Rule [35, 18, 39] + [11, 14] was added to rules with confidence: 0.926031663639
# Rule [35, 18, 14] + [11, 39] was added to rules with confidence: 0.971942250068
# Rule [35, 18, 11, 39] + [14] was added to rules with confidence: 0.926031663639
# Rule [35, 18, 11, 14] + [39] was added to rules with confidence: 0.971942250068
# Rule [18, 11, 14, 39] + [41] was added to rules with confidence: 0.921760873857
# Rule [11, 14, 39] + [41, 18] was added to rules with confidence: 0.921760873857
# Rule [41, 11, 14, 39] + [18] was added to rules with confidence: 1.0
# Rule [41, 11, 39] + [18, 14] was added to rules with confidence: 0.921033598527
# Rule [41, 11, 14] + [18, 39] was added to rules with confidence: 0.94495412844
# Rule [41, 18, 11, 39] + [14] was added to rules with confidence: 0.921033598527
# Rule [41, 18, 11, 14] + [39] was added to rules with confidence: 0.97203525085
# Rule [18, 11, 41, 39] + [35] was added to rules with confidence: 0.928857913078
# Rule [11, 41, 39] + [18, 35] was added to rules with confidence: 0.928857913078
# Rule [35, 11, 41, 39] + [18] was added to rules with confidence: 1.0
# Rule [35, 41, 39] + [18, 11] was added to rules with confidence: 1.0
# Rule [35, 39] + [41, 18, 11] was added to rules with confidence: 0.91662341033
# Rule [35, 41] + [18, 11, 39] was added to rules with confidence: 0.90055459935
# Rule [35, 11, 39] + [41, 18] was added to rules with confidence: 0.91662341033
# Rule [35, 11, 41] + [18, 39] was added to rules with confidence: 0.90055459935
# Rule [35, 18, 41, 39] + [11] was added to rules with confidence: 1.0
# Rule [35, 18, 39] + [41, 11] was added to rules with confidence: 0.91662341033
# Rule [35, 18, 41] + [11, 39] was added to rules with confidence: 0.965552593808
# Rule [35, 18, 11, 39] + [41] was added to rules with confidence: 0.91662341033
# Rule [35, 18, 11, 41] + [39] was added to rules with confidence: 0.965552593808
# Rule [18, 11, 35, 39] + [41] was added to rules with confidence: 0.91662341033
# Rule [11, 35, 39] + [41, 18] was added to rules with confidence: 0.91662341033
# Rule [18, 35, 39] + [41, 11] was added to rules with confidence: 0.91662341033
# Rule [41, 11, 35, 39] + [18] was added to rules with confidence: 1.0
# Rule [41, 35, 39] + [18, 11] was added to rules with confidence: 1.0
# Rule [41, 35] + [18, 11, 39] was added to rules with confidence: 0.90055459935
# Rule [41, 11, 39] + [18, 35] was added to rules with confidence: 0.928857913078
# Rule [41, 11, 35] + [18, 39] was added to rules with confidence: 0.90055459935
# Rule [41, 18, 35, 39] + [11] was added to rules with confidence: 1.0
# Rule [41, 18, 35] + [11, 39] was added to rules with confidence: 0.965552593808
# Rule [41, 18, 11, 39] + [35] was added to rules with confidence: 0.928857913078
# Rule [41, 18, 11, 35] + [39] was added to rules with confidence: 0.965552593808
# Rule [11, 0, 35, 39] + [18] was added to rules with confidence: 1.0
# Rule [11, 0, 39] + [18, 35] was added to rules with confidence: 0.930019401887
# Rule [11, 0, 18, 39] + [35] was added to rules with confidence: 0.930019401887
# Rule [11, 0, 18, 35] + [39] was added to rules with confidence: 0.969724450645
# Rule [11, 18, 35, 39] + [41] was added to rules with confidence: 0.91662341033
# Rule [11, 41, 35, 39] + [18] was added to rules with confidence: 1.0
# Rule [11, 41, 35] + [18, 39] was added to rules with confidence: 0.90055459935
# Rule [11, 41, 18, 39] + [35] was added to rules with confidence: 0.928857913078
# Rule [11, 41, 18, 35] + [39] was added to rules with confidence: 0.965552593808
# Rule [18, 42, 14, 15] + [68] was added to rules with confidence: 0.968370516803
# Rule [18, 14, 15] + [42, 68] was added to rules with confidence: 0.96584747553
# Rule [18, 15] + [42, 68, 14] was added to rules with confidence: 0.929079455395
# Rule [18, 42, 15] + [68, 14] was added to rules with confidence: 0.931856783749
# Rule [18, 42] + [68, 14, 15] was added to rules with confidence: 0.902249703986
# Rule [18, 42, 14] + [68, 15] was added to rules with confidence: 0.943913013557
# Rule [18, 68, 14, 15] + [42] was added to rules with confidence: 0.998834838334
# Rule [18, 68, 15] + [42, 14] was added to rules with confidence: 0.963405211772
# Rule [18, 68] + [42, 14, 15] was added to rules with confidence: 0.951839000694
# Rule [18, 68, 14] + [42, 15] was added to rules with confidence: 0.98768632534
# Rule [18, 68, 42, 15] + [14] was added to rules with confidence: 0.964556962025
# Rule [18, 68, 42] + [14, 15] was added to rules with confidence: 0.962796574477
# Rule [18, 68, 42, 14] + [15] was added to rules with confidence: 0.998253275109
# Rule [68, 18, 14, 15] + [42] was added to rules with confidence: 0.998834838334
# Rule [68, 18, 15] + [42, 14] was added to rules with confidence: 0.963405211772
# Rule [68, 18] + [42, 14, 15] was added to rules with confidence: 0.951839000694
# Rule [68, 18, 14] + [42, 15] was added to rules with confidence: 0.98768632534
# Rule [42, 18, 14, 15] + [68] was added to rules with confidence: 0.968370516803
# Rule [42, 18, 15] + [68, 14] was added to rules with confidence: 0.931856783749
# Rule [42, 18] + [68, 14, 15] was added to rules with confidence: 0.902249703986
# Rule [42, 18, 14] + [68, 15] was added to rules with confidence: 0.943913013557
# Rule [42, 68, 18, 15] + [14] was added to rules with confidence: 0.964556962025
# Rule [42, 68, 18] + [14, 15] was added to rules with confidence: 0.962796574477
# Rule [42, 68, 18, 14] + [15] was added to rules with confidence: 0.998253275109
# Rule [68, 14, 46, 15] + [42] was added to rules with confidence: 0.999589827728
# Rule [14, 46, 15] + [42, 68] was added to rules with confidence: 0.968344370861
# Rule [14, 15] + [42, 68, 46] was added to rules with confidence: 0.915935855675
# Rule [68, 14, 15] + [42, 46] was added to rules with confidence: 0.949172346641
# Rule [68, 14] + [42, 46, 15] was added to rules with confidence: 0.936167488316
# Rule [68, 14, 46] + [42, 15] was added to rules with confidence: 0.991792715187
# Rule [42, 14, 46, 15] + [68] was added to rules with confidence: 0.969564352497
# Rule [42, 14, 15] + [68, 46] was added to rules with confidence: 0.918351965833
# Rule [42, 14, 46] + [68, 15] was added to rules with confidence: 0.954314058217
# Rule [42, 68, 14, 15] + [46] was added to rules with confidence: 0.950282706181
# Rule [42, 68, 14] + [46, 15] was added to rules with confidence: 0.948618139354
# Rule [42, 68, 14, 46] + [15] was added to rules with confidence: 0.998906954502
# Rule [68, 46, 14, 15] + [42] was added to rules with confidence: 0.999589827728
# Rule [46, 14, 15] + [42, 68] was added to rules with confidence: 0.968344370861
# Rule [68, 46, 14] + [42, 15] was added to rules with confidence: 0.991792715187
# Rule [42, 46, 14, 15] + [68] was added to rules with confidence: 0.969564352497
# Rule [42, 46, 14] + [68, 15] was added to rules with confidence: 0.954314058217
# Rule [42, 68, 46, 14] + [15] was added to rules with confidence: 0.998906954502
# Rule [25, 68, 46, 15] + [42] was added to rules with confidence: 0.999795598556
# Rule [25, 46, 15] + [42, 68] was added to rules with confidence: 0.969668935439
# Rule [25, 15] + [42, 68, 46] was added to rules with confidence: 0.909733415995
# Rule [25, 46] + [42, 68, 15] was added to rules with confidence: 0.912959621726
# Rule [25, 68, 15] + [42, 46] was added to rules with confidence: 0.944090587403
# Rule [25, 68] + [42, 46, 15] was added to rules with confidence: 0.939436619718
# Rule [25, 68, 46] + [42, 15] was added to rules with confidence: 0.996604183646
# Rule [25, 42, 46, 15] + [68] was added to rules with confidence: 0.969925309009
# Rule [25, 42, 15] + [68, 46] was added to rules with confidence: 0.910636713417
# Rule [25, 42, 46] + [68, 15] was added to rules with confidence: 0.944333612202
# Rule [25, 42, 68, 15] + [46] was added to rules with confidence: 0.944455171526
# Rule [25, 42, 68] + [46, 15] was added to rules with confidence: 0.942695618656
# Rule [25, 42, 68, 46] + [15] was added to rules with confidence: 0.998706867216

# %%
users1 = analyse(median_transactions, [74, 26, 29], [30])
print
users2 = analyse(median_transactions, [72,3],[29])
print 
a = np.zeros(trans_len)
b = np.zeros(trans_len)
a[users1] = 1.0
b[users2] = 1.0
print 'Euclidean distance: ', euclidean_distances(a,b)
print len([i for i, j in zip(a, b) if i == j]) * 1.0 / trans_len
# Out:
# 0.148185528106
# Support[74, 26, 29]: 0.152529729255
# Support[30]: 0.49997805959
# Confidence[74, 26, 29]->[30]: 0.971518987342
# Confidence[30]->[74, 26, 29]: 0.296384061787
# Lift[74, 26, 29]->[30]: 1.94312324052
# Lift[30]->[74, 26, 29]: 1.94312324052
#
# 0.0180130764843
# Support[72, 3]: 0.0458773969898
# Support[29]: 0.5
# Confidence[72, 3]->[29]: 0.392635102822
# Confidence[29]->[72, 3]: 0.0360261529685
# Lift[72, 3]->[29]: 0.785270205643
# Lift[29]->[72, 3]: 0.785270205643
#
# Euclidean distance:  [[ 82.21313764]]
# 0.851704769845

# %%
freq_itemsets_mode = apriori(mode_transactions, 0.5)
assoc_rules_mode = []
for i, itemset_row in enumerate(freq_itemsets_mode):
    if i == 0:
        continue
    for itemset in itemset_row:
        find_rules(mode_transactions, itemset, [], 0.9, assoc_rules_mode)
        
assoc_rules_mode.sort(key=lambda rule: rule[2], reverse=True)
# Out:
# [[0], [1], [2], [5], [8], [9], [11], [14], [15], [18], [19], [22], [25], [26], [27], [29], [30], [33], [34], [35], [39], [41], [42], [44], [46], [49], [59], [60], [68], [70], [72], [73], [74], [76]]
# j= 1
# j=  itemset: [0]
# j=  itemset: [1]
# j=  itemset: [2]
# j=  itemset: [5]
# j=  itemset: [8]
# j=  itemset: [9]
# j=  itemset: [11]
# j=  itemset: [14]
# j=  itemset: [15]
# j=  itemset: [18]
# j=  itemset: [19]
# j=  itemset: [22]
# j=  itemset: [25]
# j=  itemset: [26]
# j=  itemset: [27]
# j=  itemset: [29]
# j=  itemset: [30]
# j=  itemset: [33]
# j=  itemset: [34]
# j=  itemset: [35]
# j=  itemset: [39]
# j=  itemset: [41]
# j=  itemset: [42]
# j=  itemset: [44]
# j=  itemset: [46]
# j=  itemset: [49]
# j=  itemset: [59]
# j=  itemset: [60]
# j=  itemset: [68]
# j=  itemset: [70]
# j=  itemset: [72]
# j=  itemset: [73]
# j=  itemset: [74]
# j=  itemset: [76]
# j= 2
# j=  itemset: [0, 1]
# j=  itemset: [0, 5]
# j=  itemset: [0, 11]
# j=  itemset: [0, 14]
# j=  itemset: [0, 15]
# j=  itemset: [0, 18]
# j=  itemset: [0, 25]
# j=  itemset: [0, 26]
# j=  itemset: [0, 27]
# j=  itemset: [0, 29]
# j=  itemset: [0, 30]
# j=  itemset: [0, 34]
# j=  itemset: [0, 39]
# j=  itemset: [0, 41]
# j=  itemset: [0, 42]
# j=  itemset: [0, 44]
# j=  itemset: [0, 68]
# j=  itemset: [0, 72]
# j=  itemset: [0, 74]
# j=  itemset: [1, 2]
# j=  itemset: [1, 5]
# j=  itemset: [8, 1]
# j=  itemset: [1, 9]
# j=  itemset: [1, 11]
# j=  itemset: [1, 14]
# j=  itemset: [1, 15]
# j=  itemset: [1, 18]
# j=  itemset: [1, 19]
# j=  itemset: [1, 22]
# j=  itemset: [1, 25]
# j=  itemset: [1, 26]
# j=  itemset: [1, 27]
# j=  itemset: [1, 29]
# j=  itemset: [1, 30]
# j=  itemset: [1, 33]
# j=  itemset: [1, 34]
# j=  itemset: [1, 35]
# j=  itemset: [1, 39]
# j=  itemset: [1, 41]
# j=  itemset: [1, 42]
# j=  itemset: [1, 44]
# j=  itemset: [1, 46]
# j=  itemset: [1, 49]
# j=  itemset: [1, 59]
# j=  itemset: [1, 60]
# j=  itemset: [1, 68]
# j=  itemset: [1, 70]
# j=  itemset: [72, 1]
# j=  itemset: [1, 73]
# j=  itemset: [1, 74]
# j=  itemset: [1, 76]
# j=  itemset: [2, 5]
# j=  itemset: [9, 2]
# j=  itemset: [2, 14]
# j=  itemset: [2, 15]
# j=  itemset: [2, 18]
# j=  itemset: [2, 19]
# j=  itemset: [2, 22]
# j=  itemset: [25, 2]
# j=  itemset: [2, 27]
# j=  itemset: [2, 29]
# j=  itemset: [2, 30]
# j=  itemset: [2, 39]
# j=  itemset: [41, 2]
# j=  itemset: [2, 42]
# j=  itemset: [2, 44]
# j=  itemset: [49, 2]
# j=  itemset: [2, 68]
# j=  itemset: [72, 2]
# j=  itemset: [2, 74]
# j=  itemset: [8, 5]
# j=  itemset: [9, 5]
# j=  itemset: [11, 5]
# j=  itemset: [5, 14]
# j=  itemset: [5, 15]
# j=  itemset: [18, 5]
# j=  itemset: [19, 5]
# j=  itemset: [5, 22]
# j=  itemset: [25, 5]
# j=  itemset: [26, 5]
# j=  itemset: [27, 5]
# j=  itemset: [5, 29]
# j=  itemset: [5, 30]
# j=  itemset: [33, 5]
# j=  itemset: [34, 5]
# j=  itemset: [35, 5]
# j=  itemset: [5, 39]
# j=  itemset: [41, 5]
# j=  itemset: [42, 5]
# j=  itemset: [44, 5]
# j=  itemset: [5, 46]
# j=  itemset: [49, 5]
# j=  itemset: [59, 5]
# j=  itemset: [60, 5]
# j=  itemset: [68, 5]
# j=  itemset: [5, 70]
# j=  itemset: [72, 5]
# j=  itemset: [73, 5]
# j=  itemset: [74, 5]
# j=  itemset: [76, 5]
# j=  itemset: [8, 14]
# j=  itemset: [8, 15]
# j=  itemset: [8, 18]
# j=  itemset: [8, 25]
# j=  itemset: [8, 26]
# j=  itemset: [8, 27]
# j=  itemset: [8, 29]
# j=  itemset: [8, 30]
# j=  itemset: [8, 39]
# j=  itemset: [8, 42]
# j=  itemset: [8, 44]
# j=  itemset: [8, 59]
# j=  itemset: [8, 60]
# j=  itemset: [8, 72]
# j=  itemset: [8, 74]
# j=  itemset: [9, 1]
# j=  itemset: [9, 14]
# j=  itemset: [9, 15]
# j=  itemset: [9, 18]
# j=  itemset: [9, 19]
# j=  itemset: [9, 22]
# j=  itemset: [9, 25]
# j=  itemset: [9, 27]
# j=  itemset: [9, 29]
# j=  itemset: [9, 30]
# j=  itemset: [9, 39]
# j=  itemset: [9, 41]
# j=  itemset: [9, 42]
# j=  itemset: [9, 44]
# j=  itemset: [9, 49]
# j=  itemset: [9, 68]
# j=  itemset: [72, 9]
# j=  itemset: [9, 74]
# j=  itemset: [11, 14]
# j=  itemset: [11, 15]
# j=  itemset: [18, 11]
# j=  itemset: [25, 11]
# j=  itemset: [26, 11]
# j=  itemset: [27, 11]
# j=  itemset: [11, 29]
# j=  itemset: [11, 30]
# j=  itemset: [35, 11]
# j=  itemset: [11, 39]
# j=  itemset: [41, 11]
# j=  itemset: [42, 11]
# j=  itemset: [11, 44]
# j=  itemset: [11, 46]
# j=  itemset: [11, 68]
# j=  itemset: [72, 11]
# j=  itemset: [73, 11]
# j=  itemset: [74, 11]
# j=  itemset: [14, 15]
# j=  itemset: [18, 14]
# j=  itemset: [19, 14]
# j=  itemset: [22, 14]
# j=  itemset: [25, 14]
# j=  itemset: [26, 14]
# j=  itemset: [27, 14]
# j=  itemset: [29, 14]
# j=  itemset: [30, 14]
# j=  itemset: [33, 14]
# j=  itemset: [34, 14]
# j=  itemset: [35, 14]
# j=  itemset: [14, 39]
# j=  itemset: [41, 14]
# j=  itemset: [42, 14]
# j=  itemset: [44, 14]
# j=  itemset: [46, 14]
# j=  itemset: [49, 14]
# j=  itemset: [59, 14]
# j=  itemset: [60, 14]
# j=  itemset: [68, 14]
# j=  itemset: [70, 14]
# j=  itemset: [72, 14]
# j=  itemset: [73, 14]
# j=  itemset: [74, 14]
# j=  itemset: [76, 14]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-130-65dccac1abcd> in <module>()
# ----> 1 freq_itemsets_mode = apriori(mode_transactions, 0.4)
#       2 assoc_rules_mode = []
#       3 for i, itemset_row in enumerate(freq_itemsets_mode):
#       4     if i == 0:
#       5         continue
#
# <ipython-input-126-fec1c18fda06> in apriori(transactions, delta)
#      18             for f in freq_features:
#      19                 if f[0] not in itemset and list(set(itemset+f)) not in temp:
# ---> 20                     cur_support = support(transactions, list(set(itemset+f)))
#      21                     if cur_support > delta:
#      22                         temp.append(list(set(itemset+f)))
#
# <ipython-input-101-51cc071f8103> in support(transactions, itemset)
#       3     for id, transaction in enumerate(transactions):
#       4         if all(transaction[itemset] != 0):
# ----> 5             ids.append(id)
#       6     return len(ids) * 1.0 / len(transactions)
#       7
#
# KeyboardInterrupt:

# %%
users1 = analyse(mode_transactions, [74, 26, 29], [30])
print
users2 = analyse(mode_transactions, [72,3],[29])
print 
a = np.zeros(trans_len)
b = np.zeros(trans_len)
a[users1] = 1.0
b[users2] = 1.0
print 'Euclidean distance: ', euclidean_distances(a,b)
print len([i for i, j in zip(a, b) if i == j]) * 1.0 / trans_len

# %%
freq_itemsets_kmeans = apriori(kmeans_transactions, 0.6)
assoc_rules_kmeans = []
for i, itemset_row in enumerate(freq_itemsets_kmeans):
    if i == 0:
        continue
    for itemset in itemset_row:
        find_rules(kmeans_transactions, itemset, [], 0.9, assoc_rules_kmeans)
        
assoc_rules_kmeans.sort(key=lambda rule: rule[2], reverse=True)
# Out:
# [[0], [3], [5], [22], [25], [32], [46], [59], [60], [65], [70], [72], [74]]
# j= 1
# j=  itemset: [0]
# j=  itemset: [3]
# j=  itemset: [5]
# j=  itemset: [22]
# j=  itemset: [25]
# j=  itemset: [32]
# j=  itemset: [46]
# j=  itemset: [59]
# j=  itemset: [60]
# j=  itemset: [65]
# j=  itemset: [70]
# j=  itemset: [72]
# j=  itemset: [74]
# j= 2
# j=  itemset: [0, 3]
# j=  itemset: [0, 5]
# j=  itemset: [0, 22]
# j=  itemset: [0, 25]
# j=  itemset: [0, 46]
# j=  itemset: [0, 59]
# j=  itemset: [0, 60]
# j=  itemset: [0, 65]
# j=  itemset: [0, 74]
# j=  itemset: [3, 5]
# j=  itemset: [3, 22]
# j=  itemset: [25, 3]
# j=  itemset: [3, 46]
# j=  itemset: [59, 3]
# j=  itemset: [65, 3]
# j=  itemset: [74, 3]
# j=  itemset: [5, 22]
# j=  itemset: [25, 5]
# j=  itemset: [5, 46]
# j=  itemset: [59, 5]
# j=  itemset: [65, 5]
# j=  itemset: [74, 5]
# j=  itemset: [25, 22]
# j=  itemset: [32, 22]
# j=  itemset: [46, 22]
# j=  itemset: [59, 22]
# j=  itemset: [60, 22]
# j=  itemset: [65, 22]
# j=  itemset: [70, 22]
# j=  itemset: [72, 22]
# j=  itemset: [74, 22]
# j=  itemset: [32, 25]
# j=  itemset: [25, 46]
# j=  itemset: [25, 59]
# j=  itemset: [25, 60]
# j=  itemset: [25, 65]
# j=  itemset: [25, 70]
# j=  itemset: [72, 25]
# j=  itemset: [25, 74]
# j=  itemset: [32, 46]
# j=  itemset: [32, 65]
# j=  itemset: [22, 46]
# j=  itemset: [59, 46]
# j=  itemset: [60, 46]
# j=  itemset: [65, 46]
# j=  itemset: [72, 46]
# j=  itemset: [74, 46]
# j=  itemset: [3, 59]
# j=  itemset: [59, 60]
# j=  itemset: [65, 59]
# j=  itemset: [74, 59]
# j=  itemset: [65, 60]
# j=  itemset: [65, 25]
# j=  itemset: [72, 65]
# j=  itemset: [65, 74]
# j=  itemset: [22, 70]
# j=  itemset: [72, 74]
# j= 3
# j=  itemset: [0, 3, 22]
# j=  itemset: [0, 25, 3]
# j=  itemset: [0, 3, 46]
# j=  itemset: [0, 5, 22]
# j=  itemset: [0, 25, 5]
# j=  itemset: [0, 5, 46]
# j=  itemset: [0, 25, 22]
# j=  itemset: [0, 46, 22]
# j=  itemset: [0, 59, 22]
# j=  itemset: [0, 60, 22]
# j=  itemset: [0, 65, 22]
# j=  itemset: [0, 74, 22]
# j=  itemset: [0, 25, 46]
# j=  itemset: [0, 25, 59]
# j=  itemset: [0, 25, 60]
# j=  itemset: [0, 25, 65]
# j=  itemset: [0, 25, 74]
# j=  itemset: [0, 22, 46]
# j=  itemset: [0, 59, 46]
# j=  itemset: [0, 65, 46]
# j=  itemset: [0, 59, 60]
# j=  itemset: [0, 65, 59]
# j=  itemset: [0, 65, 25]
# j=  itemset: [3, 5, 22]
# j=  itemset: [25, 3, 5]
# j=  itemset: [25, 3, 22]
# j=  itemset: [3, 46, 22]
# j=  itemset: [59, 3, 22]
# j=  itemset: [65, 3, 22]
# j=  itemset: [74, 3, 22]
# j=  itemset: [25, 3, 46]
# j=  itemset: [25, 3, 59]
# j=  itemset: [25, 3, 65]
# j=  itemset: [25, 74, 3]
# j=  itemset: [3, 22, 46]
# j=  itemset: [59, 3, 46]
# j=  itemset: [65, 3, 46]
# j=  itemset: [3, 59, 22]
# j=  itemset: [3, 25, 59]
# j=  itemset: [3, 59, 46]
# j=  itemset: [3, 65, 59]
# j=  itemset: [65, 3, 25]
# j=  itemset: [65, 3, 59]
# j=  itemset: [25, 5, 22]
# j=  itemset: [46, 5, 22]
# j=  itemset: [59, 5, 22]
# j=  itemset: [65, 5, 22]
# j=  itemset: [74, 5, 22]
# j=  itemset: [25, 5, 46]
# j=  itemset: [25, 59, 5]
# j=  itemset: [25, 5, 65]
# j=  itemset: [25, 74, 5]
# j=  itemset: [22, 5, 46]
# j=  itemset: [59, 5, 46]
# j=  itemset: [65, 5, 46]
# j=  itemset: [74, 5, 46]
# j=  itemset: [65, 59, 5]
# j=  itemset: [65, 5, 25]
# j=  itemset: [32, 25, 22]
# j=  itemset: [25, 46, 22]
# j=  itemset: [25, 59, 22]
# j=  itemset: [25, 60, 22]
# j=  itemset: [25, 22, 65]
# j=  itemset: [25, 70, 22]
# j=  itemset: [72, 25, 22]
# j=  itemset: [25, 74, 22]
# j=  itemset: [32, 46, 22]
# j=  itemset: [32, 65, 22]
# j=  itemset: [22, 46, 5]
# j=  itemset: [25, 22, 46]
# j=  itemset: [32, 22, 46]
# j=  itemset: [59, 22, 46]
# j=  itemset: [60, 22, 46]
# j=  itemset: [65, 22, 46]
# j=  itemset: [72, 22, 46]
# j=  itemset: [74, 22, 46]
# j=  itemset: [59, 46, 22]
# j=  itemset: [59, 60, 22]
# j=  itemset: [65, 59, 22]
# j=  itemset: [74, 59, 22]
# j=  itemset: [60, 46, 22]
# j=  itemset: [65, 60, 22]
# j=  itemset: [65, 22, 25]
# j=  itemset: [65, 46, 22]
# j=  itemset: [72, 65, 22]
# j=  itemset: [65, 74, 22]
# j=  itemset: [25, 22, 70]
# j=  itemset: [72, 46, 22]
# j=  itemset: [72, 74, 22]
# j=  itemset: [74, 46, 22]
# j=  itemset: [32, 25, 46]
# j=  itemset: [32, 25, 65]
# j=  itemset: [25, 59, 46]
# j=  itemset: [25, 60, 46]
# j=  itemset: [25, 46, 65]
# j=  itemset: [72, 25, 46]
# j=  itemset: [25, 74, 46]
# j=  itemset: [25, 59, 60]
# j=  itemset: [25, 59, 65]
# j=  itemset: [25, 74, 59]
# j=  itemset: [25, 60, 65]
# j=  itemset: [72, 25, 65]
# j=  itemset: [25, 74, 65]
# j=  itemset: [72, 25, 74]
# j=  itemset: [32, 65, 25]
# j=  itemset: [46, 22, 5]
# j=  itemset: [59, 60, 46]
# j=  itemset: [65, 59, 46]
# j=  itemset: [74, 59, 46]
# j=  itemset: [65, 60, 46]
# j=  itemset: [65, 46, 25]
# j=  itemset: [65, 74, 46]
# j=  itemset: [72, 74, 46]
# j=  itemset: [59, 3, 25]
# j=  itemset: [59, 3, 65]
# j=  itemset: [65, 59, 60]
# j=  itemset: [65, 59, 25]
# j=  itemset: [65, 74, 59]
# j=  itemset: [65, 60, 25]
# j=  itemset: [72, 65, 25]
# j=  itemset: [65, 74, 25]
# j=  itemset: [72, 65, 74]
# j= 4
# j=  itemset: [0, 25, 3, 22]
# j=  itemset: [0, 3, 46, 22]
# j=  itemset: [0, 25, 3, 46]
# j=  itemset: [0, 3, 22, 46]
# j=  itemset: [0, 25, 5, 22]
# j=  itemset: [0, 46, 5, 22]
# j=  itemset: [0, 25, 5, 46]
# j=  itemset: [0, 22, 5, 46]
# j=  itemset: [0, 25, 46, 22]
# j=  itemset: [0, 25, 59, 22]
# j=  itemset: [0, 25, 60, 22]
# j=  itemset: [0, 25, 22, 65]
# j=  itemset: [0, 25, 74, 22]
# j=  itemset: [0, 22, 46, 5]
# j=  itemset: [0, 25, 22, 46]
# j=  itemset: [0, 59, 22, 46]
# j=  itemset: [0, 65, 22, 46]
# j=  itemset: [0, 59, 46, 22]
# j=  itemset: [0, 59, 60, 22]
# j=  itemset: [0, 65, 59, 22]
# j=  itemset: [0, 65, 22, 25]
# j=  itemset: [0, 65, 46, 22]
# j=  itemset: [0, 25, 59, 46]
# j=  itemset: [0, 25, 46, 65]
# j=  itemset: [0, 25, 59, 60]
# j=  itemset: [0, 25, 59, 65]
# j=  itemset: [0, 46, 22, 5]
# j=  itemset: [0, 65, 59, 46]
# j=  itemset: [0, 65, 46, 25]
# j=  itemset: [0, 65, 59, 25]
# j=  itemset: [25, 3, 5, 22]
# j=  itemset: [25, 3, 46, 22]
# j=  itemset: [25, 3, 22, 59]
# j=  itemset: [25, 3, 22, 65]
# j=  itemset: [25, 74, 3, 22]
# j=  itemset: [25, 3, 22, 46]
# j=  itemset: [59, 3, 22, 46]
# j=  itemset: [65, 3, 22, 46]
# j=  itemset: [3, 25, 59, 22]
# j=  itemset: [3, 59, 46, 22]
# j=  itemset: [3, 65, 59, 22]
# j=  itemset: [65, 3, 22, 25]
# j=  itemset: [65, 3, 46, 22]
# j=  itemset: [65, 3, 22, 59]
# j=  itemset: [25, 3, 46, 59]
# j=  itemset: [25, 3, 46, 65]
# j=  itemset: [25, 3, 59, 65]
# j=  itemset: [59, 3, 46, 22]
# j=  itemset: [3, 59, 22, 46]
# j=  itemset: [3, 25, 59, 46]
# j=  itemset: [65, 3, 46, 25]
# j=  itemset: [59, 3, 22, 25]
# j=  itemset: [59, 3, 22, 65]
# j=  itemset: [59, 3, 46, 25]
# j=  itemset: [65, 3, 59, 25]
# j=  itemset: [25, 46, 5, 22]
# j=  itemset: [25, 59, 5, 22]
# j=  itemset: [25, 5, 22, 65]
# j=  itemset: [25, 74, 5, 22]
# j=  itemset: [25, 22, 5, 46]
# j=  itemset: [22, 59, 5, 46]
# j=  itemset: [65, 22, 5, 46]
# j=  itemset: [22, 74, 5, 46]
# j=  itemset: [46, 59, 5, 22]
# j=  itemset: [65, 59, 5, 22]
# j=  itemset: [65, 5, 22, 25]
# j=  itemset: [65, 46, 5, 22]
# j=  itemset: [74, 46, 5, 22]
# j=  itemset: [25, 59, 5, 46]
# j=  itemset: [25, 5, 46, 65]
# j=  itemset: [25, 74, 5, 46]
# j=  itemset: [25, 59, 5, 65]
# j=  itemset: [59, 46, 5, 22]
# j=  itemset: [65, 5, 46, 25]
# j=  itemset: [74, 22, 5, 46]
# j=  itemset: [65, 59, 5, 25]
# j=  itemset: [32, 25, 22, 65]
# j=  itemset: [25, 22, 46, 5]
# j=  itemset: [25, 59, 22, 46]
# j=  itemset: [25, 60, 22, 46]
# j=  itemset: [25, 22, 46, 65]
# j=  itemset: [72, 25, 22, 46]
# j=  itemset: [25, 74, 22, 46]
# j=  itemset: [25, 59, 46, 22]
# j=  itemset: [25, 59, 60, 22]
# j=  itemset: [25, 59, 22, 65]
# j=  itemset: [25, 74, 59, 22]
# j=  itemset: [25, 60, 46, 22]
# j=  itemset: [25, 60, 22, 65]
# j=  itemset: [25, 46, 22, 65]
# j=  itemset: [72, 25, 22, 65]
# j=  itemset: [25, 74, 22, 65]
# j=  itemset: [72, 25, 46, 22]
# j=  itemset: [72, 25, 74, 22]
# j=  itemset: [25, 74, 46, 22]
# j=  itemset: [32, 65, 22, 25]
# j=  itemset: [25, 46, 22, 5]
# j=  itemset: [59, 46, 22, 5]
# j=  itemset: [65, 46, 22, 5]
# j=  itemset: [74, 46, 22, 5]
# j=  itemset: [59, 60, 46, 22]
# j=  itemset: [65, 59, 46, 22]
# j=  itemset: [74, 59, 46, 22]
# j=  itemset: [65, 60, 46, 22]
# j=  itemset: [65, 46, 22, 25]
# j=  itemset: [65, 74, 46, 22]
# j=  itemset: [72, 74, 46, 22]
# j=  itemset: [59, 22, 46, 5]
# j=  itemset: [59, 60, 22, 46]
# j=  itemset: [65, 59, 22, 46]
# j=  itemset: [74, 59, 22, 46]
# j=  itemset: [65, 59, 60, 22]
# j=  itemset: [65, 59, 22, 25]
# j=  itemset: [65, 74, 59, 22]
# j=  itemset: [65, 60, 22, 46]
# j=  itemset: [65, 60, 22, 25]
# j=  itemset: [72, 65, 22, 25]
# j=  itemset: [65, 74, 22, 25]
# j=  itemset: [65, 22, 46, 5]
# j=  itemset: [65, 22, 46, 25]
# j=  itemset: [65, 74, 22, 46]
# j=  itemset: [72, 65, 74, 22]
# j=  itemset: [72, 74, 22, 46]
# j=  itemset: [74, 22, 46, 5]
# j=  itemset: [25, 59, 60, 46]
# j=  itemset: [25, 59, 46, 65]
# j=  itemset: [25, 74, 59, 46]
# j=  itemset: [25, 60, 46, 65]
# j=  itemset: [25, 74, 46, 65]
# j=  itemset: [72, 25, 74, 46]
# j=  itemset: [25, 59, 60, 65]
# j=  itemset: [3, 25, 59, 65]
# j=  itemset: [25, 74, 59, 65]
# j=  itemset: [72, 25, 74, 65]
# j=  itemset: [65, 59, 60, 46]
# j=  itemset: [65, 59, 46, 25]
# j=  itemset: [65, 60, 46, 25]
# j=  itemset: [65, 74, 46, 25]
# j=  itemset: [3, 65, 59, 25]
# j=  itemset: [65, 59, 60, 25]
# j=  itemset: [65, 74, 59, 25]
# j=  itemset: [72, 65, 74, 25]
# j= 5
# j=  itemset: [0, 25, 3, 46, 22]
# j=  itemset: [0, 25, 3, 22, 46]
# j=  itemset: [0, 25, 46, 5, 22]
# j=  itemset: [0, 25, 22, 5, 46]
# j=  itemset: [0, 25, 22, 46, 5]
# j=  itemset: [0, 25, 59, 22, 46]
# j=  itemset: [0, 25, 22, 46, 65]
# j=  itemset: [0, 25, 59, 46, 22]
# j=  itemset: [0, 25, 59, 60, 22]
# j=  itemset: [0, 25, 59, 22, 65]
# j=  itemset: [0, 25, 46, 22, 65]
# j=  itemset: [0, 25, 46, 22, 5]
# j=  itemset: [0, 65, 59, 46, 22]
# j=  itemset: [0, 65, 46, 22, 25]
# j=  itemset: [0, 65, 59, 22, 46]
# j=  itemset: [0, 65, 59, 22, 25]
# j=  itemset: [0, 65, 22, 46, 25]
# j=  itemset: [0, 25, 59, 46, 65]
# j=  itemset: [0, 65, 59, 46, 25]
# j=  itemset: [25, 3, 22, 46, 59]
# j=  itemset: [25, 3, 22, 46, 65]
# j=  itemset: [25, 3, 46, 22, 59]
# j=  itemset: [25, 3, 65, 22, 59]
# j=  itemset: [25, 3, 46, 22, 65]
# j=  itemset: [25, 3, 59, 22, 65]
# j=  itemset: [3, 25, 59, 46, 22]
# j=  itemset: [65, 3, 46, 22, 25]
# j=  itemset: [46, 25, 3, 22, 59]
# j=  itemset: [25, 3, 22, 59, 65]
# j=  itemset: [59, 3, 22, 46, 25]
# j=  itemset: [65, 3, 22, 59, 25]
# j=  itemset: [65, 3, 59, 22, 25]
# j=  itemset: [65, 3, 22, 46, 25]
# j=  itemset: [65, 3, 25, 22, 59]
# j=  itemset: [3, 25, 59, 22, 46]
# j=  itemset: [59, 3, 46, 22, 25]
# j=  itemset: [25, 22, 3, 46, 59]
# j=  itemset: [3, 25, 59, 22, 65]
# j=  itemset: [3, 65, 59, 22, 25]
# j=  itemset: [25, 22, 59, 5, 46]
# j=  itemset: [25, 22, 5, 46, 65]
# j=  itemset: [25, 22, 74, 5, 46]
# j=  itemset: [46, 25, 59, 5, 22]
# j=  itemset: [25, 59, 5, 22, 65]
# j=  itemset: [25, 46, 5, 22, 65]
# j=  itemset: [25, 74, 46, 5, 22]
# j=  itemset: [25, 46, 5, 22, 59]
# j=  itemset: [65, 46, 5, 22, 25]
# j=  itemset: [65, 59, 5, 22, 25]
# j=  itemset: [65, 22, 5, 46, 25]
# j=  itemset: [25, 74, 22, 5, 46]
# j=  itemset: [25, 59, 46, 22, 5]
# j=  itemset: [25, 65, 46, 22, 5]
# j=  itemset: [25, 74, 46, 22, 5]
# j=  itemset: [25, 59, 60, 46, 22]
# j=  itemset: [25, 59, 46, 22, 65]
# j=  itemset: [25, 74, 59, 46, 22]
# j=  itemset: [25, 60, 46, 22, 65]
# j=  itemset: [25, 5, 46, 22, 65]
# j=  itemset: [25, 74, 46, 22, 65]
# j=  itemset: [72, 25, 74, 46, 22]
# j=  itemset: [25, 59, 22, 46, 5]
# j=  itemset: [25, 59, 60, 22, 46]
# j=  itemset: [25, 59, 22, 46, 65]
# j=  itemset: [25, 74, 59, 22, 46]
# j=  itemset: [25, 59, 60, 22, 65]
# j=  itemset: [25, 74, 59, 22, 65]
# j=  itemset: [25, 60, 22, 46, 65]
# j=  itemset: [25, 5, 22, 46, 65]
# j=  itemset: [25, 74, 22, 46, 65]
# j=  itemset: [72, 25, 74, 22, 65]
# j=  itemset: [72, 25, 74, 22, 46]
# j=  itemset: [25, 74, 22, 46, 5]
# j=  itemset: [25, 65, 22, 46, 5]
# j=  itemset: [65, 25, 22, 46, 5]
# j=  itemset: [65, 59, 60, 22, 46]
# j=  itemset: [65, 59, 22, 46, 25]
# j=  itemset: [65, 60, 22, 46, 25]
# j=  itemset: [65, 5, 22, 46, 25]
# j=  itemset: [65, 74, 22, 46, 25]
# j=  itemset: [65, 59, 60, 46, 22]
# j=  itemset: [65, 59, 46, 22, 25]
# j=  itemset: [65, 59, 60, 22, 25]
# j=  itemset: [65, 74, 59, 22, 25]
# j=  itemset: [65, 60, 46, 22, 25]
# j=  itemset: [72, 65, 74, 22, 25]
# j=  itemset: [65, 74, 46, 22, 25]
# j=  itemset: [65, 25, 46, 22, 5]
# j=  itemset: [65, 5, 46, 22, 25]
# j=  itemset: [25, 59, 60, 46, 65]
# j=  itemset: [65, 59, 60, 46, 25]
# j= 6
# j=  itemset: [0, 65, 46, 22, 25, 59]
# j=  itemset: [65, 46, 22, 25, 59, 60]
# j= 7
# Rule [0, 3] + [22] was added to rules with confidence: 0.993392655555
# Rule [0, 3] + [25] was added to rules with confidence: 0.993359452819
# Rule [0, 3] + [46] was added to rules with confidence: 0.915233415233
# Rule [0, 5] + [22] was added to rules with confidence: 0.996307187308
# Rule [0, 5] + [25] was added to rules with confidence: 0.996238801887
# Rule [0, 5] + [46] was added to rules with confidence: 0.940846611502
# Rule [0, 22] + [25] was added to rules with confidence: 0.998429639882
# Rule [0, 25] + [22] was added to rules with confidence: 0.998482791663
# Rule [0, 22] + [46] was added to rules with confidence: 0.91304463549
# Rule [0, 46] + [22] was added to rules with confidence: 0.996832592334
# Rule [0, 59] + [22] was added to rules with confidence: 0.996344361177
# Rule [0, 60] + [22] was added to rules with confidence: 0.997511641961
# Rule [0, 65] + [22] was added to rules with confidence: 0.993937063764
# Rule [0, 74] + [22] was added to rules with confidence: 0.997202210254
# Rule [0, 46] + [25] was added to rules with confidence: 0.996716357191
# Rule [0, 25] + [46] was added to rules with confidence: 0.912986771008
# Rule [0, 59] + [25] was added to rules with confidence: 0.996527143118
# Rule [0, 60] + [25] was added to rules with confidence: 0.997262806157
# Rule [0, 65] + [25] was added to rules with confidence: 0.99402578966
# Rule [0, 74] + [25] was added to rules with confidence: 0.997097293138
# Rule [0, 46] + [59] was added to rules with confidence: 0.901665068433
# Rule [0, 59] + [46] was added to rules with confidence: 0.945256808627
# Rule [0, 65] + [46] was added to rules with confidence: 0.907547616231
# Rule [0, 60] + [59] was added to rules with confidence: 0.98855355302
# Rule [3, 5] + [22] was added to rules with confidence: 0.995634549423
# Rule [3, 5] + [25] was added to rules with confidence: 0.99559990299
# Rule [3, 22] + [25] was added to rules with confidence: 0.9985250327
# Rule [25, 3] + [22] was added to rules with confidence: 0.998552821997
# Rule [3, 22] + [46] was added to rules with confidence: 0.918654161912
# Rule [3, 46] + [22] was added to rules with confidence: 0.996257620571
# Rule [59, 3] + [22] was added to rules with confidence: 0.996040760693
# Rule [65, 3] + [22] was added to rules with confidence: 0.993582821707
# Rule [74, 3] + [22] was added to rules with confidence: 0.996443837782
# Rule [3, 46] + [25] was added to rules with confidence: 0.996167079133
# Rule [25, 3] + [46] was added to rules with confidence: 0.918596237337
# Rule [3, 59] + [25] was added to rules with confidence: 0.996267930162
# Rule [3, 65] + [25] was added to rules with confidence: 0.993737080801
# Rule [74, 3] + [25] was added to rules with confidence: 0.996515679443
# Rule [59, 3] + [46] was added to rules with confidence: 0.950769130915
# Rule [65, 3] + [46] was added to rules with confidence: 0.914108536698
# Rule [3, 59] + [22] was added to rules with confidence: 0.996040760693
# Rule [3, 59] + [46] was added to rules with confidence: 0.950769130915
# Rule [65, 3] + [25] was added to rules with confidence: 0.993737080801
# Rule [5, 22] + [25] was added to rules with confidence: 0.999065579341
# Rule [25, 5] + [22] was added to rules with confidence: 0.999093869461
# Rule [5, 22] + [46] was added to rules with confidence: 0.941527919357
# Rule [46, 5] + [22] was added to rules with confidence: 0.997121180316
# Rule [59, 5] + [22] was added to rules with confidence: 0.997347823274
# Rule [65, 5] + [22] was added to rules with confidence: 0.996376696437
# Rule [74, 5] + [22] was added to rules with confidence: 0.997102437362
# Rule [5, 46] + [25] was added to rules with confidence: 0.997211143431
# Rule [25, 5] + [46] was added to rules with confidence: 0.941639529945
# Rule [59, 5] + [25] was added to rules with confidence: 0.997541884986
# Rule [5, 65] + [25] was added to rules with confidence: 0.996440263166
# Rule [74, 5] + [25] was added to rules with confidence: 0.997170615306
# Rule [5, 46] + [22] was added to rules with confidence: 0.997121180316
# Rule [22, 5] + [46] was added to rules with confidence: 0.941527919357
# Rule [59, 5] + [46] was added to rules with confidence: 0.963451710977
# Rule [65, 5] + [46] was added to rules with confidence: 0.939865874201
# Rule [74, 5] + [46] was added to rules with confidence: 0.950775524118
# Rule [65, 5] + [25] was added to rules with confidence: 0.996440263166
# Rule [32, 22] + [25] was added to rules with confidence: 0.998163934426
# Rule [32, 25] + [22] was added to rules with confidence: 0.998196662186
# Rule [46, 22] + [25] was added to rules with confidence: 0.999083232811
# Rule [25, 22] + [46] was added to rules with confidence: 0.915526275065
# Rule [25, 46] + [22] was added to rules with confidence: 0.999107336727
# Rule [59, 22] + [25] was added to rules with confidence: 0.999254728618
# Rule [25, 59] + [22] was added to rules with confidence: 0.999049331963
# Rule [60, 22] + [25] was added to rules with confidence: 0.9992460114
# Rule [25, 60] + [22] was added to rules with confidence: 0.999396718147
# Rule [22, 65] + [25] was added to rules with confidence: 0.998622182856
# Rule [25, 65] + [22] was added to rules with confidence: 0.998474784748
# Rule [70, 22] + [25] was added to rules with confidence: 0.999086693832
# Rule [25, 70] + [22] was added to rules with confidence: 0.999332419803
# Rule [72, 22] + [25] was added to rules with confidence: 0.999033505155
# Rule [72, 25] + [22] was added to rules with confidence: 0.999130070561
# Rule [74, 22] + [25] was added to rules with confidence: 0.999297969728
# Rule [25, 74] + [22] was added to rules with confidence: 0.999297969728
# Rule [32, 46] + [22] was added to rules with confidence: 0.995853188316
# Rule [32, 22] + [65] was added to rules with confidence: 0.906819672131
# Rule [32, 65] + [22] was added to rules with confidence: 0.99225084308
# Rule [22, 46] + [25] was added to rules with confidence: 0.999083232811
# Rule [59, 46] + [22] was added to rules with confidence: 0.997347767253
# Rule [59, 22] + [46] was added to rules with confidence: 0.947060032895
# Rule [60, 46] + [22] was added to rules with confidence: 0.997943220418
# Rule [60, 22] + [46] was added to rules with confidence: 0.965799077118
# Rule [65, 46] + [22] was added to rules with confidence: 0.996804168009
# Rule [65, 22] + [46] was added to rules with confidence: 0.913222123807
# Rule [72, 46] + [22] was added to rules with confidence: 0.996742558131
# Rule [72, 22] + [46] was added to rules with confidence: 0.926643041237
# Rule [74, 46] + [22] was added to rules with confidence: 0.997105859888
# Rule [74, 22] + [46] was added to rules with confidence: 0.938445985791
# Rule [60, 22] + [59] was added to rules with confidence: 0.987966341949
# Rule [59, 60] + [22] was added to rules with confidence: 0.997563798039
# Rule [65, 59] + [22] was added to rules with confidence: 0.996607173405
# Rule [74, 59] + [22] was added to rules with confidence: 0.997812387762
# Rule [65, 60] + [22] was added to rules with confidence: 0.997708199926
# Rule [65, 25] + [22] was added to rules with confidence: 0.998474784748
# Rule [65, 22] + [25] was added to rules with confidence: 0.998622182856
# Rule [72, 22] + [65] was added to rules with confidence: 0.907280927835
# Rule [72, 65] + [22] was added to rules with confidence: 0.996038763528
# Rule [74, 22] + [65] was added to rules with confidence: 0.905619050293
# Rule [65, 74] + [22] was added to rules with confidence: 0.996847181009
# Rule [22, 70] + [25] was added to rules with confidence: 0.999086693832
# Rule [72, 22] + [74] was added to rules with confidence: 0.99487757732
# Rule [72, 74] + [22] was added to rules with confidence: 0.99622556294
# Rule [32, 46] + [25] was added to rules with confidence: 0.995707686152
# Rule [32, 65] + [25] was added to rules with confidence: 0.992501973165
# Rule [32, 25] + [65] was added to rules with confidence: 0.90707892062
# Rule [59, 46] + [25] was added to rules with confidence: 0.997293640054
# Rule [25, 59] + [46] was added to rules with confidence: 0.94681397739
# Rule [60, 46] + [25] was added to rules with confidence: 0.997756240456
# Rule [25, 60] + [46] was added to rules with confidence: 0.965763754826
# Rule [46, 65] + [25] was added to rules with confidence: 0.996911590934
# Rule [25, 65] + [46] was added to rules with confidence: 0.913185731857
# Rule [72, 46] + [25] was added to rules with confidence: 0.996811865405
# Rule [72, 25] + [46] was added to rules with confidence: 0.926797048684
# Rule [74, 46] + [25] was added to rules with confidence: 0.997255042368
# Rule [25, 74] + [46] was added to rules with confidence: 0.938586391845
# Rule [59, 60] + [25] was added to rules with confidence: 0.997472440465
# Rule [25, 60] + [59] was added to rules with confidence: 0.988024855212
# Rule [59, 65] + [25] was added to rules with confidence: 0.996977818327
# Rule [74, 59] + [25] was added to rules with confidence: 0.997975642407
# Rule [60, 65] + [25] was added to rules with confidence: 0.997708199926
# Rule [72, 65] + [25] was added to rules with confidence: 0.995897290797
# Rule [72, 25] + [65] was added to rules with confidence: 0.907239746109
# Rule [74, 65] + [25] was added to rules with confidence: 0.996816271019
# Rule [25, 74] + [65] was added to rules with confidence: 0.905590969083
# Rule [72, 74] + [25] was added to rules with confidence: 0.996128782502
# Rule [72, 25] + [74] was added to rules with confidence: 0.994877082192
# Rule [60, 46] + [59] was added to rules with confidence: 0.98775281249
# Rule [59, 60] + [46] was added to rules with confidence: 0.965223217005
# Rule [65, 59] + [46] was added to rules with confidence: 0.94500199578
# Rule [74, 59] + [46] was added to rules with confidence: 0.959643451856
# Rule [65, 60] + [46] was added to rules with confidence: 0.965420781234
# Rule [65, 25] + [46] was added to rules with confidence: 0.913185731857
# Rule [65, 46] + [25] was added to rules with confidence: 0.996911590934
# Rule [74, 46] + [65] was added to rules with confidence: 0.905716672634
# Rule [65, 74] + [46] was added to rules with confidence: 0.938303659743
# Rule [72, 46] + [74] was added to rules with confidence: 0.998232664518
# Rule [72, 74] + [46] was added to rules with confidence: 0.929285760372
# Rule [59, 3] + [25] was added to rules with confidence: 0.996267930162
# Rule [65, 60] + [59] was added to rules with confidence: 0.988574702572
# Rule [65, 59] + [25] was added to rules with confidence: 0.996977818327
# Rule [74, 59] + [65] was added to rules with confidence: 0.908544748098
# Rule [65, 60] + [25] was added to rules with confidence: 0.997708199926
# Rule [74, 25] + [65] was added to rules with confidence: 0.905590969083
# Rule [65, 74] + [25] was added to rules with confidence: 0.996816271019
# Rule [72, 74] + [65] was added to rules with confidence: 0.906897219175
# Rule [72, 65] + [74] was added to rules with confidence: 0.994270354389
# Rule [0, 3, 22] + [25] was added to rules with confidence: 0.998429091881
# Rule [0, 3] + [25, 22] was added to rules with confidence: 0.991832126967
# Rule [0, 25, 3] + [22] was added to rules with confidence: 0.998462464068
# Rule [0, 3, 22] + [46] was added to rules with confidence: 0.918179083526
# Rule [0, 3] + [22, 46] was added to rules with confidence: 0.912112358058
# Rule [0, 3, 46] + [22] was added to rules with confidence: 0.996589878469
# Rule [0, 3] + [46, 22] was added to rules with confidence: 0.912112358058
# Rule [0, 3, 46] + [25] was added to rules with confidence: 0.996444766915
# Rule [0, 3] + [25, 46] was added to rules with confidence: 0.911979547115
# Rule [0, 25, 3] + [46] was added to rules with confidence: 0.918076074604
# Rule [0, 5, 22] + [25] was added to rules with confidence: 0.999039055529
# Rule [0, 5] + [25, 22] was added to rules with confidence: 0.995349791424
# Rule [0, 25, 5] + [22] was added to rules with confidence: 0.999107633169
# Rule [0, 5, 22] + [46] was added to rules with confidence: 0.942000137278
# Rule [0, 5] + [22, 46] was added to rules with confidence: 0.938521507215
# Rule [0, 46, 5] + [22] was added to rules with confidence: 0.997528710568
# Rule [0, 5] + [46, 22] was added to rules with confidence: 0.938521507215
# Rule [0, 5, 46] + [25] was added to rules with confidence: 0.997528710568
# Rule [0, 5] + [25, 46] was added to rules with confidence: 0.938521507215
# Rule [0, 25, 5] + [46] was added to rules with confidence: 0.942064799561
# Rule [0, 5, 46] + [22] was added to rules with confidence: 0.997528710568
# Rule [0, 22, 5] + [46] was added to rules with confidence: 0.942000137278
# Rule [0, 46, 22] + [25] was added to rules with confidence: 0.99900886194
# Rule [0, 22] + [25, 46] was added to rules with confidence: 0.912139682202
# Rule [0, 46] + [25, 22] was added to rules with confidence: 0.995844593613
# Rule [0, 25, 22] + [46] was added to rules with confidence: 0.913574322883
# Rule [0, 25] + [22, 46] was added to rules with confidence: 0.912188240305
# Rule [0, 25, 46] + [22] was added to rules with confidence: 0.999125364431
# Rule [0, 25] + [46, 22] was added to rules with confidence: 0.912188240305
# Rule [0, 59, 22] + [25] was added to rules with confidence: 0.999174463401
# Rule [0, 59] + [25, 22] was added to rules with confidence: 0.995521842442
# Rule [0, 25, 59] + [22] was added to rules with confidence: 0.998991195891
# Rule [0, 60, 22] + [25] was added to rules with confidence: 0.99914472043
# Rule [0, 60] + [25, 22] was added to rules with confidence: 0.996658490633
# Rule [0, 25, 60] + [22] was added to rules with confidence: 0.999394025807
# Rule [0, 22, 65] + [25] was added to rules with confidence: 0.998512214717
# Rule [0, 65] + [25, 22] was added to rules with confidence: 0.992458298829
# Rule [0, 25, 65] + [22] was added to rules with confidence: 0.998423088367
# Rule [0, 74, 22] + [25] was added to rules with confidence: 0.999333660658
# Rule [0, 74] + [25, 22] was added to rules with confidence: 0.996537735189
# Rule [0, 25, 74] + [22] was added to rules with confidence: 0.99943881309
# Rule [0, 22, 46] + [25] was added to rules with confidence: 0.99900886194
# Rule [0, 22, 46] + [59] was added to rules with confidence: 0.902168843284
# Rule [0, 59, 46] + [22] was added to rules with confidence: 0.997389538819
# Rule [0, 59] + [46, 22] was added to rules with confidence: 0.942789252422
# Rule [0, 59, 22] + [46] was added to rules with confidence: 0.94624839479
# Rule [0, 59] + [22, 46] was added to rules with confidence: 0.942789252422
# Rule [0, 65, 46] + [22] was added to rules with confidence: 0.997132242717
# Rule [0, 65] + [46, 22] was added to rules with confidence: 0.904944989944
# Rule [0, 65, 22] + [46] was added to rules with confidence: 0.910465081679
# Rule [0, 65] + [22, 46] was added to rules with confidence: 0.904944989944
# Rule [0, 46, 22] + [59] was added to rules with confidence: 0.902168843284
# Rule [0, 60, 22] + [59] was added to rules with confidence: 0.988560635758
# Rule [0, 60] + [59, 22] was added to rules with confidence: 0.986100742953
# Rule [0, 59, 60] + [22] was added to rules with confidence: 0.997518788881
# Rule [0, 65, 59] + [22] was added to rules with confidence: 0.996532617194
# Rule [0, 65, 25] + [22] was added to rules with confidence: 0.998423088367
# Rule [0, 65, 22] + [25] was added to rules with confidence: 0.998512214717
# Rule [0, 59, 46] + [25] was added to rules with confidence: 0.997292855071
# Rule [0, 59] + [25, 46] was added to rules with confidence: 0.942697861451
# Rule [0, 25, 46] + [59] was added to rules with confidence: 0.902186588921
# Rule [0, 25, 59] + [46] was added to rules with confidence: 0.945983125459
# Rule [0, 46, 65] + [25] was added to rules with confidence: 0.997132242717
# Rule [0, 65] + [25, 46] was added to rules with confidence: 0.904944989944
# Rule [0, 25, 65] + [46] was added to rules with confidence: 0.910383814341
# Rule [0, 59, 60] + [25] was added to rules with confidence: 0.997338990974
# Rule [0, 60] + [25, 59] was added to rules with confidence: 0.985923003093
# Rule [0, 25, 60] + [59] was added to rules with confidence: 0.988629072503
# Rule [0, 59, 65] + [25] was added to rules with confidence: 0.996872556685
# Rule [0, 65, 46] + [59] was added to rules with confidence: 0.904321188816
# Rule [0, 65, 59] + [46] was added to rules with confidence: 0.943332086889
# Rule [0, 65, 25] + [46] was added to rules with confidence: 0.910383814341
# Rule [0, 65, 46] + [25] was added to rules with confidence: 0.997132242717
# Rule [0, 65, 59] + [25] was added to rules with confidence: 0.996872556685
# Rule [3, 5, 22] + [25] was added to rules with confidence: 0.999025646379
# Rule [3, 5] + [25, 22] was added to rules with confidence: 0.994664449295
# Rule [25, 3, 5] + [22] was added to rules with confidence: 0.999060412027
# Rule [3, 46, 22] + [25] was added to rules with confidence: 0.999000302939
# Rule [3, 22] + [25, 46] was added to rules with confidence: 0.917735786046
# Rule [3, 46] + [25, 22] was added to rules with confidence: 0.995261664755
# Rule [25, 3, 22] + [46] was added to rules with confidence: 0.919091415831
# Rule [25, 3] + [22, 46] was added to rules with confidence: 0.917761326951
# Rule [25, 3, 46] + [22] was added to rules with confidence: 0.999091101887
# Rule [25, 3] + [46, 22] was added to rules with confidence: 0.917761326951
# Rule [3, 22, 59] + [25] was added to rules with confidence: 0.999152873713
# Rule [3, 59] + [25, 22] was added to rules with confidence: 0.995196988382
# Rule [25, 3, 59] + [22] was added to rules with confidence: 0.998925046418
# Rule [3, 22, 65] + [25] was added to rules with confidence: 0.998664803602
# Rule [3, 65] + [25, 22] was added to rules with confidence: 0.992256193503
# Rule [25, 3, 65] + [22] was added to rules with confidence: 0.998509779572
# Rule [74, 3, 22] + [25] was added to rules with confidence: 0.999387166547
# Rule [74, 3] + [25, 22] was added to rules with confidence: 0.995833183663
# Rule [25, 74, 3] + [22] was added to rules with confidence: 0.999315117872
# Rule [3, 22, 46] + [25] was added to rules with confidence: 0.999000302939
# Rule [59, 3, 46] + [22] was added to rules with confidence: 0.99703041267
# Rule [59, 3] + [46, 22] was added to rules with confidence: 0.94794573895
# Rule [59, 3, 22] + [46] was added to rules with confidence: 0.951713801642
# Rule [59, 3] + [22, 46] was added to rules with confidence: 0.94794573895
# Rule [65, 3, 46] + [22] was added to rules with confidence: 0.996658678997
# Rule [65, 3] + [46, 22] was added to rules with confidence: 0.911054206645
# Rule [65, 3, 22] + [46] was added to rules with confidence: 0.916938363608
# Rule [65, 3] + [22, 46] was added to rules with confidence: 0.911054206645
# Rule [3, 59, 22] + [25] was added to rules with confidence: 0.999152873713
# Rule [3, 25, 59] + [22] was added to rules with confidence: 0.998925046418
# Rule [3, 59, 22] + [46] was added to rules with confidence: 0.951713801642
# Rule [3, 59] + [22, 46] was added to rules with confidence: 0.94794573895
# Rule [3, 59, 46] + [22] was added to rules with confidence: 0.99703041267
# Rule [3, 59] + [46, 22] was added to rules with confidence: 0.94794573895
# Rule [3, 65, 59] + [22] was added to rules with confidence: 0.996276749566
# Rule [65, 3, 25] + [22] was added to rules with confidence: 0.998509779572
# Rule [65, 3] + [25, 22] was added to rules with confidence: 0.992256193503
# Rule [65, 3, 22] + [25] was added to rules with confidence: 0.998664803602
# Rule [65, 3, 59] + [22] was added to rules with confidence: 0.996276749566
# Rule [3, 46, 59] + [25] was added to rules with confidence: 0.996996279483
# Rule [3, 59] + [25, 46] was added to rules with confidence: 0.947913286169
# Rule [25, 3, 59] + [46] was added to rules with confidence: 0.951464217075
# Rule [3, 46, 65] + [25] was added to rules with confidence: 0.996726180431
# Rule [3, 65] + [25, 46] was added to rules with confidence: 0.911115910283
# Rule [25, 3, 65] + [46] was added to rules with confidence: 0.916858118597
# Rule [3, 59, 65] + [25] was added to rules with confidence: 0.996710526316
# Rule [3, 59, 46] + [25] was added to rules with confidence: 0.996996279483
# Rule [3, 25, 59] + [46] was added to rules with confidence: 0.951464217075
# Rule [65, 3, 25] + [46] was added to rules with confidence: 0.916858118597
# Rule [65, 3] + [25, 46] was added to rules with confidence: 0.911115910283
# Rule [65, 3, 46] + [25] was added to rules with confidence: 0.996726180431
# Rule [59, 3, 25] + [22] was added to rules with confidence: 0.998925046418
# Rule [59, 3] + [25, 22] was added to rules with confidence: 0.995196988382
# Rule [59, 3, 22] + [25] was added to rules with confidence: 0.999152873713
# Rule [59, 3, 65] + [22] was added to rules with confidence: 0.996276749566
# Rule [59, 3, 25] + [46] was added to rules with confidence: 0.951464217075
# Rule [59, 3] + [25, 46] was added to rules with confidence: 0.947913286169
# Rule [59, 3, 46] + [25] was added to rules with confidence: 0.996996279483
# Rule [65, 3, 59] + [25] was added to rules with confidence: 0.996710526316
# Rule [46, 5, 22] + [25] was added to rules with confidence: 0.99939851433
# Rule [5, 22] + [25, 46] was added to rules with confidence: 0.940961603806
# Rule [46, 5] + [25, 22] was added to rules with confidence: 0.996521426215
# Rule [25, 5, 22] + [46] was added to rules with confidence: 0.941841680129
# Rule [25, 5] + [22, 46] was added to rules with confidence: 0.94098824862
# Rule [25, 46, 5] + [22] was added to rules with confidence: 0.999308353882
# Rule [25, 5] + [46, 22] was added to rules with confidence: 0.94098824862
# Rule [59, 5, 22] + [25] was added to rules with confidence: 0.999481125957
# Rule [59, 5] + [25, 22] was added to rules with confidence: 0.996830325377
# Rule [25, 59, 5] + [22] was added to rules with confidence: 0.999286686985
# Rule [5, 22, 65] + [25] was added to rules with confidence: 0.999170627452
# Rule [5, 65] + [25, 22] was added to rules with confidence: 0.995550328958
# Rule [25, 5, 65] + [22] was added to rules with confidence: 0.999106886543
# Rule [74, 5, 22] + [25] was added to rules with confidence: 0.999452991453
# Rule [74, 5] + [25, 22] was added to rules with confidence: 0.996557013806
# Rule [25, 74, 5] + [22] was added to rules with confidence: 0.999384657459
# Rule [22, 5, 46] + [25] was added to rules with confidence: 0.99939851433
# Rule [5, 46] + [25, 22] was added to rules with confidence: 0.996521426215
# Rule [22, 5] + [25, 46] was added to rules with confidence: 0.940961603806
# Rule [25, 5, 46] + [22] was added to rules with confidence: 0.999308353882
# Rule [25, 22, 5] + [46] was added to rules with confidence: 0.941841680129
# Rule [59, 5, 46] + [22] was added to rules with confidence: 0.997750772123
# Rule [59, 5] + [46, 22] was added to rules with confidence: 0.961284688531
# Rule [22, 59, 5] + [46] was added to rules with confidence: 0.963840965106
# Rule [59, 5] + [22, 46] was added to rules with confidence: 0.961284688531
# Rule [65, 5, 46] + [22] was added to rules with confidence: 0.997531365189
# Rule [65, 5] + [46, 22] was added to rules with confidence: 0.937545688587
# Rule [65, 22, 5] + [46] was added to rules with confidence: 0.940955054388
# Rule [65, 5] + [22, 46] was added to rules with confidence: 0.937545688587
# Rule [74, 5, 46] + [22] was added to rules with confidence: 0.997526083683
# Rule [74, 5] + [46, 22] was added to rules with confidence: 0.948423385035
# Rule [22, 74, 5] + [46] was added to rules with confidence: 0.951179487179
# Rule [74, 5] + [22, 46] was added to rules with confidence: 0.948423385035
# Rule [59, 5, 22] + [46] was added to rules with confidence: 0.963840965106
# Rule [46, 59, 5] + [22] was added to rules with confidence: 0.997750772123
# Rule [65, 59, 5] + [22] was added to rules with confidence: 0.997672134725
# Rule [65, 5, 25] + [22] was added to rules with confidence: 0.999106886543
# Rule [65, 5] + [25, 22] was added to rules with confidence: 0.995550328958
# Rule [65, 5, 22] + [25] was added to rules with confidence: 0.999170627452
# Rule [65, 5, 22] + [46] was added to rules with confidence: 0.940955054388
# Rule [65, 46, 5] + [22] was added to rules with confidence: 0.997531365189
# Rule [74, 5, 22] + [46] was added to rules with confidence: 0.951179487179
# Rule [74, 46, 5] + [22] was added to rules with confidence: 0.997526083683
# Rule [59, 5, 46] + [25] was added to rules with confidence: 0.997851483819
# Rule [59, 5] + [25, 46] was added to rules with confidence: 0.961381719387
# Rule [25, 59, 5] + [46] was added to rules with confidence: 0.963750729525
# Rule [5, 46, 65] + [25] was added to rules with confidence: 0.99773426668
# Rule [5, 65] + [25, 46] was added to rules with confidence: 0.937736388774
# Rule [25, 5, 65] + [46] was added to rules with confidence: 0.941086408727
# Rule [74, 5, 46] + [25] was added to rules with confidence: 0.997741206841
# Rule [74, 5] + [25, 46] was added to rules with confidence: 0.948627918868
# Rule [25, 74, 5] + [46] was added to rules with confidence: 0.951319567893
# Rule [59, 5, 65] + [25] was added to rules with confidence: 0.997999490779
# Rule [59, 46, 5] + [22] was added to rules with confidence: 0.997750772123
# Rule [65, 5, 25] + [46] was added to rules with confidence: 0.941086408727
# Rule [65, 5] + [25, 46] was added to rules with confidence: 0.937736388774
# Rule [65, 5, 46] + [25] was added to rules with confidence: 0.99773426668
# Rule [74, 22, 5] + [46] was added to rules with confidence: 0.951179487179
# Rule [65, 59, 5] + [25] was added to rules with confidence: 0.997999490779
# Rule [32, 22, 65] + [25] was added to rules with confidence: 0.9983006725
# Rule [32, 65] + [25, 22] was added to rules with confidence: 0.990564683935
# Rule [32, 22] + [25, 65] was added to rules with confidence: 0.905278688525
# Rule [32, 25, 65] + [22] was added to rules with confidence: 0.998048075185
# Rule [32, 25] + [65, 22] was added to rules with confidence: 0.905308370766
# Rule [32, 25, 22] + [65] was added to rules with confidence: 0.906943896991
# Rule [32, 22] + [65, 25] was added to rules with confidence: 0.905278688525
# Rule [22, 46, 5] + [25] was added to rules with confidence: 0.99939851433
# Rule [59, 22, 46] + [25] was added to rules with confidence: 0.999294475198
# Rule [59, 46] + [25, 22] was added to rules with confidence: 0.996644113667
# Rule [59, 22] + [25, 46] was added to rules with confidence: 0.946391858553
# Rule [25, 59, 46] + [22] was added to rules with confidence: 0.999348710991
# Rule [25, 59] + [46, 22] was added to rules with confidence: 0.946197327852
# Rule [25, 59, 22] + [46] was added to rules with confidence: 0.947097703367
# Rule [25, 59] + [22, 46] was added to rules with confidence: 0.946197327852
# Rule [60, 22, 46] + [25] was added to rules with confidence: 0.999250538675
# Rule [60, 46] + [25, 22] was added to rules with confidence: 0.99719530057
# Rule [60, 22] + [25, 46] was added to rules with confidence: 0.965075248062
# Rule [25, 60, 46] + [22] was added to rules with confidence: 0.999437798669
# Rule [25, 60] + [46, 22] was added to rules with confidence: 0.965220801158
# Rule [25, 60, 22] + [46] was added to rules with confidence: 0.965803452855
# Rule [25, 60] + [22, 46] was added to rules with confidence: 0.965220801158
# Rule [22, 46, 65] + [25] was added to rules with confidence: 0.999218686855
# Rule [46, 65] + [25, 22] was added to rules with confidence: 0.99602535181
# Rule [22, 65] + [25, 46] was added to rules with confidence: 0.912508611357
# Rule [25, 46, 65] + [22] was added to rules with confidence: 0.999111015328
# Rule [25, 65] + [46, 22] was added to rules with confidence: 0.912373923739
# Rule [25, 22, 65] + [46] was added to rules with confidence: 0.913767616044
# Rule [25, 65] + [22, 46] was added to rules with confidence: 0.912373923739
# Rule [72, 22, 46] + [25] was added to rules with confidence: 0.999408962904
# Rule [72, 46] + [25, 22] was added to rules with confidence: 0.996153446304
# Rule [72, 22] + [25, 46] was added to rules with confidence: 0.926095360825
# Rule [72, 25, 46] + [22] was added to rules with confidence: 0.999339475056
# Rule [72, 25] + [46, 22] was added to rules with confidence: 0.926184876116
# Rule [72, 25, 22] + [46] was added to rules with confidence: 0.926991293131
# Rule [72, 25] + [22, 46] was added to rules with confidence: 0.926184876116
# Rule [74, 22, 46] + [25] was added to rules with confidence: 0.999521230438
# Rule [74, 46] + [25, 22] was added to rules with confidence: 0.996628475952
# Rule [74, 22] + [25, 46] was added to rules with confidence: 0.937996686417
# Rule [25, 74, 46] + [22] was added to rules with confidence: 0.999371708952
# Rule [25, 74] + [46, 22] was added to rules with confidence: 0.937996686417
# Rule [25, 74, 22] + [46] was added to rules with confidence: 0.938655651099
# Rule [25, 74] + [22, 46] was added to rules with confidence: 0.937996686417
# Rule [59, 46, 22] + [25] was added to rules with confidence: 0.999294475198
# Rule [59, 60, 22] + [25] was added to rules with confidence: 0.999297881434
# Rule [60, 22] + [25, 59] was added to rules with confidence: 0.987272672437
# Rule [59, 60] + [25, 22] was added to rules with confidence: 0.996863389975
# Rule [25, 60, 22] + [59] was added to rules with confidence: 0.988017626464
# Rule [25, 60] + [59, 22] was added to rules with confidence: 0.987421573359
# Rule [25, 59, 60] + [22] was added to rules with confidence: 0.999389406198
# Rule [59, 22, 65] + [25] was added to rules with confidence: 0.999399227578
# Rule [59, 65] + [25, 22] was added to rules with confidence: 0.9960084393
# Rule [25, 59, 65] + [22] was added to rules with confidence: 0.999027682453
# Rule [74, 59, 22] + [25] was added to rules with confidence: 0.999640052356
# Rule [74, 59] + [25, 22] was added to rules with confidence: 0.997453227544
# Rule [25, 74, 59] + [22] was added to rules with confidence: 0.999476525438
# Rule [60, 46, 22] + [25] was added to rules with confidence: 0.999250538675
# Rule [60, 22, 65] + [25] was added to rules with confidence: 0.999358173158
# Rule [60, 65] + [25, 22] was added to rules with confidence: 0.997067844023
# Rule [25, 60, 65] + [22] was added to rules with confidence: 0.999358173158
# Rule [46, 22, 65] + [25] was added to rules with confidence: 0.999218686855
# Rule [72, 22, 65] + [25] was added to rules with confidence: 0.999005752432
# Rule [72, 65] + [25, 22] was added to rules with confidence: 0.99504845441
# Rule [72, 22] + [25, 65] was added to rules with confidence: 0.906378865979
# Rule [72, 25, 65] + [22] was added to rules with confidence: 0.999147666738
# Rule [72, 25] + [65, 22] was added to rules with confidence: 0.906466475497
# Rule [72, 25, 22] + [65] was added to rules with confidence: 0.90725572396
# Rule [72, 22] + [65, 25] was added to rules with confidence: 0.906378865979
# Rule [74, 22, 65] + [25] was added to rules with confidence: 0.999286821705
# Rule [74, 65] + [25, 22] was added to rules with confidence: 0.996136251236
# Rule [74, 22] + [25, 65] was added to rules with confidence: 0.904973182444
# Rule [25, 74, 65] + [22] was added to rules with confidence: 0.999317808304
# Rule [25, 74] + [65, 22] was added to rules with confidence: 0.904973182444
# Rule [25, 74, 22] + [65] was added to rules with confidence: 0.905608947339
# Rule [74, 22] + [65, 25] was added to rules with confidence: 0.904973182444
# Rule [72, 46, 22] + [25] was added to rules with confidence: 0.999408962904
# Rule [72, 74, 22] + [25] was added to rules with confidence: 0.999190440724
# Rule [72, 22] + [25, 74] was added to rules with confidence: 0.994072164948
# Rule [72, 74] + [25, 22] was added to rules with confidence: 0.995419059294
# Rule [72, 25, 22] + [74] was added to rules with confidence: 0.995033860045
# Rule [72, 25] + [74, 22] was added to rules with confidence: 0.994168250797
# Rule [72, 25, 74] + [22] was added to rules with confidence: 0.999287518622
# Rule [74, 46, 22] + [25] was added to rules with confidence: 0.999521230438
# Rule [32, 22, 25] + [65] was added to rules with confidence: 0.906943896991
# Rule [32, 65, 25] + [22] was added to rules with confidence: 0.998048075185
# Rule [32, 65, 22] + [25] was added to rules with confidence: 0.9983006725
# Rule [46, 22, 5] + [25] was added to rules with confidence: 0.99939851433
# Rule [59, 22, 5] + [46] was added to rules with confidence: 0.963840965106
# Rule [60, 46, 22] + [59] was added to rules with confidence: 0.987727570808
# Rule [60, 22] + [59, 46] was added to rules with confidence: 0.953946376331
# Rule [60, 46] + [59, 22] was added to rules with confidence: 0.985696032908
# Rule [59, 60, 22] + [46] was added to rules with confidence: 0.965565663349
# Rule [59, 60] + [22, 46] was added to rules with confidence: 0.963213350387
# Rule [59, 60, 46] + [22] was added to rules with confidence: 0.997917718324
# Rule [59, 60] + [46, 22] was added to rules with confidence: 0.963213350387
# Rule [65, 59, 22] + [46] was added to rules with confidence: 0.945959090259
# Rule [65, 59] + [22, 46] was added to rules with confidence: 0.9427496151
# Rule [65, 59, 46] + [22] was added to rules with confidence: 0.997616533414
# Rule [65, 59] + [46, 22] was added to rules with confidence: 0.9427496151
# Rule [74, 59, 22] + [46] was added to rules with confidence: 0.959816753927
# Rule [74, 59] + [22, 46] was added to rules with confidence: 0.95771704705
# Rule [74, 59, 46] + [22] was added to rules with confidence: 0.997992582763
# Rule [74, 59] + [46, 22] was added to rules with confidence: 0.95771704705
# Rule [65, 60, 22] + [46] was added to rules with confidence: 0.96578049522
# Rule [65, 60] + [22, 46] was added to rules with confidence: 0.96356711941
# Rule [65, 60, 46] + [22] was added to rules with confidence: 0.998079944144
# Rule [65, 60] + [46, 22] was added to rules with confidence: 0.96356711941
# Rule [65, 22, 25] + [46] was added to rules with confidence: 0.913767616044
# Rule [65, 25] + [22, 46] was added to rules with confidence: 0.912373923739
# Rule [65, 22] + [25, 46] was added to rules with confidence: 0.912508611357
# Rule [65, 46, 25] + [22] was added to rules with confidence: 0.999111015328
# Rule [65, 25] + [46, 22] was added to rules with confidence: 0.912373923739
# Rule [65, 46] + [25, 22] was added to rules with confidence: 0.99602535181
# Rule [65, 46, 22] + [25] was added to rules with confidence: 0.999218686855
# Rule [74, 46, 22] + [65] was added to rules with confidence: 0.905981627218
# Rule [74, 46] + [65, 22] was added to rules with confidence: 0.90335958945
# Rule [65, 74, 22] + [46] was added to rules with confidence: 0.938821705426
# Rule [65, 74] + [22, 46] was added to rules with confidence: 0.935861770524
# Rule [65, 74, 46] + [22] was added to rules with confidence: 0.997397549084
# Rule [65, 74] + [46, 22] was added to rules with confidence: 0.935861770524
# Rule [72, 46, 22] + [74] was added to rules with confidence: 0.998261655599
# Rule [72, 22] + [74, 46] was added to rules with confidence: 0.925032216495
# Rule [72, 46] + [74, 22] was added to rules with confidence: 0.995009876287
# Rule [72, 74, 22] + [46] was added to rules with confidence: 0.929795019591
# Rule [72, 74] + [22, 46] was added to rules with confidence: 0.926285566811
# Rule [72, 74, 46] + [22] was added to rules with confidence: 0.996771505936
# Rule [72, 74] + [46, 22] was added to rules with confidence: 0.926285566811
# Rule [60, 22, 46] + [59] was added to rules with confidence: 0.987727570808
# Rule [65, 60, 22] + [59] was added to rules with confidence: 0.988582238287
# Rule [65, 60] + [59, 22] was added to rules with confidence: 0.98631660544
# Rule [65, 59, 60] + [22] was added to rules with confidence: 0.997715805264
# Rule [65, 59, 25] + [22] was added to rules with confidence: 0.999027682453
# Rule [65, 59] + [25, 22] was added to rules with confidence: 0.9960084393
# Rule [65, 59, 22] + [25] was added to rules with confidence: 0.999399227578
# Rule [74, 59, 22] + [65] was added to rules with confidence: 0.908736910995
# Rule [74, 59] + [65, 22] was added to rules with confidence: 0.906748947008
# Rule [65, 74, 59] + [22] was added to rules with confidence: 0.998023431323
# Rule [65, 60, 25] + [22] was added to rules with confidence: 0.999358173158
# Rule [65, 60] + [25, 22] was added to rules with confidence: 0.997067844023
# Rule [65, 60, 22] + [25] was added to rules with confidence: 0.999358173158
# Rule [72, 22, 25] + [65] was added to rules with confidence: 0.90725572396
# Rule [72, 65, 25] + [22] was added to rules with confidence: 0.999147666738
# Rule [72, 65, 22] + [25] was added to rules with confidence: 0.999005752432
# Rule [74, 22, 25] + [65] was added to rules with confidence: 0.905608947339
# Rule [74, 25] + [65, 22] was added to rules with confidence: 0.904973182444
# ...
# Rule [74, 46, 22, 65] + [25] was added to rules with confidence: 0.999537602801
# Rule [74, 22, 65] + [25, 46] was added to rules with confidence: 0.938387596899
# Rule [74, 65] + [25, 22, 46] was added to rules with confidence: 0.935429030663
# Rule [74, 46, 65] + [25, 22] was added to rules with confidence: 0.996936355251
# Rule [74, 65] + [25, 46, 22] was added to rules with confidence: 0.935429030663
# Rule [74, 46] + [25, 22, 65] was added to rules with confidence: 0.902941878506
# Rule [74, 46, 22] + [25, 65] was added to rules with confidence: 0.905562703851
# Rule [25, 74, 22, 65] + [46] was added to rules with confidence: 0.939057312192
# Rule [25, 74, 65] + [22, 46] was added to rules with confidence: 0.938416695091
# Rule [25, 74, 46, 65] + [22] was added to rules with confidence: 0.999405567848
# Rule [25, 74, 65] + [46, 22] was added to rules with confidence: 0.938416695091
# Rule [25, 74, 46] + [65, 22] was added to rules with confidence: 0.905427237913
# Rule [74, 46] + [65, 22, 25] was added to rules with confidence: 0.902941878506
# Rule [25, 74, 46, 22] + [65] was added to rules with confidence: 0.905996467383
# Rule [74, 46, 22] + [65, 25] was added to rules with confidence: 0.905562703851
# Rule [72, 74, 46, 22] + [25] was added to rules with confidence: 0.999442761119
# Rule [72, 46, 22] + [25, 74] was added to rules with confidence: 0.997705385391
# Rule [72, 22] + [25, 74, 46] was added to rules with confidence: 0.924516752577
# Rule [72, 46] + [25, 74, 22] was added to rules with confidence: 0.994455418096
# Rule [72, 74, 22] + [25, 46] was added to rules with confidence: 0.929276901655
# Rule [72, 74] + [25, 22, 46] was added to rules with confidence: 0.925769404478
# Rule [72, 74, 46] + [25, 22] was added to rules with confidence: 0.996216066097
# Rule [72, 74] + [25, 46, 22] was added to rules with confidence: 0.925769404478
# Rule [72, 25, 46, 22] + [74] was added to rules with confidence: 0.998295415014
# Rule [72, 25, 22] + [74, 46] was added to rules with confidence: 0.925411157691
# Rule [72, 25] + [74, 22, 46] was added to rules with confidence: 0.924606115282
# Rule [72, 25, 46] + [74, 22] was added to rules with confidence: 0.997636015992
# Rule [72, 25] + [74, 46, 22] was added to rules with confidence: 0.924606115282
# Rule [72, 25, 74, 22] + [46] was added to rules with confidence: 0.930029815919
# Rule [72, 25, 74] + [22, 46] was added to rules with confidence: 0.929367186994
# Rule [72, 25, 74, 46] + [22] was added to rules with confidence: 0.999373149922
# Rule [72, 25, 74] + [46, 22] was added to rules with confidence: 0.929367186994
# Rule [59, 22, 46, 5] + [25] was added to rules with confidence: 0.999528952592
# Rule [59, 60, 22, 46] + [25] was added to rules with confidence: 0.999304457793
# Rule [60, 22, 46] + [25, 59] was added to rules with confidence: 0.987040564594
# Rule [25, 60, 22, 46] + [59] was added to rules with confidence: 0.987780868152
# Rule [59, 22, 46, 65] + [25] was added to rules with confidence: 0.999455634186
# Rule [74, 59, 22, 46] + [25] was added to rules with confidence: 0.999659075413
# Rule [59, 60, 22, 65] + [25] was added to rules with confidence: 0.999419101316
# Rule [60, 22, 65] + [25, 59] was added to rules with confidence: 0.988007972165
# Rule [60, 65] + [25, 59, 22] was added to rules with confidence: 0.985743655421
# Rule [59, 60, 65] + [25, 22] was added to rules with confidence: 0.997136233465
# Rule [25, 60, 22, 65] + [59] was added to rules with confidence: 0.988642509465
# Rule [25, 60, 65] + [59, 22] was added to rules with confidence: 0.988007972165
# Rule [25, 59, 60, 65] + [22] was added to rules with confidence: 0.999350804661
# Rule [74, 59, 22, 65] + [25] was added to rules with confidence: 0.999675920925
# Rule [74, 59, 65] + [25, 22] was added to rules with confidence: 0.997699992812
# Rule [74, 59] + [25, 22, 65] was added to rules with confidence: 0.906455088647
# Rule [74, 59, 22] + [25, 65] was added to rules with confidence: 0.908442408377
# Rule [25, 74, 59, 65] + [22] was added to rules with confidence: 0.999495967742
# Rule [25, 74, 59] + [65, 22] was added to rules with confidence: 0.908293800098
# Rule [74, 59] + [65, 22, 25] was added to rules with confidence: 0.906455088647
# Rule [25, 74, 59, 22] + [65] was added to rules with confidence: 0.908769517824
# Rule [74, 59, 22] + [65, 25] was added to rules with confidence: 0.908442408377
# Rule [60, 22, 46, 65] + [25] was added to rules with confidence: 0.999370409234
# Rule [5, 22, 46, 65] + [25] was added to rules with confidence: 0.999559292155
# Rule [74, 22, 46, 65] + [25] was added to rules with confidence: 0.999537602801
# Rule [74, 22, 46] + [25, 65] was added to rules with confidence: 0.905562703851
# Rule [25, 74, 22, 46] + [65] was added to rules with confidence: 0.905996467383
# Rule [74, 22, 46] + [65, 25] was added to rules with confidence: 0.905562703851
# Rule [72, 74, 22, 65] + [25] was added to rules with confidence: 0.999178981938
# Rule [72, 22, 65] + [25, 74] was added to rules with confidence: 0.993927988069
# Rule [72, 65] + [25, 74, 22] was added to rules with confidence: 0.989990804272
# Rule [72, 22] + [25, 74, 65] was added to rules with confidence: 0.901771907216
# Rule [72, 74, 65] + [25, 22] was added to rules with confidence: 0.995695788275
# Rule [72, 74] + [25, 22, 65] was added to rules with confidence: 0.902993741532
# Rule [72, 74, 22] + [25, 65] was added to rules with confidence: 0.906414947702
# Rule [72, 25, 22, 65] + [74] was added to rules with confidence: 0.994917182057
# Rule [72, 25, 65] + [74, 22] was added to rules with confidence: 0.99406918105
# Rule [72, 25] + [65, 74, 22] was added to rules with confidence: 0.901859071431
# Rule [72, 25, 22] + [65, 74] was added to rules with confidence: 0.902644308288
# Rule [72, 22] + [65, 74, 25] was added to rules with confidence: 0.901771907216
# Rule [72, 25, 74, 65] + [22] was added to rules with confidence: 0.999321670832
# Rule [72, 25, 74] + [65, 22] was added to rules with confidence: 0.906503011853
# Rule [72, 74] + [65, 22, 25] was added to rules with confidence: 0.902993741532
# Rule [72, 25, 74, 22] + [65] was added to rules with confidence: 0.907149338864
# Rule [72, 74, 22] + [65, 25] was added to rules with confidence: 0.906414947702
# Rule [72, 74, 22, 46] + [25] was added to rules with confidence: 0.999442761119
# Rule [72, 22, 46] + [25, 74] was added to rules with confidence: 0.997705385391
# Rule [72, 25, 22, 46] + [74] was added to rules with confidence: 0.998295415014
# Rule [74, 22, 46, 5] + [25] was added to rules with confidence: 0.999676514988
# Rule [65, 22, 46, 5] + [25] was added to rules with confidence: 0.999559292155
# Rule [65, 25, 46, 5] + [22] was added to rules with confidence: 0.999356019523
# Rule [65, 25, 5] + [46, 22] was added to rules with confidence: 0.940480367452
# Rule [65, 25, 22, 5] + [46] was added to rules with confidence: 0.941321073971
# Rule [65, 25, 5] + [22, 46] was added to rules with confidence: 0.940480367452
# Rule [65, 60, 22, 46] + [59] was added to rules with confidence: 0.988387548094
# Rule [65, 60, 46] + [59, 22] was added to rules with confidence: 0.986489788794
# Rule [65, 60] + [59, 46, 22] was added to rules with confidence: 0.952377742577
# Rule [65, 60, 22] + [59, 46] was added to rules with confidence: 0.954565415667
# Rule [65, 60] + [59, 22, 46] was added to rules with confidence: 0.952377742577
# Rule [65, 59, 60, 46] + [22] was added to rules with confidence: 0.998057429449
# Rule [65, 59, 60] + [46, 22] was added to rules with confidence: 0.963384699305
# Rule [65, 59, 60, 22] + [46] was added to rules with confidence: 0.965590295575
# Rule [65, 59, 60] + [22, 46] was added to rules with confidence: 0.963384699305
# Rule [65, 59, 46, 25] + [22] was added to rules with confidence: 0.999364964166
# Rule [65, 59, 25] + [46, 22] was added to rules with confidence: 0.945092656143
# Rule [65, 59] + [25, 22, 46] was added to rules with confidence: 0.942236414438
# Rule [65, 59, 46] + [25, 22] was added to rules with confidence: 0.997073465078
# Rule [65, 59] + [25, 46, 22] was added to rules with confidence: 0.942236414438
# Rule [65, 59, 22, 25] + [46] was added to rules with confidence: 0.946012480678
# Rule [65, 59, 25] + [22, 46] was added to rules with confidence: 0.945092656143
# Rule [65, 59, 22] + [25, 46] was added to rules with confidence: 0.945444142469
# Rule [65, 59, 22, 46] + [25] was added to rules with confidence: 0.999455634186
# Rule [65, 60, 46, 25] + [22] was added to rules with confidence: 0.9994053657
# Rule [65, 60, 25] + [46, 22] was added to rules with confidence: 0.965172448738
# Rule [65, 60] + [25, 22, 46] was added to rules with confidence: 0.962960466449
# Rule [65, 60, 46] + [25, 22] was added to rules with confidence: 0.997451562227
# Rule [65, 60] + [25, 46, 22] was added to rules with confidence: 0.962960466449
# Rule [65, 60, 22, 25] + [46] was added to rules with confidence: 0.965792320173
# Rule [65, 60, 25] + [22, 46] was added to rules with confidence: 0.965172448738
# Rule [65, 60, 22] + [25, 46] was added to rules with confidence: 0.965172448738
# Rule [65, 60, 22, 46] + [25] was added to rules with confidence: 0.999370409234
# Rule [65, 5, 22, 46] + [25] was added to rules with confidence: 0.999559292155
# Rule [74, 22, 46, 25] + [65] was added to rules with confidence: 0.905996467383
# Rule [74, 46, 25] + [65, 22] was added to rules with confidence: 0.905427237913
# Rule [65, 74, 46, 25] + [22] was added to rules with confidence: 0.999405567848
# Rule [65, 74, 25] + [46, 22] was added to rules with confidence: 0.938416695091
# Rule [65, 74] + [25, 22, 46] was added to rules with confidence: 0.935429030663
# Rule [65, 74, 46] + [25, 22] was added to rules with confidence: 0.996936355251
# Rule [65, 74] + [25, 46, 22] was added to rules with confidence: 0.935429030663
# Rule [65, 74, 22, 25] + [46] was added to rules with confidence: 0.939057312192
# Rule [65, 74, 25] + [22, 46] was added to rules with confidence: 0.938416695091
# Rule [65, 74, 22] + [25, 46] was added to rules with confidence: 0.938387596899
# Rule [65, 74, 22, 46] + [25] was added to rules with confidence: 0.999537602801
# Rule [65, 60, 46, 22] + [59] was added to rules with confidence: 0.988387548094
# Rule [65, 59, 46, 22] + [25] was added to rules with confidence: 0.999455634186
# Rule [65, 60, 22, 25] + [59] was added to rules with confidence: 0.988642509465
# Rule [65, 60, 25] + [59, 22] was added to rules with confidence: 0.988007972165
# Rule [65, 60] + [25, 59, 22] was added to rules with confidence: 0.985743655421
# Rule [65, 60, 22] + [25, 59] was added to rules with confidence: 0.988007972165
# Rule [65, 59, 60, 25] + [22] was added to rules with confidence: 0.999350804661
# Rule [65, 59, 60] + [25, 22] was added to rules with confidence: 0.997136233465
# Rule [65, 59, 60, 22] + [25] was added to rules with confidence: 0.999419101316
# Rule [74, 59, 22, 25] + [65] was added to rules with confidence: 0.908769517824
# Rule [74, 59, 25] + [65, 22] was added to rules with confidence: 0.908293800098
# Rule [65, 74, 59, 25] + [22] was added to rules with confidence: 0.999495967742
# Rule [65, 74, 59] + [25, 22] was added to rules with confidence: 0.997699992812
# Rule [65, 74, 59, 22] + [25] was added to rules with confidence: 0.999675920925
# Rule [65, 60, 46, 22] + [25] was added to rules with confidence: 0.999370409234
# Rule [72, 74, 22, 25] + [65] was added to rules with confidence: 0.907149338864
# Rule [72, 22, 25] + [65, 74] was added to rules with confidence: 0.902644308288
# Rule [72, 74, 25] + [65, 22] was added to rules with confidence: 0.906503011853
# Rule [72, 65, 22, 25] + [74] was added to rules with confidence: 0.994917182057
# Rule [72, 65, 25] + [74, 22] was added to rules with confidence: 0.99406918105
# Rule [72, 65, 22] + [25, 74] was added to rules with confidence: 0.993927988069
# Rule [72, 65, 74, 25] + [22] was added to rules with confidence: 0.999321670832
# Rule [72, 65, 74] + [25, 22] was added to rules with confidence: 0.995695788275
# Rule [72, 65, 74, 22] + [25] was added to rules with confidence: 0.999178981938
# Rule [74, 46, 22, 25] + [65] was added to rules with confidence: 0.905996467383
# Rule [65, 74, 46, 22] + [25] was added to rules with confidence: 0.999537602801
# Rule [65, 5, 46, 22] + [25] was added to rules with confidence: 0.999559292155
# Rule [59, 60, 46, 65] + [25] was added to rules with confidence: 0.998092748914
# Rule [60, 46, 65] + [25, 59] was added to rules with confidence: 0.9865246989
# Rule [60, 65] + [25, 59, 46] was added to rules with confidence: 0.952411445519
# Rule [59, 60, 65] + [25, 46] was added to rules with confidence: 0.963418791763
# Rule [25, 60, 46, 65] + [59] was added to rules with confidence: 0.988457098884
# Rule [25, 60, 65] + [59, 46] was added to rules with confidence: 0.954599196027
# Rule [25, 59, 60, 65] + [46] was added to rules with confidence: 0.965558478833
# Rule [65, 60, 46, 25] + [59] was added to rules with confidence: 0.988457098884
# Rule [65, 60, 25] + [59, 46] was added to rules with confidence: 0.954599196027
# Rule [65, 60] + [25, 59, 46] was added to rules with confidence: 0.952411445519
# Rule [65, 60, 46] + [25, 59] was added to rules with confidence: 0.9865246989
# Rule [65, 59, 60, 25] + [46] was added to rules with confidence: 0.965558478833
# Rule [65, 59, 60] + [25, 46] was added to rules with confidence: 0.963418791763
# Rule [65, 59, 60, 46] + [25] was added to rules with confidence: 0.998092748914
# Rule [0, 65, 22, 25, 59] + [46] was added to rules with confidence: 0.944427376685
# Rule [0, 65, 25, 59] + [22, 46] was added to rules with confidence: 0.943461210571
# Rule [0, 65, 59] + [25, 46, 22] was added to rules with confidence: 0.940510589115
# Rule [0, 65, 22, 59] + [25, 46] was added to rules with confidence: 0.943783046222
# Rule [0, 65, 59] + [25, 22, 46] was added to rules with confidence: 0.940510589115
# Rule [0, 65, 46, 25, 59] + [22] was added to rules with confidence: 0.999349828427
# Rule [0, 65, 25, 59] + [46, 22] was added to rules with confidence: 0.943461210571
# Rule [0, 65, 46, 59] + [25, 22] was added to rules with confidence: 0.997009009009
# Rule [0, 65, 46] + [25, 59, 22] was added to rules with confidence: 0.901616372287
# Rule [0, 65, 46, 25] + [59, 22] was added to rules with confidence: 0.904209425453
# Rule [0, 65, 46, 22, 59] + [25] was added to rules with confidence: 0.999385926889
# Rule [0, 65, 46, 22] + [25, 59] was added to rules with confidence: 0.904209425453
# Rule [0, 65, 46, 22, 25] + [59] was added to rules with confidence: 0.904978411618
# Rule [65, 22, 25, 59, 60] + [46] was added to rules with confidence: 0.965604485777
# Rule [65, 25, 59, 60] + [22, 46] was added to rules with confidence: 0.964977619845
# Rule [65, 59, 60] + [25, 46, 22] was added to rules with confidence: 0.962839219965
# Rule [65, 60] + [25, 59, 22, 46] was added to rules with confidence: 0.951838495501
# Rule [65, 25, 60] + [59, 46, 22] was added to rules with confidence: 0.954024929906
# Rule [65, 22, 59, 60] + [25, 46] was added to rules with confidence: 0.965043567401
# Rule [65, 59, 60] + [25, 22, 46] was added to rules with confidence: 0.962839219965
# Rule [65, 60] + [25, 59, 46, 22] was added to rules with confidence: 0.951838495501
# Rule [65, 22, 60] + [25, 59, 46] was added to rules with confidence: 0.954024929906
# Rule [65, 22, 25, 60] + [59, 46] was added to rules with confidence: 0.954637641969
# Rule [65, 25, 60] + [59, 22, 46] was added to rules with confidence: 0.954024929906
# Rule [65, 46, 25, 59, 60] + [22] was added to rules with confidence: 0.999398421742
# Rule [65, 25, 59, 60] + [46, 22] was added to rules with confidence: 0.964977619845
# Rule [65, 46, 59, 60] + [25, 22] was added to rules with confidence: 0.997492318016
# Rule [65, 46, 60] + [25, 59, 22] was added to rules with confidence: 0.98593122709
# Rule [65, 46, 25, 60] + [59, 22] was added to rules with confidence: 0.987862464584
# Rule [65, 46, 22, 59, 60] + [25] was added to rules with confidence: 0.999433788662
# Rule [65, 46, 22, 60] + [25, 59] was added to rules with confidence: 0.987827911857
# Rule [65, 46, 22, 25, 60] + [59] was added to rules with confidence: 0.988450230995

# %%
users1 = analyse(kmeans_transactions, [65,46,22,25,60], [59])
print
users2 = analyse(kmeans_transactions, [74,46],[25,22,65])
print 
a = np.zeros(trans_len)
b = np.zeros(trans_len)
a[users1] = 1.0
b[users2] = 1.0
print 'Euclidean distance: ', euclidean_distances(a,b)
print len([i for i, j in zip(a, b) if i == j]) * 1.0 / trans_len
# Out:
# 0.619641054895
# Support[65, 46, 22, 25, 60]: 0.626881390144
# Support[59]: 0.856838825749
# Confidence[65, 46, 22, 25, 60]->[59]: 0.988450230995
# Confidence[59]->[65, 46, 22, 25, 60]: 0.723171075205
# Lift[65, 46, 22, 25, 60]->[59]: 1.15360112228
# Lift[59]->[65, 46, 22, 25, 60]: 1.15360112228
#
# 0.663982623195
# Support[74, 46]: 0.735354776427
# Support[25, 22, 65]: 0.890517354864
# Confidence[74, 46]->[25, 22, 65]: 0.902941878506
# Confidence[25, 22, 65]->[74, 46]: 0.74561446733
# Lift[74, 46]->[25, 22, 65]: 1.01395202864
# Lift[25, 22, 65]->[74, 46]: 1.01395202864
#
# Euclidean distance:  [[ 115.46861045]]
# 0.707468515512

# %% [markdown]
# ### А вот тут начинаются уже более интересные результаты по поиску ассоциативных правил!

# %% [markdown]
# ##### Apriori для бинаризованных пятым способом данных

# %%
print X.shape
# Out:
# (45578, 520)

# %%
freq_itemsets_bins = apriori(X, 0.5)
assoc_rules_bins = []
for i, itemset_row in enumerate(freq_itemsets_bins):
    if i == 0:
        continue
    for itemset in itemset_row:
        find_rules(X, itemset, [], 0.9, assoc_rules_bins)
        
assoc_rules_bins.sort(key=lambda rule: rule[2], reverse=True)
# Out:
# [[19], [31], [39], [59], [69], [79], [89], [99], [109], [119], [129], [139], [149], [159], [169], [180], [189], [209], [219], [239], [249], [259], [270], [279], [289], [299], [309], [319], [329], [339], [349], [359], [369], [379], [389], [399], [409], [419], [430], [441], [450], [459], [470], [479], [489], [499], [509]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-9617fd38dbc5> in <module>()
# ----> 1 freq_itemsets_bins = apriori(X, 0.5)
#       2 assoc_rules_bins = []
#       3 for i, itemset_row in enumerate(freq_itemsets_bins):
#       4     if i == 0:
#       5         continue
#
# <ipython-input-71-7af9a8af128c> in apriori(transactions, delta)
#      18             for f in freq_features:
#      19                 if f[0] not in itemset and list(set(itemset+f)) not in temp:
# ---> 20                     cur_support = support(transactions, list(set(itemset+f)))
#      21                     if cur_support > delta:
#      22                         temp.append(list(set(itemset+f)))
#
# <ipython-input-65-51cc071f8103> in support(transactions, itemset)
#       2     ids = []
#       3     for id, transaction in enumerate(transactions):
# ----> 4         if all(transaction[itemset] != 0):
#       5             ids.append(id)
#       6     return len(ids) * 1.0 / len(transactions)
#
# KeyboardInterrupt:

# %% [markdown]
# Вот тут не успело досчитаться

# %% [markdown]
# ##### Как применить полученные решающие правила для кластеризации множества сессий?

# %% [markdown]
# Здесь мне хочется попробовать несколько подходов.

# %% [markdown]
# ##### Первый подход

# %% [markdown]
# Первый - попробовать генерировать столбец ответов y, а затем искать правила вида X -> y. Если найдутся такие правила с большим confidence, можно делать вывод, что сгенерированный стоблец ответов приближает реальное распределение сессий на человеческие и роботные.

# %% [markdown]
# ##### Генерация столбца ответов

# %% [markdown]
# Генерируем столбец ответов с помощью kmeans (делаем то же самое, как и при бинаризации признаков). Будем обучать kmeans на разных подпространствах и смотреть, как kmeans поделил сессии на кластеры. Если доля 1 и 0 в векторе предсказаний примерно одинакова, будем считать, что такому "вектору ответов" можно доверять и затем будем искать решающие правила, в правой части которых находится признак, отвечающий за вектор предсказаний.

# %%
labels = np.empty((trans_len,0))
used_features = []

for i in range(transactions.shape[1]):
    kmeans = KMeans(n_clusters = 2)
    y_pred = kmeans.fit_predict(transactions[:, [i]])
    if 45 < sum(y_pred) * 100.0 / len(y_pred) < 55:
        print i, sum(y_pred) * 100.0 / len(y_pred)
        labels = np.column_stack((labels, y_pred))
        used_features.append(i)
# Out:
# 1 48.2118565975
# 8 51.0224230989
# 31 45.6163061126

# %%
print 'Euclidean distance: ', euclidean_distances(labels[:,1],labels[:,2])
print len([i for i, j in zip(labels[:,1],labels[:,2]) if i == j]) * 1.0 / trans_len
# Out:
# Euclidean distance:  [[ 151.02979838]]
# 0.499539251393

# %% [markdown]
# Полученные два вектора совпадают примерно на 60%. Этого мало, чтобы делать предположение о том, что для верной кластеризации достаточно поделить сессии по признаку 1 или 8 (или по обоим). Посмотрим на пары признаков:

# %%
for i, j in itertools.combinations(range(transactions.shape[1]), 2):
    if i not in used_features and j not in used_features:
        kmeans = KMeans(n_clusters = 2)
        y_pred = kmeans.fit_predict(transactions[:, [i,j]])
        if 45 < sum(y_pred) * 100.0 / len(y_pred) < 55:
            print i, j, sum(y_pred) * 100.0 / len(y_pred)
            labels = np.column_stack((labels, y_pred))
            used_features.append((i,j))

# %%
print 'Euclidean distance: ', euclidean_distances(labels[:,1],labels[:,28])
print len([i for i, j in zip(labels[:,1],labels[:,28]) if i == j]) * 1.0 / trans_len
# Out:
# Euclidean distance:  [[ 150.84097587]]
# 0.500789854754

# %% [markdown]
# Среди пар признаков, не включающих уже использованные признаки (1,8 и 32), вообще не нашлось таких, что опираясь на них, можно получить метки сессий с примерно одинаковым числом нулей и единиц. Неожиданно.

# %% [markdown]
# Используем информацию о группах признаков, найденных в начале отчета. Из каждой группы берем один признак и плюс добавляем те, которые после анализа их гистограмм показались интересными

# %%
group = [1,8,32,42,46]
kmeans = KMeans(n_clusters = 2)
y_pred = kmeans.fit_predict(transactions[:, group])
#if 40 < sum(y_pred) * 100.0 / len(y_pred) < 50:
print group, sum(y_pred) * 100.0 / len(y_pred)
#labels = np.column_stack((labels, y_pred))
#used_features.append(group)
# Out:
# [1, 8, 32, 42, 46] 51.8122778534

# %%
transactions_label = np.column_stack((mean_transactions, y_pred))
transactions_label = np.column_stack((transactions_label, np.abs(y_pred-1)))
print transactions_label.shape

freq_itemsets_label = apriori(transactions_label, 0.4)
assoc_rules_labels = []
for i, itemset_row in enumerate(freq_itemsets_label):
    if i == 0:
        continue
    for itemset in itemset_row:
        find_rules(transactions_label, itemset, [], 0.7, assoc_rules_labels, labels=[85,86])
        
assoc_rules_labels.sort(key=lambda rule: rule[2], reverse=True)
# Out:
# (45578, 87)
# [[1], [3], [8], [26], [29], [30], [31], [32], [60], [68], [70], [71], [72], [74], [85], [86]]
# j= 1
# j=  itemset: [1]
# j=  itemset: [3]
# j=  itemset: [8]
# j=  itemset: [26]
# j=  itemset: [29]
# j=  itemset: [30]
# j=  itemset: [31]
# j=  itemset: [32]
# j=  itemset: [60]
# j=  itemset: [68]
# j=  itemset: [70]
# j=  itemset: [71]
# j=  itemset: [72]
# j=  itemset: [74]
# j=  itemset: [85]
# j=  itemset: [86]
# j= 2
# j=  itemset: [1, 29]
# j=  itemset: [1, 30]
# j=  itemset: [1, 85]
# j=  itemset: [26, 3]
# j=  itemset: [3, 29]
# j=  itemset: [3, 30]
# j=  itemset: [3, 71]
# j=  itemset: [72, 3]
# j=  itemset: [74, 3]
# j=  itemset: [8, 29]
# j=  itemset: [8, 30]
# j=  itemset: [26, 29]
# j=  itemset: [26, 30]
# j=  itemset: [72, 26]
# j=  itemset: [26, 74]
# j=  itemset: [29, 30]
# j=  itemset: [29, 31]
# j=  itemset: [32, 29]
# j=  itemset: [60, 29]
# j=  itemset: [68, 29]
# j=  itemset: [29, 70]
# j=  itemset: [29, 71]
# j=  itemset: [72, 29]
# j=  itemset: [74, 29]
# j=  itemset: [29, 85]
# j=  itemset: [29, 86]
# j=  itemset: [30, 31]
# j=  itemset: [32, 30]
# j=  itemset: [60, 30]
# j=  itemset: [68, 30]
# j=  itemset: [70, 30]
# j=  itemset: [30, 71]
# j=  itemset: [72, 30]
# j=  itemset: [74, 30]
# j=  itemset: [85, 30]
# j=  itemset: [86, 30]
# j=  itemset: [30, 70]
# j=  itemset: [72, 74]
# j=  itemset: [74, 26]
# j=  itemset: [85, 29]
# j=  itemset: [30, 86]
# j= 3
# j=  itemset: [1, 29, 30]
# j=  itemset: [1, 29, 85]
# j=  itemset: [1, 85, 30]
# j=  itemset: [1, 85, 29]
# j=  itemset: [26, 3, 29]
# j=  itemset: [26, 3, 30]
# j=  itemset: [3, 29, 30]
# j=  itemset: [3, 29, 71]
# j=  itemset: [72, 3, 29]
# j=  itemset: [74, 3, 29]
# j=  itemset: [3, 30, 71]
# j=  itemset: [72, 3, 30]
# j=  itemset: [74, 3, 30]
# j=  itemset: [8, 29, 30]
# j=  itemset: [26, 29, 30]
# j=  itemset: [72, 26, 29]
# j=  itemset: [26, 74, 29]
# j=  itemset: [72, 26, 30]
# j=  itemset: [26, 74, 30]
# j=  itemset: [29, 30, 31]
# j=  itemset: [32, 29, 30]
# j=  itemset: [60, 29, 30]
# j=  itemset: [68, 29, 30]
# j=  itemset: [70, 29, 30]
# j=  itemset: [29, 30, 71]
# j=  itemset: [72, 29, 30]
# j=  itemset: [74, 29, 30]
# j=  itemset: [29, 30, 85]
# j=  itemset: [86, 29, 30]
# j=  itemset: [30, 29, 70]
# j=  itemset: [72, 74, 29]
# j=  itemset: [74, 26, 29]
# j=  itemset: [30, 29, 86]
# j=  itemset: [30, 70, 29]
# j=  itemset: [72, 74, 30]
# j=  itemset: [74, 26, 30]
# j=  itemset: [85, 30, 29]
# j=  itemset: [30, 86, 29]
# j=  itemset: [70, 30, 29]
# j=  itemset: [86, 30, 29]
# j= 4
# j=  itemset: [1, 29, 30, 85]
# j=  itemset: [1, 85, 30, 29]
# j=  itemset: [26, 3, 29, 30]
# j=  itemset: [3, 29, 30, 71]
# j=  itemset: [72, 3, 29, 30]
# j=  itemset: [74, 3, 29, 30]
# j=  itemset: [72, 26, 29, 30]
# j=  itemset: [26, 74, 29, 30]
# j=  itemset: [26, 74, 30, 29]
# j=  itemset: [72, 74, 29, 30]
# j=  itemset: [74, 26, 29, 30]
# j=  itemset: [74, 26, 30, 29]
# j= 5
# Rule [1, 29] + [85] was added to rules with confidence: 1.0
# Rule [1, 30] + [85] was added to rules with confidence: 1.0
# Rule [1, 29, 30] + [85] was added to rules with confidence: 1.0
# Rule [1, 30, 29] + [85] was added to rules with confidence: 1.0

# %% [markdown]
# Найдено 4 правила с confidence 1.0. Это неплохо, сравним полученный вектор таргетов с векторами, полученными другими способами (см. эти способы далее).

# %%
print 'Euclidean distance: ', euclidean_distances(y_pred, y_kmeans)
print len([i for i, j in zip(y_pred, y_kmeans) if i == j]) * 1.0 / trans_len

# %% [markdown]
# ##### Кластеризация на основе ассоциативных правил

# %% [markdown]
# Вот в этой статье: http://www.cs.ru.nl/~elenam/ida99f.pdf - предлагается простой способ кластеризации на основе ассоциативных правил. Берем правило наибольшего порядка (то есть такое, в котором задействовано как можно больше разных признаков) с наибольшим confidence и все сессии, в которых присутствуют признаки из левой части определяем как кластер. Далее удаляем эти сессии из выборки, и среди оставшихся сессий ищем новый кластер, используя ассоциативное правило наибольшего порядка со вторым по величине confidence и т.д. Поскольку нам нужно всего два кластера, нам хватит одной итерации этого алгоритма.

# %% [markdown]
# В силу простоты этого алгоритма, я не уверена, что он даст верные результаты. Далее сравним их с результатами кластеризации, полученными другими способами.

# %%
assoc_rules_kmeans.sort(key=lambda rule: rule[2], reverse=True)
for rule in assoc_rules_kmeans:
    if len(rule[0]) == 5:
        print rule
# Out:
# ([65, 46, 22, 59, 60], [25], 0.9994337886616179)
# ([65, 46, 25, 59, 60], [22], 0.9993984217417459)
# ([0, 65, 46, 22, 59], [25], 0.9993859268891779)
# ([0, 65, 46, 25, 59], [22], 0.9993498284269461)
# ([65, 46, 22, 25, 60], [59], 0.98845023099538)
# ([65, 22, 25, 59, 60], [46], 0.9656044857768051)
# ([0, 65, 22, 25, 59], [46], 0.9444273766854412)
# ([0, 65, 46, 22, 25], [59], 0.9049784116184745)

# %%
def label(transactions, rule):
    y = []
    for transaction in transactions:
        if all(transaction[rule] == 1):
            y.append(1)
        else:
            y.append(0)

    print "cluster_1 includes {0:.3f}% of overall sessions".format(sum(y) * 100.0 / len(transactions))
    return y

# %%
y_mean = label(mean_transactions, [74, 26, 29])
# Out:
# cluster_1 includes 44.034% of overall sessions

# %%
y_median = label(median_transactions, [41,39])
# Out:
# cluster_1 includes 40.950% of overall sessions

# %%
y_kmeans = label(kmeans_transactions, [65, 46, 22, 59, 60])
# Out:
# cluster_1 includes 61.999% of overall sessions

# %% [markdown]
# Здесь надо принять во внимание, что для выборки, которая была бинаризована с помощью kmeans, метки классов расставлялись произвольно, и поэтому говорить, что признак присутствует тогда, когда в соответсвующей ячейке таблицы стоит 1, не совсем корректно. Поэтому здесь результат в 62% можно интерпретировать как результат в 100-62=38% (при этом обратив метки y_kmeans), что довольно близко с полученным ранее значениям в 44% и 40%.

# %% [markdown]
# ##### Третий подход

# %% [markdown]
# Еще один подход - искать clusterization association rules. Про этот подход хорошо написано в статье http://ilpubs.stanford.edu:8090/158/1/1996-31.pdf (стр.10-15).
# Суть подхода в следующем. Мы хотим научиться группировать ассоциативные правила, составлять из нескольких локальных правил одно более глобальное. После поиска ассоциативных правил составляем битсет - это матрица A размера <количество признаков>х<количество признаков>, где A[i,j] = 1 <=> существует правило с не меньше, чем заданным confidence вида i -> j.
# дальше предлагается реализовать алгоритм BitOp. Суть в том, что мы подсчитываем маски для поиска кластеров по множеству ассоциативных правил. Для каждой строки битсета строим таблицу: ее нижняя строка равна текущей строке датасета, ее вторая снизу строка равна результату битового умножения первой строки маски на вторую строку датасета и т.д. Добавляем строки в маску до тех пор, пока не получим строку, состоящую из одних нулей.  Повторяем то же самое, начиная со второй строки битсета.

# %% [markdown]
# Картинка из статьи, так будет выглядеть bitset:

# %%
picture = imread('Bitset.png')
f, ax = plt.subplots(1,1, figsize=(20,10))
ax.imshow(picture)

# %% [markdown]
# Пример, как будет выглядеть маска (кружками отмечены полученные кластеры):

# %%
picture = imread('Bitset_mask.png')
imshow(picture)

# %% [markdown]
# Дальше с помощью полученной маски формируем кластеры и с помощью жадной стратегии объединяем маленькие кластеры в большие. Строим более общие ассоциативные правила, которые дальше можно использовать для деления множества поисковых сессий на роботные и человеческие.

# %% [markdown]
# Не успела закодить эту идею, к сожалению.

# %% [markdown]
# ##### Еще одна идея:

# %% [markdown]
# На одной из последних лекций Ветрова по байесовским методам упоминался метод оценки плотности распределения с помощью метода парзеновского окна (метод байесовской классификации, основанный на непараметрическом восстановлении плотности по имеющейся выборке). В основе подхода лежит идея о том, что плотность выше в тех точках, рядом с которыми находится большое количество объектов выборки.

# %% [markdown]
# Ширина окна сильно влияет на восстановление плотности. При слишком большом окне плотность вырождается в константу. Смысл этого замечания в том, что ширину окна надо подбирать, иначе ничего хорошего не получится.

# %% [markdown]
# Получив таким методом плотность, можно дальше посмотреть на ее график, и те значения, плотность которых выше какого-то определенного порога, считать принадлежащими роботным сессиям. Таким образом можно сформировать вектор лейблов.

# %% [markdown]
# Я не успела закодить этот подход, хотя подозреваю, что он даст результаты намного лучше, чем те, что можно получить генерируя вектор лейблов при помощи кластеризации по подвыборкам признаков.

# %% [markdown]
# ##### Выводы:

# %% [markdown]
# Основная проблема, которая у меня возникла - apriori, написанный мной, работает долго, поэтому искать правила с маленьким support сложно (приходится ждать около часа). Думаю, надо было не мучаться, а взять готовую реализацию алгоритма и работать с ней.

# %% [markdown]
# Жалко, что не успела закодить идею про группировку ассоциативных правил из http://ilpubs.stanford.edu:8090/158/1/1996-31.pdf и  про метод окна Парзена.
